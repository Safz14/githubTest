# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Assumes scale images are on your Drive under "Images"

# !ls /content/drive/MyDrive/Images/*csv
# Out:
# /content/drive/MyDrive/Images/labels.csv
# /content/drive/MyDrive/Images/SalmonFishScalesCoordinates-V2.csv

# %%
import os.path
import numpy as np
import math
from matplotlib.image import imread
import matplotlib.pyplot as plt
import skimage.draw as drw

SCALE_WIDTH = 1500
SCALE_HEIGHT = 2000
IMAGE_HEIGHT = 1920
TRANSECT_LENGTH = 750

PATH=os.sep + os.path.join("content", "drive", "MyDrive", "Images")

def rgb2gray(rgb):
    return np.dot(rgb[...,:3], [0.2989, 0.5870, 0.1140])

def fill_boarder(gray_img, thickness, fill_value=255):
  gray_img[:thickness,:] = fill_value
  gray_img[-thickness:,:] = fill_value
  gray_img[:,:thickness] = fill_value
  gray_img[:,-thickness:] = fill_value

def scale_edge_detector(x,index, window_size, frequency_factor, orientation):
  if not (orientation == 'LR' or orientation == 'RL'):
    raise Exception("Edge detection orientation must be 'LR' or 'RL'.")

  if window_size % 2 != 1:
    raise Exception("Window size must be an odd number.")

  l_sum = np.sum(x[index - int(window_size / 2): index])
  r_sum = np.sum(x[index + 1: index + int(window_size / 2)])

  if orientation == 'LR':
    if r_sum > l_sum * frequency_factor:
      return True
    else:
      return False
  else:
    if r_sum * frequency_factor > l_sum:
      return True
    else:
      return False

def mask1d(gray_img, kernel_size, threshold=20):
  if kernel_size % 2 != 1:
    raise Exception("Kernel size must be an odd number.")


  mask = np.zeros(gray_img.shape, dtype=np.uint8)
  filter = np.ones(kernel_size) / kernel_size

  for y in range(gray_img.shape[0]):
    delta = np.convolve(gray_img[y,:], filter, mode='same') - gray_img[y,:]
    mask[y, (np.abs(delta) > threshold)] = 255.

  return mask

def mask(gray_img, kernel_size, threshold=20):
  if kernel_size % 2 != 1:
    raise Exception("Kernel size must be an odd number.")

  xd = mask1d(gray_img, 9, 20)
  yd = mask1d(np.transpose(gray_img), 9, 20).transpose()
  mask = xd /2 + yd / 2

  return mask

def denoise(gray_img, kernel_size, percent_activated_threshold=0.4):
  if kernel_size % 2 != 1:
    raise Exception("Kernel size must be an odd number.")

  activation_cutoff = percent_activated_threshold * kernel_size * kernel_size * 255
  denoised_img = gray_img.copy()

  for j in range(int(kernel_size / 2), gray_img.shape[0] - int(kernel_size / 2)):
    for k in range(int(kernel_size / 2), gray_img.shape[1] - int(kernel_size / 2)):
      if gray_img[j, k] > 120:
        if np.sum(gray_img[j:j+kernel_size,k:k+kernel_size]) < activation_cutoff:
          denoised_img[j, k] = 0

  return denoised_img

def detect_scale_contour(gray_img, padding=25):
  contour = []

  for j in range(padding, gray_img.shape[0] - padding):
    k = padding
    k_min = padding

    # Burn in period to make sure we are not detecting a scale on the edge
    while k < gray_img.shape[1] - padding and np.sum(gray_img[j, k-10:k+25]) > 30 * 255:
      k = k + 1

    while k < gray_img.shape[1] - padding:
      if gray_img[j, k] > 0 and scale_edge_detector(gray_img[j,:], k, 25, 5, 'LR'):
        contour.append((j, k))
        k_min = k
        k = gray_img.shape[1] - padding
      k = k + 1

    # Burn in period to make sure we are not detecting a scale on the edge
    while k > k_min and np.sum(gray_img[j, k-25:k+10]) > 30 * 255:
      k = k - 1

    while k > k_min:
      if gray_img[j, k] > 0 and scale_edge_detector(gray_img[j,:], k, 25, 5, 'RL'):
        contour.append((j, k))
        k = 0
      k = k - 1

  return contour

def dilate_contour(contour, thickness):

  dialated_contour = set()
  for (j, k) in contour:
    for l in range(j - thickness, j + thickness):
      for m in range(k - thickness, k + thickness):
        dialated_contour.add((l, m))

  return list(dialated_contour)

def draw_box(gray_img, top_left_point, bottom_right_point, color=255):
  j1, k1 = top_left_point
  j2, k2 = bottom_right_point

  gray_img[j1,k1:k2+1] = color
  gray_img[j2,k1:k2+1] = color
  gray_img[j1:j2+1,k1] = color
  gray_img[j1:j2+1,k2] = color

def draw_line(gray_img, mid_point, end_point, color=255):

  rr, cc = drw.line(*mid_point, *end_point)
  gray_img[rr, cc] = color

def draw_contour(size, contour, color=255):

  img = np.zeros(size, dtype=np.uint8)
  for (j, k) in contour:
    img[j, k] = color

  return img

def load_img_to_gray(file):
  img = imread(file)
  gray = rgb2gray(img)

  return gray

def show_image_and_contour(gray):

  plt.imshow(gray, cmap=plt.get_cmap('gray'))
  plt.show()

  masked_image = mask(gray, 9, 20)
  denoised_mask = denoise(masked_image, 101, .025)

  contour = detect_scale_contour(denoised_mask, 100)
  dilated_contour = dilate_contour(contour, 5)
  drawn_contour = draw_contour(denoised_mask.shape, dilated_contour)

  plt.imshow(np.abs(drawn_contour - 255), cmap=plt.get_cmap('gray'))
  plt.show()

def frame_image_w_mean(gray, j_m, k_m):
  mean_pixel_value = np.mean(gray)

  if j_m - SCALE_HEIGHT // 2 > 0:
    gray[0:j_m - SCALE_HEIGHT // 2,:] = mean_pixel_value
    gray[j_m + SCALE_HEIGHT // 2:,:] = mean_pixel_value

  if k_m - SCALE_WIDTH // 2 > 0:
    gray[:, 0:k_m - SCALE_WIDTH // 2] = mean_pixel_value
    gray[:,k_m + SCALE_WIDTH // 2:] = mean_pixel_value

  #return gray

def calculate_transect_endpoint(mid_point, offset, length):
  """
  Given an offset from a line extending direclty down from the
  mid-point, determine the coordinates of the other endpoint of
  a line that starts at the mid-point and extends in the direction
  of the offset of specified length

  :param mid_point: the coordinates of the mid-point in row-major format
  :param offset: offset angle in radians from 6 o'clock applied counter-clockwise
  :param length: describe about parameter p3
  :return: the coordinates of the endpoint in row-major format
  """
  j, k = mid_point

  return (j + int(length * math.cos(offset)),
          k + int(length * math.sin(offset)))

def calculate_transect_angle(mid_point, end_point):
  """
  Given two points, calculated the angle between a line that
  extends down from the mid-point, opens counter-clockwise
  to the line that is defined by the mid_point and end_point

  :param mid_point: the coordinates of the mid-point in row-major format
  :param end_point: the coordinates of the end-point of the transect
     in row-major format
  :return: angle in radians
  """

  offset = 0

  # if the transect angle is at pi/2 or 3 pi/2, the atan will be undefined
  if abs(mid_point[0] - end_point[0]) < 1e-5:
    if mid_point[0] < end_point[0]:
      offset = math.pi / 2
    else:
      offset = 3 * math.pi / 2

  else:
    offset = math.atan((mid_point[1] - end_point[1]) /
                       (mid_point[0] - end_point[0]))

    # if end point is above mid point, add pi to offset as it would have
    #  been caculated relative to line extending above mid point.
    if(end_point[0] < mid_point[0]):
      offset = offset + math.pi

    # if offset is negative, add to 2pi
    if(end_point[1] < mid_point[1]):
      offset = 2 * math.pi + offset

  return offset

def calculate_coordinates_of_transects(mid_point, transect_angle, offset_step_size, transect_count):
  """
  Determine the coordintates of points along transect lines at specified offsets
  from an initial trasect.

  :param mid_point: the coordinates of the mid-point in row-major format
  :param offset: transect angle in radians from 6 o'clock applied counter-clockwise
  :param offset_step_size: Offset in radians between transects
  :param transect_count: The number of transects to generate in addition to
    main transect
  :return: a list of lists containing the coordinates of points on transects
    extending out from the mid_point.  Indexing of transects alternates out
    from main transect.
  """
  transects_coordinates = []
  calculate_transect_endpoint(mid_point, transect_angle, TRANSECT_LENGTH)
  transects_coordinates.append(drw.line(*mid_point,
                                        *calculate_transect_endpoint(mid_point, transect_angle, TRANSECT_LENGTH))
                               )

  for offset in [o for i in range(1, int(transect_count / 2) + 1) for o in (i * offset_step_size, -i * offset_step_size)]:
    transects_coordinates.append(drw.line(*mid_point,
                                          *calculate_transect_endpoint(mid_point, transect_angle + offset, TRANSECT_LENGTH))
                                 )

  return transects_coordinates

def draw_transects(gray_img, transects_coordinates, color = 250):
  """
  Draws transects on a copy of grayscale image.

  :param gray_img: 2d array of a grayscale image
  :param trasects_coordinates: a list of lists containing the coordinates of points on transects
    extending out from the mid_point.  Indexing of transects alternates out
    from main transect.
  :param color: pixel value for drawn transect
  :return: 2d array representing grayscale image with transects applied
  """
  img_w_transects = np.copy(gray_img)
  j_max = gray_img.shape[0]
  k_max = gray_img.shape[1]

  for i, transect in enumerate(transects_coordinates):
    rr, cc = transect
    rr[rr >= j_max] = j_max - 1
    cc[cc >= k_max] = k_max - 1

    img_w_transects[rr, cc] = color

  return img_w_transects

def extract_transects_signals(gray_img, transects_coordinates):

  transect_signals = []
  for i, transect in enumerate(transects_coordinates):
    signal = []
    rr, cc = transect
    for j, k in zip(rr, cc):
      signal.append(gray_img[j, k])
    transect_signals.append(signal)

  return transect_signals

def convolve_transects_signals(transects_signals, kernel_size):

  filter = np.ones(kernel_size) / kernel_size
  convolved_signals = []

  for signal in transects_signals:
    convolved_signals.append(convolve_transects_signal(signal, kernel_size))

  return convolved_signals

def convolve_transects_signal(transects_signal, kernel_size):

  filter = np.ones(kernel_size) / kernel_size
  signal_length = max(len(transects_signal), kernel_size) - min(len(transects_signal), kernel_size) + 1
  offset = int((len(transects_signal) - signal_length) / 2)
  return(np.convolve(transects_signal, filter, mode='valid') - transects_signal[offset:-offset])


def plot_transect_signals(transects_signals, figure_path, figure_filename):
  n = len(transects)

  fig, axes = plt.subplots(2 * n)
  for i, signal in enumerate(transects_signals):
    axes[i].plot(signal)

  convolved_signals = convolve_transects_signals(transects_signals, 5)
  for i, signal in enumerate(convolved_signals):
    axes[i + n].plot(signal)

  fig.savefig(os.path.join(figure_path, figure_filename +".png"), format="png",
              bbox_inches="tight")

def plot_transect_signals_for_image(filepath, mid_point, transect_angle,
                                    offset_step_size, transect_count,
                                    figure_path):
  gray = load_img_to_gray(filepath)
  filename = os.path.splitext(os.path.basename(filepath))[0]

  transects = calculate_coordinates_of_transects(mid_point, transect_angle,
                                                 offset_step_size, transect_count)
  transects_signals = extract_transects_signals(gray, transects)

  plot_transect_signals(transects_signals, figure_path, filename)

# %%
import pandas as pd
from ast import literal_eval

scale_data = pd.read_csv('/content/drive/MyDrive/Images/SalmonFishScalesCoordinates-V2.csv', sep=",",
                          names=['filename', 'lt_center', 'br_center', 'end_point'],
                          dtype={'filename': 'string'},
                          converters={'lt_center': literal_eval,
                                      'br_center': literal_eval,
                                      'end_point': literal_eval},
                          header=0)
scale_data['filepath'] = scale_data.apply(lambda row: os.path.join(PATH, row['filename']) +  ".tif", axis=1)

# Switch from column-major to row major
scale_data['lt_center'] = scale_data.apply(lambda row: (row['lt_center'][1], row['lt_center'][0]) , axis = 1)
scale_data['br_center'] = scale_data.apply(lambda row: (row['br_center'][1], row['br_center'][0]) , axis = 1)
scale_data['end_point'] = scale_data.apply(lambda row: (row['end_point'][1], row['end_point'][0]) , axis = 1)

scale_data['mid_center'] = scale_data.apply(lambda row: (int((row['lt_center'][0] + row['br_center'][0]) / 2),
                                                         int((row['lt_center'][1] + row['br_center'][1]) / 2)) , axis=1)
scale_data['transect_angle'] = scale_data.apply(lambda row: calculate_transect_angle(row['mid_center'], row['end_point']), axis=1)

scale_data['id'] = scale_data.apply(lambda row: int(row['filename'].split('_')[0]), axis=1)

# Bring in labels
label_data = pd.read_csv('/content/drive/MyDrive/Images/labels.csv', sep=",",
                          names=['id', 'age', 'type', 'fold'],
                          dtype={'filename': 'int64', 'age': 'int32', 'type': 'int32', 'fold': 'int32'},
                          header=0)

# Fold in labels with scale data
scale_data = scale_data.merge(label_data, on='id', how='left', validate='many_to_one')

# Drop any rows with NaNs, recast ints
scale_data = scale_data.dropna().astype({'fold': int, 'type': int})

# %%
# Get transect signals
transects_signals = []

for index, row in scale_data.iterrows():
  #print(index, row['id'], row['filename'], row['fold'])

  gray = load_img_to_gray(row['filepath'])
  transects = calculate_coordinates_of_transects(row['mid_center'],
                                                 row['transect_angle'],
                                                 .1, 11)

  transects_signals.append([row['id'],
                           extract_transects_signals(gray, transects)],
                           )

transects_signals_df = pd.DataFrame(transects_signals, columns=['id', 'signals'])

# Merge with labels and explode
transects_signals_df = transects_signals_df.merge(label_data, on='id',
                                                  how='left',
                                                  validate='many_to_one')\
                                                  .explode('signals', ignore_index=True)\
                                                  .rename(columns={"signals": "signal"})
transects_signals_df['signal'] = transects_signals_df['signal'].apply(lambda x: np.array(x))

# Add convolved signals
transects_signals_df['convolved_signal'] = transects_signals_df.apply(lambda row: convolve_transects_signal(row['signal'], 5), axis=1)

# %%
# Create a copy of transects_signals_df so that it doesn't have to be generated
#  each time
from numpy.fft import fft, ifft

def rolling_window(a, window, step):
    shape = a.shape[:-1] + ((a.shape[-1] - window + 1)//step, window)
    strides = (a.strides[0] * step,) + (a.strides[-1],)
    return np.lib.stride_tricks.as_strided(a, shape=shape, strides=strides)

#print(rolling_window(s[2], 25, 1).shape)

df = transects_signals_df.copy(deep=True)
df['signal'] = df['signal'].apply(lambda x: np.pad(x, (0, int(1.4 * TRANSECT_LENGTH) - x.size), 'constant', constant_values=(0, 0)))
df['signal'] = df['signal'].apply(lambda x: np.flip(x))
df['convolved_signal'] = df['convolved_signal'].apply(lambda x: np.pad(x, (0, int(1.4 * TRANSECT_LENGTH) - x.size), 'constant', constant_values=(0, 0)))
df['convolved_signal'] = df['convolved_signal'].apply(lambda x: np.flip(x))
df['convolved_freq'] = df['signal'].apply(lambda x: np.abs(fft(x))[0:75])

train = df[df['fold'] < 9][['convolved_freq', 'type']].to_numpy(copy=True)
val = df[df['fold'] >= 9][['convolved_freq', 'type']].to_numpy(copy=True)

x_train = np.stack(train[:,0])
x_max = np.max(x_train)
x_train = x_train / x_max

y_train = train[:,1].astype(int)

x_val = np.stack(val[:,0]) / x_max
y_val = val[:,1].astype(int)

import keras
model = keras.Sequential([
    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dropout(.5),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dropout(.75),
    keras.layers.Dense(124, activation='relu'),
    keras.layers.Dropout(.75),
    keras.layers.Dense(2, activation='softmax')
])
model.compile(optimizer='rmsprop', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.fit(x=x_train, y=y_train, batch_size=256, epochs=350, validation_data=(x_val, y_val))

plt.plot(x_train[2,:])

#from numpy.fft import fft, ifft
#X = fft(x_train[2,:])
#o = ifft(X)

#print(len(X))

#print(np.abs(X[0:100]))

#np.sum(x_train[2,:] - o)

#plt.stem(freq, np.abs(X), 'b', \
#         markerfmt=" ", basefmt="-b")
#plt.xlabel('Freq (Hz)')
#plt.ylabel('FFT Amplitude |X(freq)|')
#plt.xlim(0, 10)

#plt.plot(o)
# Out:
# Epoch 1/350
# 8/8 [==============================] - 2s 73ms/step - loss: 0.6966 - accuracy: 0.5206 - val_loss: 0.6838 - val_accuracy: 0.6000
# Epoch 2/350
# 8/8 [==============================] - 0s 26ms/step - loss: 0.6925 - accuracy: 0.5521 - val_loss: 0.6855 - val_accuracy: 0.6000
# Epoch 3/350
# 8/8 [==============================] - 0s 28ms/step - loss: 0.6935 - accuracy: 0.5373 - val_loss: 0.6840 - val_accuracy: 0.6000
# Epoch 4/350
# 8/8 [==============================] - 0s 26ms/step - loss: 0.6903 - accuracy: 0.5465 - val_loss: 0.6834 - val_accuracy: 0.6000
# Epoch 5/350
# 8/8 [==============================] - 0s 29ms/step - loss: 0.6923 - accuracy: 0.5465 - val_loss: 0.6839 - val_accuracy: 0.6000
# Epoch 6/350
# 8/8 [==============================] - 0s 27ms/step - loss: 0.6914 - accuracy: 0.5449 - val_loss: 0.6831 - val_accuracy: 0.6000
# Epoch 7/350
# 8/8 [==============================] - 0s 27ms/step - loss: 0.6904 - accuracy: 0.5582 - val_loss: 0.6823 - val_accuracy: 0.6000
# Epoch 8/350
# 8/8 [==============================] - 0s 27ms/step - loss: 0.6880 - accuracy: 0.5505 - val_loss: 0.6811 - val_accuracy: 0.6000
# Epoch 9/350
# 8/8 [==============================] - 0s 27ms/step - loss: 0.6907 - accuracy: 0.5515 - val_loss: 0.6805 - val_accuracy: 0.6000
# Epoch 10/350
# 8/8 [==============================] - 0s 24ms/step - loss: 0.6917 - accuracy: 0.5465 - val_loss: 0.6796 - val_accuracy: 0.6000
# Epoch 11/350
# 8/8 [==============================] - 0s 26ms/step - loss: 0.6880 - accuracy: 0.5587 - val_loss: 0.6780 - val_accuracy: 0.6000
# Epoch 12/350
# 8/8 [==============================] - 0s 28ms/step - loss: 0.6881 - accuracy: 0.5632 - val_loss: 0.6772 - val_accuracy: 0.6000
# Epoch 13/350
# 8/8 [==============================] - 0s 29ms/step - loss: 0.6896 - accuracy: 0.5576 - val_loss: 0.6772 - val_accuracy: 0.6000
# Epoch 14/350
# 8/8 [==============================] - 0s 19ms/step - loss: 0.6885 - accuracy: 0.5571 - val_loss: 0.6778 - val_accuracy: 0.6000
# Epoch 15/350
# 8/8 [==============================] - 0s 17ms/step - loss: 0.6869 - accuracy: 0.5622 - val_loss: 0.6768 - val_accuracy: 0.6000
# Epoch 16/350
# 8/8 [==============================] - 0s 17ms/step - loss: 0.
350
# 8/8 [==============================] - 0s 19ms/step - loss: 0.6117 - accuracy: 0.6618 - val_loss: 0.4723 - val_accuracy: 0.8182
# Epoch 323/350
# 8/8 [==============================] - 0s 20ms/step - loss: 0.6062 - accuracy: 0.6633 - val_loss: 0.5439 - val_accuracy: 0.7403
# Epoch 324/350
# 8/8 [==============================] - 0s 19ms/step - loss: 0.6096 - accuracy: 0.6572 - val_loss: 0.4828 - val_accuracy: 0.8130
# Epoch 325/350
# 8/8 [==============================] - 0s 19ms/step - loss: 0.6076 - accuracy: 0.6592 - val_loss: 0.4503 - val_accuracy: 0.8390
# Epoch 326/350
# 8/8 [==============================] - 0s 21ms/step - loss: 0.6035 - accuracy: 0.6679 - val_loss: 0.4539 - val_accuracy: 0.8312
# Epoch 327/350
# 8/8 [==============================] - 0s 19ms/step - loss: 0.6080 - accuracy: 0.6582 - val_loss: 0.4826 - val_accuracy: 0.8156
# Epoch 328/350
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6124 - accuracy: 0.6557 - val_loss: 0.4567 - val_accuracy: 0.8312
# Epoch 329/350
# 8/8 [==============================] - 0s 20ms/step - loss: 0.6020 - accuracy: 0.6602 - val_loss: 0.4740 - val_accuracy: 0.8156
# Epoch 330/350
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6040 - accuracy: 0.6602 - val_loss: 0.5085 - val_accuracy: 0.7792
# Epoch 331/350
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6031 - accuracy: 0.6612 - val_loss: 0.4783 - val_accuracy: 0.8104
# Epoch 332/350
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6123 - accuracy: 0.6557 - val_loss: 0.4953 - val_accuracy: 0.8052
# Epoch 333/350
# 8/8 [==============================] - 0s 18ms/step - loss: 0.6016 - accuracy: 0.6663 - val_loss: 0.4721 - val_accuracy: 0.8286
# Epoch 334/350
# 8/8 [==============================] - 0s 19ms/step - loss: 0.6045 - accuracy: 0.6648 - val_loss: 0.4539 - val_accuracy: 0.8364
# Epoch 335/350
# 8/8 [==============================] - 0s 19ms/step - loss: 0.6085 - accuracy: 0.6592 - val_loss: 0.4875 - val_accuracy: 0.8078
# Epoch 336/350
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6086 - accuracy: 0.6546 - val_loss: 0.4734 - val_accuracy: 0.8156
# Epoch 337/350
# 8/8 [==============================] - 0s 19ms/step - loss: 0.6053 - accuracy: 0.6612 - val_loss: 0.4424 - val_accuracy: 0.8364
# Epoch 338/350
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6062 - accuracy: 0.6612 - val_loss: 0.4608 - val_accuracy: 0.8260
# Epoch 339/350
# 8/8 [==============================] - 0s 19ms/step - loss: 0.6085 - accuracy: 0.6602 - val_loss: 0.4588 - val_accuracy: 0.8234
# Epoch 340/350
# 8/8 [==============================] - 0s 20ms/step - loss: 0.6051 - accuracy: 0.6607 - val_loss: 0.4909 - val_accuracy: 0.8078
# Epoch 341/350
# 8/8 [==============================] - 0s 18ms/step - loss: 0.6052 - accuracy: 0.6582 - val_loss: 0.4783 - val_accuracy: 0.8130
# Epoch 342/350
# 8/8 [==============================] - 0s 18ms/step - loss: 0.6075 - accuracy: 0.6592 - val_loss: 0.4612 - val_accuracy: 0.8286
# Epoch 343/350
# 8/8 [==============================] - 0s 18ms/step - loss: 0.6061 - accuracy: 0.6618 - val_loss: 0.4487 - val_accuracy: 0.8364
# Epoch 344/350
# 8/8 [==============================] - 0s 18ms/step - loss: 0.6092 - accuracy: 0.6582 - val_loss: 0.4650 - val_accuracy: 0.8208
# Epoch 345/350
# 8/8 [==============================] - 0s 19ms/step - loss: 0.6006 - accuracy: 0.6673 - val_loss: 0.4602 - val_accuracy: 0.8312
# Epoch 346/350
# 8/8 [==============================] - 0s 18ms/step - loss: 0.6123 - accuracy: 0.6521 - val_loss: 0.4618 - val_accuracy: 0.8208
# Epoch 347/350
# 8/8 [==============================] - 0s 18ms/step - loss: 0.6014 - accuracy: 0.6643 - val_loss: 0.4647 - val_accuracy: 0.8182
# Epoch 348/350
# 8/8 [==============================] - 0s 17ms/step - loss: 0.6097 - accuracy: 0.6592 - val_loss: 0.4933 - val_accuracy: 0.8052
# Epoch 349/350
# 8/8 [==============================] - 0s 18ms/step - loss: 0.6075 - accuracy: 0.6597 - val_loss: 0.4555 - val_accuracy: 0.8364
# Epoch 350/350
# 8/8 [==============================] - 0s 17ms/step - loss: 0.6039 - accuracy: 0.6628 - val_loss: 0.4508 - val_accuracy: 0.8364

# %%
# transects_signals_df contains the intensities of transects, type, age, and fold
# you should be able to use these to train models

# Create a copy of transects_signals_df so that it doesn't have to be generated
#  each time

def rolling_window(a, window, step):
    shape = a.shape[:-1] + ((a.shape[-1] - window + 1)//step, window)
    strides = (a.strides[0] * step,) + (a.strides[-1],)
    return np.lib.stride_tricks.as_strided(a, shape=shape, strides=strides)

#print(rolling_window(s[2], 25, 1).shape)

df = transects_signals_df.copy(deep=True)
df['signal'] = df['signal'].apply(lambda x: np.pad(x, (0, int(1.4 * TRANSECT_LENGTH) - x.size), 'constant', constant_values=(0, 0)))
df['signal'] = df['signal'].apply(lambda x: np.flip(x))
df['convolved_signal'] = df['convolved_signal'].apply(lambda x: np.pad(x, (0, int(1.4 * TRANSECT_LENGTH) - x.size), 'constant', constant_values=(0, 0)))
df['convolved_signal'] = df['convolved_signal'].apply(lambda x: np.flip(x))

import keras

# Untuned example from
# https://keras.io/examples/timeseries/timeseries_classification_from_scratch/

def make_model(input_shape):
    input_layer = keras.layers.Input(input_shape)

    conv1 = keras.layers.Conv1D(filters=64, kernel_size=9, padding="same")(input_layer)
    conv1 = keras.layers.BatchNormalization()(conv1)
    conv1 = keras.layers.ReLU()(conv1)

    conv2 = keras.layers.Conv1D(filters=64, kernel_size=5, padding="same")(conv1)
    conv2 = keras.layers.BatchNormalization()(conv2)
    conv2 = keras.layers.ReLU()(conv2)

    conv3 = keras.layers.Conv1D(filters=64, kernel_size=3, padding="same")(conv2)
    conv3 = keras.layers.BatchNormalization()(conv3)
    conv3 = keras.layers.ReLU()(conv3)

    gap = keras.layers.GlobalAveragePooling1D()(conv3)

    output_layer = keras.layers.Dense(2, activation="softmax")(gap)

    return keras.models.Model(inputs=input_layer, outputs=output_layer)

train = df[df['fold'] < 9][['signal', 'type']].to_numpy(copy=True)
val = df[df['fold'] >= 9][['signal', 'type']].to_numpy(copy=True)

print(train.shape)

x_train = np.stack(train[:,0]) / 250.
y_train = train[:,1].astype(int)

x_val = np.stack(val[:,0]) / 250.
y_val = val[:,1].astype(int)

x_train = x_train.reshape((x_train.shape[0], x_train.shape[1], 1))
x_val = x_val.reshape((x_val.shape[0], x_val.shape[1], 1))

model = make_model(input_shape=x_train.shape[1:])

epochs = 500
batch_size = 32

callbacks = [
    keras.callbacks.ModelCheckpoint(
        "best_model.keras", save_best_only=True, monitor="val_loss"
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss", factor=0.5, patience=20, min_lr=0.0001
    ),
    keras.callbacks.EarlyStopping(monitor="val_loss", patience=50, verbose=1),
]
model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["sparse_categorical_accuracy"],
)

history = model.fit(
    x_train,
    y_train,
    batch_size=batch_size,
    epochs=epochs,
    callbacks=callbacks,
    validation_split=0.2,
    verbose=1,
)
# Out:
# (1969, 2)
# Epoch 1/500
# 50/50 [==============================] - 21s 353ms/step - loss: 0.6271 - sparse_categorical_accuracy: 0.6241 - val_loss: 0.7028 - val_sparse_categorical_accuracy: 0.5254 - lr: 0.0010
# Epoch 2/500
# 50/50 [==============================] - 16s 325ms/step - loss: 0.6187 - sparse_categorical_accuracy: 0.6495 - val_loss: 0.7027 - val_sparse_categorical_accuracy: 0.4315 - lr: 0.0010
# Epoch 3/500
# 50/50 [==============================] - 18s 360ms/step - loss: 0.6135 - sparse_categorical_accuracy: 0.6438 - val_loss: 0.7311 - val_sparse_categorical_accuracy: 0.4442 - lr: 0.0010
# Epoch 4/500
# 50/50 [==============================] - 16s 326ms/step - loss: 0.6208 - sparse_categorical_accuracy: 0.6470 - val_loss: 0.7797 - val_sparse_categorical_accuracy: 0.4619 - lr: 0.0010
# Epoch 5/500
# 50/50 [==============================] - 18s 348ms/step - loss: 0.6128 - sparse_categorical_accuracy: 0.6463 - val_loss: 0.8606 - val_sparse_categorical_accuracy: 0.4746 - lr: 0.0010
# Epoch 6/500
# 50/50 [==============================] - 17s 332ms/step - loss: 0.6068 - sparse_categorical_accuracy: 0.6413 - val_loss: 0.9251 - val_sparse_categorical_accuracy: 0.4746 - lr: 0.0010
# Epoch 7/500
# 50/50 [==============================] - 16s 325ms/step - loss: 0.6097 - sparse_categorical_accuracy: 0.6476 - val_loss: 0.8417 - val_sparse_categorical_accuracy: 0.4162 - lr: 0.0010
# Epoch 8/500
# 50/50 [==============================] - 17s 343ms/step - loss: 0.6129 - sparse_categorical_accuracy: 0.6457 - val_loss: 0.7734 - val_sparse_categorical_accuracy: 0.4239 - lr: 0.0010
# Epoch 9/500
# 50/50 [==============================] - 16s 327ms/step - loss: 0.6123 - sparse_categorical_accuracy: 0.6451 - val_loss: 0.7912 - val_sparse_categorical_accuracy: 0.5330 - lr: 0.0010
# Epoch 10/500
# 50/50 [==============================] - 17s 335ms/step - loss: 0.6106 - sparse_categorical_accuracy: 0.6476 - val_loss: 0.8866 - val_sparse_categorical_accuracy: 0.5482 - lr: 0.0010
# Epoch 11/500
# 50/50 [==============================] - 17s 339ms/step - loss: 0.6100 - sparse_categorical_accuracy: 0.6413 - val_loss: 0.7095 - val_sparse_categorical_accuracy: 0.5178 - lr: 0.0010
# Epoch 12/500
# 50/50 [==============================] - 17s 330ms/step - loss: 0.6029 - sparse_categorical_accuracy: 0.6590 - val_loss: 0.7066 - val_sparse_categorical_accuracy: 0.4239 - lr: 0.0010
# Epoch 13/500
# 50/50 [==============================] - 17s 341ms/step - loss: 0.6070 - sparse_categorical_accuracy: 0.6565 - val_loss: 0.7149 - val_sparse_categorical_accuracy: 0.5279 - lr: 0.0010
# Epoch 14/500
# 50/50 [==============================] - 16s 325ms/step - loss: 0.6031 - sparse_categorical_accuracy: 0.6521 - val_loss: 0.9858 - val_sparse_categorical_accuracy: 0.4670 - lr: 0.0010
# Epoch 15/500
# 50/50 [==============================] - 16s 327ms/step - loss: 0.5978 - sparse_categorical_accuracy: 0.6578 - val_loss: 0.7610 - val_sparse_categorical_accuracy: 0.5838 - lr: 0.0010
# Epoch 16/500
# 50/50 [==============================] - 16s 317ms/step - loss: 0.5993 - sparse_categorical_accuracy: 0.6641 - val_loss: 0.7629 - val_sparse_categorical_accuracy: 0.3985 - lr: 0.0010
# Epoch 17/500
# 50/50 [==============================] - 16s 318ms/step - loss: 0.5987 - sparse_categorical_accuracy: 0.6648 - val_loss: 0.7370 - val_sparse_categorical_accuracy: 0.4594 - lr: 0.0010
# Epoch 18/500
# 50/50 [==============================] - 17s 335ms/step - loss: 0.5912 - sparse_categorical_accuracy: 0.6806 - val_loss: 0.7859 - val_sparse_categorical_accuracy: 0.4670 - lr: 0.0010
# Epoch 19/500
# 50/50 [==============================] - 16s 328ms/step - loss: 0.5966 - sparse_categorical_accuracy: 0.6737 - val_loss: 0.8676 - val_sparse_categorical_accuracy: 0.5254 - lr: 0.0010
# Epoch 20/500
# 50/50 [==============================] - 17s 331ms/step - loss: 0.5951 - sparse_categorical_accuracy: 0.6654 - val_loss: 0.8567 - val_sparse_categorical_accuracy: 0.5406 - lr: 0.0010
# Epoch 21/500
# 50/50 [==============================] - 17s 342ms/step - loss: 0.5918 - sparse_categorical_accuracy: 0.6673 - val_loss: 1.5080 - val_sparse_categorical_accuracy: 0.5787 - lr: 0.0010
# Epoch 22/500
# 50/50 [==============================] - 17s 336ms/step - loss: 0.5957 - sparse_categorical_accuracy: 0.6540 - val_loss: 1.0185 - val_sparse_categorical_accuracy: 0.5939 - lr: 0.0010
# Epoch 23/500
# 50/50 [==============================] - 17s 334ms/step - loss: 0.5882 - sparse_categorical_accuracy: 0.6806 - val_loss: 0.8297 - val_sparse_categorical_accuracy: 0.5355 - lr: 5.0000e-04
# Epoch 24/500
# 50/50 [==============================] - 17s 344ms/step - loss: 0.5846 - sparse_categorical_accuracy: 0.6844 - val_loss: 1.1319 - val_sparse_categorical_accuracy: 0.5431 - lr: 5.0000e-04
# Epoch 25/500
# 50/50 [==============================] - 17s 337ms/step - loss: 0.5851 - sparse_categorical_accuracy: 0.6825 - val_loss: 1.0335 - val_sparse_categorical_accuracy: 0.5254 - lr: 5.0000e-04
# Epoch 26/500
# 50/50 [==============================] - 17s 332ms/step - loss: 0.5802 - sparse_categorical_accuracy: 0.6863 - val_loss: 0.7325 - val_sparse_categorical_accuracy: 0.4391 - lr: 5.0000e-04
# Epoch 27/500
# 50/50 [==============================] - 16s 323ms/step - loss: 0.5816 - sparse_categorical_accuracy: 0.6914 - val_loss: 0.7440 - val_sparse_categorical_accuracy: 0.4264 - lr: 5.0000e-04
# Epoch 28/500
# 50/50 [==============================] - 16s 329ms/step - loss: 0.5794 - sparse_categorical_accuracy: 0.6743 - val_loss: 0.8769 - val_sparse_categorical_accuracy: 0.4721 - lr: 5.0000e-04
# Epoch 29/500
# 50/50 [==============================] - 16s 325ms/step - loss: 0.5747 - sparse_categorical_accuracy: 0.6984 - val_loss: 0.7803 - val_sparse_categorical_accuracy: 0.5203 - lr: 5.0000e-04
# Epoch 30/500
# 50/50 [==============================] - 16s 328ms/step - loss: 0.5773 - sparse_categorical_accuracy: 0.6978 - val_loss: 1.0740 - val_sparse_categorical_accuracy: 0.4264 - lr: 5.0000e-04
# Epoch 31/500
# 50/50 [==============================] - 17s 344ms/step - loss: 0.5786 - sparse_categorical_accuracy: 0.6940 - val_loss: 0.8297 - val_sparse_categorical_accuracy: 0.5635 - lr: 5.0000e-04
# Epoch 32/500
# 50/50 [==============================] - 17s 338ms/step - loss: 0.5820 - sparse_categorical_accuracy: 0.6984 - val_loss: 0.9882 - val_sparse_categorical_accuracy: 0.5482 - lr: 5.0000e-04
# Epoch 33/500
# 50/50 [==============================] - 17s 334ms/step - loss: 0.5758 - sparse_categorical_accuracy: 0.6971 - val_loss: 0.8682 - val_sparse_categorical_accuracy: 0.5660 - lr: 5.0000e-04
# Epoch 34/500
# 50/50 [==============================] - 16s 325ms/step - loss: 0.5685 - sparse_categorical_accuracy: 0.7029 - val_loss: 0.8361 - val_sparse_categorical_accuracy: 0.5533 - lr: 5.0000e-04
# Epoch 35/500
# 50/50 [==============================] - 15s 305ms/step - loss: 0.5676 - sparse_categorical_accuracy: 0.7079 - val_loss: 0.8069 - val_sparse_categorical_accuracy: 0.5482 - lr: 5.0000e-04
# Epoch 36/500
# 50/50 [==============================] - 17s 331ms/step - loss: 0.5689 - sparse_categorical_accuracy: 0.7048 - val_loss: 0.8791 - val_sparse_categorical_accuracy: 0.5076 - lr: 5.0000e-04
# Epoch 37/500
# 50/50 [==============================] - 16s 328ms/step - loss: 0.5694 - sparse_categorical_accuracy: 0.6965 - val_loss: 0.8757 - val_sparse_categorical_accuracy: 0.5787 - lr: 5.0000e-04
# Epoch 38/500
# 50/50 [==============================] - 17s 343ms/step - loss: 0.5658 - sparse_categorical_accuracy: 0.7073 - val_loss: 1.2757 - val_sparse_categorical_accuracy: 0.5736 - lr: 5.0000e-04
# Epoch 39/500
# 50/50 [==============================] - 16s 318ms/step - loss: 0.5624 - sparse_categorical_accuracy: 0.7035 - val_loss: 1.5031 - val_sparse_categorical_accuracy: 0.4746 - lr: 5.0000e-04
# Epoch 40/500
# 50/50 [==============================] - 16s 319ms/step - loss: 0.5631 - sparse_categorical_accuracy: 0.7041 - val_loss: 1.2131 - val_sparse_categorical_accuracy: 0.4391 - lr: 5.0000e-04
# Epoch 41/500
# 50/50 [==============================] - 16s 313ms/step - loss: 0.5577 - sparse_categorical_accuracy: 0.7105 - val_loss: 1.1009 - val_sparse_categorical_accuracy: 0.5660 - lr: 5.0000e-04
# Epoch 42/500
# 50/50 [==============================] - 16s 313ms/step - loss: 0.5519 - sparse_categorical_accuracy: 0.7130 - val_loss: 1.3128 - val_sparse_categorical_accuracy: 0.5812 - lr: 5.0000e-04
# Epoch 43/500
# 50/50 [==============================] - 16s 312ms/step - loss: 0.5547 - sparse_categorical_accuracy: 0.7124 - val_loss: 1.1804 - val_sparse_categorical_accuracy: 0.5660 - lr: 2.5000e-04
# Epoch 44/500
# 50/50 [==============================] - 16s 326ms/step - loss: 0.5558 - sparse_categorical_accuracy: 0.7137 - val_loss: 0.7568 - val_sparse_categorical_accuracy: 0.4619 - lr: 2.5000e-04
# Epoch 45/500
# 50/50 [==============================] - 16s 318ms/step - loss: 0.5533 - sparse_categorical_accuracy: 0.7219 - val_loss: 0.8344 - val_sparse_categorical_accuracy: 0.4340 - lr: 2.5000e-04
# Epoch 46/500
# 50/50 [==============================] - 16s 316ms/step - loss: 0.5487 - sparse_categorical_accuracy: 0.7206 - val_loss: 0.7970 - val_sparse_categorical_accuracy: 0.4975 - lr: 2.5000e-04
# Epoch 47/500
# 50/50 [==============================] - 16s 318ms/step - loss: 0.5438 - sparse_categorical_accuracy: 0.7289 - val_loss: 0.9624 - val_sparse_categorical_accuracy: 0.5508 - lr: 2.5000e-04
# Epoch 48/500
# 50/50 [==============================] - 16s 319ms/step - loss: 0.5490 - sparse_categorical_accuracy: 0.7175 - val_loss: 1.0171 - val_sparse_categorical_accuracy: 0.5812 - lr: 2.5000e-04
# Epoch 49/500
# 50/50 [==============================] - 16s 328ms/step - loss: 0.5390 - sparse_categorical_accuracy: 0.7308 - val_loss: 0.8885 - val_sparse_categorical_accuracy: 0.4949 - lr: 2.5000e-04
# Epoch 50/500
# 50/50 [==============================] - 16s 313ms/step - loss: 0.5475 - sparse_categorical_accuracy: 0.7270 - val_loss: 0.7907 - val_sparse_categorical_accuracy: 0.5711 - lr: 2.5000e-04
# Epoch 51/500
# 50/50 [==============================] - 16s 328ms/step - loss: 0.5406 - sparse_categorical_accuracy: 0.7270 - val_loss: 0.9267 - val_sparse_categorical_accuracy: 0.4619 - lr: 2.5000e-04
# Epoch 52/500
# 50/50 [==============================] - 16s 327ms/step - loss: 0.5387 - sparse_categorical_accuracy: 0.7263 - val_loss: 0.7415 - val_sparse_categorical_accuracy: 0.4822 - lr: 2.5000e-04
# Epoch 52: early stopping
