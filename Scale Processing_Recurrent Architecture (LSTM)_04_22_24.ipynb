# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Assumes scale images are on your Drive under "Images"

# !ls /content/drive/MyDrive/Images/*csv
# Out:
# /content/drive/MyDrive/Images/labels.csv
# /content/drive/MyDrive/Images/SalmonFishScalesCoordinates-V2.csv

# %%
import os.path
import numpy as np
import math
from matplotlib.image import imread
import matplotlib.pyplot as plt
import skimage.draw as drw

SCALE_WIDTH = 1500
SCALE_HEIGHT = 2000
IMAGE_HEIGHT = 1920
TRANSECT_LENGTH = 750

PATH=os.sep + os.path.join("content", "drive", "MyDrive", "Images")

def rgb2gray(rgb):
    return np.dot(rgb[...,:3], [0.2989, 0.5870, 0.1140])

def fill_boarder(gray_img, thickness, fill_value=255):
  gray_img[:thickness,:] = fill_value
  gray_img[-thickness:,:] = fill_value
  gray_img[:,:thickness] = fill_value
  gray_img[:,-thickness:] = fill_value

def scale_edge_detector(x,index, window_size, frequency_factor, orientation):
  if not (orientation == 'LR' or orientation == 'RL'):
    raise Exception("Edge detection orientation must be 'LR' or 'RL'.")

  if window_size % 2 != 1:
    raise Exception("Window size must be an odd number.")

  l_sum = np.sum(x[index - int(window_size / 2): index])
  r_sum = np.sum(x[index + 1: index + int(window_size / 2)])

  if orientation == 'LR':
    if r_sum > l_sum * frequency_factor:
      return True
    else:
      return False
  else:
    if r_sum * frequency_factor > l_sum:
      return True
    else:
      return False

def mask1d(gray_img, kernel_size, threshold=20):
  if kernel_size % 2 != 1:
    raise Exception("Kernel size must be an odd number.")


  mask = np.zeros(gray_img.shape, dtype=np.uint8)
  filter = np.ones(kernel_size) / kernel_size

  for y in range(gray_img.shape[0]):
    delta = np.convolve(gray_img[y,:], filter, mode='same') - gray_img[y,:]
    mask[y, (np.abs(delta) > threshold)] = 255.

  return mask

def mask(gray_img, kernel_size, threshold=20):
  if kernel_size % 2 != 1:
    raise Exception("Kernel size must be an odd number.")

  xd = mask1d(gray_img, 9, 20)
  yd = mask1d(np.transpose(gray_img), 9, 20).transpose()
  mask = xd /2 + yd / 2

  return mask

def denoise(gray_img, kernel_size, percent_activated_threshold=0.4):
  if kernel_size % 2 != 1:
    raise Exception("Kernel size must be an odd number.")

  activation_cutoff = percent_activated_threshold * kernel_size * kernel_size * 255
  denoised_img = gray_img.copy()

  for j in range(int(kernel_size / 2), gray_img.shape[0] - int(kernel_size / 2)):
    for k in range(int(kernel_size / 2), gray_img.shape[1] - int(kernel_size / 2)):
      if gray_img[j, k] > 120:
        if np.sum(gray_img[j:j+kernel_size,k:k+kernel_size]) < activation_cutoff:
          denoised_img[j, k] = 0

  return denoised_img

def detect_scale_contour(gray_img, padding=25):
  contour = []

  for j in range(padding, gray_img.shape[0] - padding):
    k = padding
    k_min = padding

    # Burn in period to make sure we are not detecting a scale on the edge
    while k < gray_img.shape[1] - padding and np.sum(gray_img[j, k-10:k+25]) > 30 * 255:
      k = k + 1

    while k < gray_img.shape[1] - padding:
      if gray_img[j, k] > 0 and scale_edge_detector(gray_img[j,:], k, 25, 5, 'LR'):
        contour.append((j, k))
        k_min = k
        k = gray_img.shape[1] - padding
      k = k + 1

    # Burn in period to make sure we are not detecting a scale on the edge
    while k > k_min and np.sum(gray_img[j, k-25:k+10]) > 30 * 255:
      k = k - 1

    while k > k_min:
      if gray_img[j, k] > 0 and scale_edge_detector(gray_img[j,:], k, 25, 5, 'RL'):
        contour.append((j, k))
        k = 0
      k = k - 1

  return contour

def dilate_contour(contour, thickness):

  dialated_contour = set()
  for (j, k) in contour:
    for l in range(j - thickness, j + thickness):
      for m in range(k - thickness, k + thickness):
        dialated_contour.add((l, m))

  return list(dialated_contour)

def draw_box(gray_img, top_left_point, bottom_right_point, color=255):
  j1, k1 = top_left_point
  j2, k2 = bottom_right_point

  gray_img[j1,k1:k2+1] = color
  gray_img[j2,k1:k2+1] = color
  gray_img[j1:j2+1,k1] = color
  gray_img[j1:j2+1,k2] = color

def draw_line(gray_img, mid_point, end_point, color=255):

  rr, cc = drw.line(*mid_point, *end_point)
  gray_img[rr, cc] = color

def draw_contour(size, contour, color=255):

  img = np.zeros(size, dtype=np.uint8)
  for (j, k) in contour:
    img[j, k] = color

  return img

def load_img_to_gray(file):
  img = imread(file)
  gray = rgb2gray(img)

  return gray

def show_image_and_contour(gray):

  plt.imshow(gray, cmap=plt.get_cmap('gray'))
  plt.show()

  masked_image = mask(gray, 9, 20)
  denoised_mask = denoise(masked_image, 101, .025)

  contour = detect_scale_contour(denoised_mask, 100)
  dilated_contour = dilate_contour(contour, 5)
  drawn_contour = draw_contour(denoised_mask.shape, dilated_contour)

  plt.imshow(np.abs(drawn_contour - 255), cmap=plt.get_cmap('gray'))
  plt.show()

def frame_image_w_mean(gray, j_m, k_m):
  mean_pixel_value = np.mean(gray)

  if j_m - SCALE_HEIGHT // 2 > 0:
    gray[0:j_m - SCALE_HEIGHT // 2,:] = mean_pixel_value
    gray[j_m + SCALE_HEIGHT // 2:,:] = mean_pixel_value

  if k_m - SCALE_WIDTH // 2 > 0:
    gray[:, 0:k_m - SCALE_WIDTH // 2] = mean_pixel_value
    gray[:,k_m + SCALE_WIDTH // 2:] = mean_pixel_value

  #return gray

def calculate_transect_endpoint(mid_point, offset, length):
  """
  Given an offset from a line extending direclty down from the
  mid-point, determine the coordinates of the other endpoint of
  a line that starts at the mid-point and extends in the direction
  of the offset of specified length

  :param mid_point: the coordinates of the mid-point in row-major format
  :param offset: offset angle in radians from 6 o'clock applied counter-clockwise
  :param length: describe about parameter p3
  :return: the coordinates of the endpoint in row-major format
  """
  j, k = mid_point

  return (j + int(length * math.cos(offset)),
          k + int(length * math.sin(offset)))

def calculate_transect_angle(mid_point, end_point):
  """
  Given two points, calculated the angle between a line that
  extends down from the mid-point, opens counter-clockwise
  to the line that is defined by the mid_point and end_point

  :param mid_point: the coordinates of the mid-point in row-major format
  :param end_point: the coordinates of the end-point of the transect
     in row-major format
  :return: angle in radians
  """

  offset = 0

  # if the transect angle is at pi/2 or 3 pi/2, the atan will be undefined
  if abs(mid_point[0] - end_point[0]) < 1e-5:
    if mid_point[0] < end_point[0]:
      offset = math.pi / 2
    else:
      offset = 3 * math.pi / 2

  else:
    offset = math.atan((mid_point[1] - end_point[1]) /
                       (mid_point[0] - end_point[0]))

    # if end point is above mid point, add pi to offset as it would have
    #  been caculated relative to line extending above mid point.
    if(end_point[0] < mid_point[0]):
      offset = offset + math.pi

    # if offset is negative, add to 2pi
    if(end_point[1] < mid_point[1]):
      offset = 2 * math.pi + offset

  return offset

def calculate_coordinates_of_transects(mid_point, transect_angle, offset_step_size, transect_count):
  """
  Determine the coordintates of points along transect lines at specified offsets
  from an initial trasect.

  :param mid_point: the coordinates of the mid-point in row-major format
  :param offset: transect angle in radians from 6 o'clock applied counter-clockwise
  :param offset_step_size: Offset in radians between transects
  :param transect_count: The number of transects to generate in addition to
    main transect
  :return: a list of lists containing the coordinates of points on transects
    extending out from the mid_point.  Indexing of transects alternates out
    from main transect.
  """
  transects_coordinates = []
  calculate_transect_endpoint(mid_point, transect_angle, TRANSECT_LENGTH)
  transects_coordinates.append(drw.line(*mid_point,
                                        *calculate_transect_endpoint(mid_point, transect_angle, TRANSECT_LENGTH))
                               )

  for offset in [o for i in range(1, int(transect_count / 2) + 1) for o in (i * offset_step_size, -i * offset_step_size)]:
    transects_coordinates.append(drw.line(*mid_point,
                                          *calculate_transect_endpoint(mid_point, transect_angle + offset, TRANSECT_LENGTH))
                                 )

  return transects_coordinates

def draw_transects(gray_img, transects_coordinates, color = 250):
  """
  Draws transects on a copy of grayscale image.

  :param gray_img: 2d array of a grayscale image
  :param trasects_coordinates: a list of lists containing the coordinates of points on transects
    extending out from the mid_point.  Indexing of transects alternates out
    from main transect.
  :param color: pixel value for drawn transect
  :return: 2d array representing grayscale image with transects applied
  """
  img_w_transects = np.copy(gray_img)
  j_max = gray_img.shape[0]
  k_max = gray_img.shape[1]

  for i, transect in enumerate(transects_coordinates):
    rr, cc = transect
    rr[rr >= j_max] = j_max - 1
    cc[cc >= k_max] = k_max - 1

    img_w_transects[rr, cc] = color

  return img_w_transects

def extract_transects_signals(gray_img, transects_coordinates):

  transect_signals = []
  for i, transect in enumerate(transects_coordinates):
    signal = []
    rr, cc = transect
    for j, k in zip(rr, cc):
      signal.append(gray_img[j, k])
    transect_signals.append(signal)

  return transect_signals

def convolve_transects_signals(transects_signals, kernel_size):

  filter = np.ones(kernel_size) / kernel_size
  convolved_signals = []

  for signal in transects_signals:
    convolved_signals.append(convolve_transects_signal(signal, kernel_size))

  return convolved_signals

def convolve_transects_signal(transects_signal, kernel_size):

  filter = np.ones(kernel_size) / kernel_size
  signal_length = max(len(transects_signal), kernel_size) - min(len(transects_signal), kernel_size) + 1
  offset = int((len(transects_signal) - signal_length) / 2)
  return(np.convolve(transects_signal, filter, mode='valid') - transects_signal[offset:-offset])


def plot_transect_signals(transects_signals, figure_path, figure_filename):
  n = len(transects)

  fig, axes = plt.subplots(2 * n)
  for i, signal in enumerate(transects_signals):
    axes[i].plot(signal)

  convolved_signals = convolve_transects_signals(transects_signals, 5)
  for i, signal in enumerate(convolved_signals):
    axes[i + n].plot(signal)

  fig.savefig(os.path.join(figure_path, figure_filename +".png"), format="png",
              bbox_inches="tight")

def plot_transect_signals_for_image(filepath, mid_point, transect_angle,
                                    offset_step_size, transect_count,
                                    figure_path):
  gray = load_img_to_gray(filepath)
  filename = os.path.splitext(os.path.basename(filepath))[0]

  transects = calculate_coordinates_of_transects(mid_point, transect_angle,
                                                 offset_step_size, transect_count)
  transects_signals = extract_transects_signals(gray, transects)

  plot_transect_signals(transects_signals, figure_path, filename)

# %%
import pandas as pd
from ast import literal_eval

scale_data = pd.read_csv('/content/drive/MyDrive/Images/SalmonFishScalesCoordinates-V2.csv', sep=",",
                          names=['filename', 'lt_center', 'br_center', 'end_point'],
                          dtype={'filename': 'string'},
                          converters={'lt_center': literal_eval,
                                      'br_center': literal_eval,
                                      'end_point': literal_eval},
                          header=0)
scale_data['filepath'] = scale_data.apply(lambda row: os.path.join(PATH, row['filename']) +  ".tif", axis=1)

# Switch from column-major to row major
scale_data['lt_center'] = scale_data.apply(lambda row: (row['lt_center'][1], row['lt_center'][0]) , axis = 1)
scale_data['br_center'] = scale_data.apply(lambda row: (row['br_center'][1], row['br_center'][0]) , axis = 1)
scale_data['end_point'] = scale_data.apply(lambda row: (row['end_point'][1], row['end_point'][0]) , axis = 1)

scale_data['mid_center'] = scale_data.apply(lambda row: (int((row['lt_center'][0] + row['br_center'][0]) / 2),
                                                         int((row['lt_center'][1] + row['br_center'][1]) / 2)) , axis=1)
scale_data['transect_angle'] = scale_data.apply(lambda row: calculate_transect_angle(row['mid_center'], row['end_point']), axis=1)

scale_data['id'] = scale_data.apply(lambda row: int(row['filename'].split('_')[0]), axis=1)

# Bring in labels
label_data = pd.read_csv('/content/drive/MyDrive/Images/labels.csv', sep=",",
                          names=['id', 'age', 'type', 'fold'],
                          dtype={'filename': 'int64', 'age': 'int32', 'type': 'int32', 'fold': 'int32'},
                          header=0)

# Fold in labels with scale data
scale_data = scale_data.merge(label_data, on='id', how='left', validate='many_to_one')

# Drop any rows with NaNs, recast ints
scale_data = scale_data.dropna().astype({'fold': int, 'type': int})

# %%
# Get transect signals
transects_signals = []

for index, row in scale_data.iterrows():
  #print(index, row['id'], row['filename'], row['fold'])

  gray = load_img_to_gray(row['filepath'])
  transects = calculate_coordinates_of_transects(row['mid_center'],
                                                 row['transect_angle'],
                                                 .1, 11)

  transects_signals.append([row['id'],
                           extract_transects_signals(gray, transects)],
                           )

transects_signals_df = pd.DataFrame(transects_signals, columns=['id', 'signals'])

# Merge with labels and explode
transects_signals_df = transects_signals_df.merge(label_data, on='id',
                                                  how='left',
                                                  validate='many_to_one')\
                                                  .explode('signals', ignore_index=True)\
                                                  .rename(columns={"signals": "signal"})
transects_signals_df['signal'] = transects_signals_df['signal'].apply(lambda x: np.array(x))

# Add convolved signals
transects_signals_df['convolved_signal'] = transects_signals_df.apply(lambda row: convolve_transects_signal(row['signal'], 5), axis=1)

# %% [markdown]
# ### Recurrent Architecture: LSTM

# %%
# Create a copy of transects_signals_df so that it doesn't have to be generated
#  each time
from numpy.fft import fft, ifft

def rolling_window(a, window, step):
    shape = a.shape[:-1] + ((a.shape[-1] - window + 1)//step, window)
    strides = (a.strides[0] * step,) + (a.strides[-1],)
    return np.lib.stride_tricks.as_strided(a, shape=shape, strides=strides)

#print(rolling_window(s[2], 25, 1).shape)

df = transects_signals_df.copy(deep=True)
df['signal'] = df['signal'].apply(lambda x: np.pad(x, (0, int(1.4 * TRANSECT_LENGTH) - x.size), 'constant', constant_values=(0, 0)))
df['signal'] = df['signal'].apply(lambda x: np.flip(x))
df['convolved_signal'] = df['convolved_signal'].apply(lambda x: np.pad(x, (0, int(1.4 * TRANSECT_LENGTH) - x.size), 'constant', constant_values=(0, 0)))
df['convolved_signal'] = df['convolved_signal'].apply(lambda x: np.flip(x))
df['convolved_freq'] = df['signal'].apply(lambda x: np.abs(fft(x))[0:75])

train = df[df['fold'] < 9][['convolved_freq', 'type']].to_numpy(copy=True)
val = df[df['fold'] >= 9][['convolved_freq', 'type']].to_numpy(copy=True)

x_train = np.stack(train[:,0])
x_max = np.max(x_train)
x_train = x_train / x_max

y_train = train[:,1].astype(int)

x_val = np.stack(val[:,0]) / x_max
y_val = val[:,1].astype(int)

# Reshape input data to include timestep dimension
x_train = x_train.reshape(x_train.shape[0], x_train.shape[1], 1)
x_val = x_val.reshape(x_val.shape[0], x_val.shape[1], 1)


import numpy as np
import matplotlib.pyplot as plt
import keras
from keras.layers import LSTM

# Define the model
model = keras.Sequential([
    LSTM(256, activation='relu', return_sequences=True),
    keras.layers.Dropout(0.5),
    LSTM(256, activation='relu'),
    keras.layers.Dropout(0.75),
    keras.layers.Dense(124, activation='relu'),
    keras.layers.Dropout(0.75),
    keras.layers.Dense(2, activation='softmax')
])

# Compile and train the model
model.compile(optimizer='rmsprop', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.fit(x=x_train, y=y_train, batch_size=256, epochs=350, validation_data=(x_val, y_val))

# Plotting
plt.plot(x_train[2,:,0])  # Assuming 0th feature
# Out:
# Epoch 1/350
# 8/8 [==============================] - 22s 2s/step - loss: 0.6903 - accuracy: 0.5470 - val_loss: 0.6830 - val_accuracy: 0.6000
# Epoch 2/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6879 - accuracy: 0.5546 - val_loss: 0.6787 - val_accuracy: 0.6000
# Epoch 3/350
# 8/8 [==============================] - 18s 2s/step - loss: 0.6890 - accuracy: 0.5592 - val_loss: 0.6786 - val_accuracy: 0.6000
# Epoch 4/350
# 8/8 [==============================] - 18s 2s/step - loss: 0.6861 - accuracy: 0.5582 - val_loss: 0.6776 - val_accuracy: 0.6000
# Epoch 5/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6863 - accuracy: 0.5592 - val_loss: 0.6768 - val_accuracy: 0.6000
# Epoch 6/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6866 - accuracy: 0.5587 - val_loss: 0.6776 - val_accuracy: 0.6000
# Epoch 7/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6875 - accuracy: 0.5587 - val_loss: 0.6777 - val_accuracy: 0.6000
# Epoch 8/350
# 8/8 [==============================] - 18s 2s/step - loss: 0.6863 - accuracy: 0.5587 - val_loss: 0.6772 - val_accuracy: 0.6000
# Epoch 9/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6865 - accuracy: 0.5587 - val_loss: 0.6764 - val_accuracy: 0.6000
# Epoch 10/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6876 - accuracy: 0.5587 - val_loss: 0.6766 - val_accuracy: 0.6000
# Epoch 11/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6868 - accuracy: 0.5587 - val_loss: 0.6768 - val_accuracy: 0.6000
# Epoch 12/350
# 8/8 [==============================] - 18s 2s/step - loss: 0.6864 - accuracy: 0.5587 - val_loss: 0.6772 - val_accuracy: 0.6000
# Epoch 13/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6877 - accuracy: 0.5587 - val_loss: 0.6772 - val_accuracy: 0.6000
# Epoch 14/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6873 - accuracy: 0.5587 - val_loss: 0.6770 - val_accuracy: 0.6000
# Epoch 15/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6870 - accuracy: 0.5582 - val_loss: 0.6772 - val_accuracy: 0.6000
# Epoch 16/350
# 8/8 [==============================] - 18s 2s/step - loss: 0.6867 - accuracy: 0.5587 - val_loss: 0.6776 - val_accuracy: 0.6000
# Epoch 17/350
# 8/8 [==============================] - 16s 2s/step - loss: 0.6862 - accuracy: 0.5587 - val_loss: 0.6772 - val_accuracy: 0.6000
# Epoch 18/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6868 - accuracy: 0.5587 - val_loss: 0.6773 - val_accuracy: 0.6000
# Epoch 19/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6879 - accuracy: 0.5587 - val_loss: 0.6776 - val_accuracy: 0.6000
# Epoch 20/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6877 - accuracy: 0.5587 - val_loss: 0.6775 - val_accuracy: 0.6000
# Epoch 21/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6864 - accuracy: 0.5587 - val_loss: 0.6767 - val_accuracy: 0.6000
# Epoch 22/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6858 - accuracy: 0.5587 - val_loss: 0.6765 - val_accuracy: 0.6000
# Epoch 23/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6863 - accuracy: 0.5587 - val_loss: 0.6770 - val_accuracy: 0.6000
# Epoch 24/350
# 8/8 [==============================] - 16s 2s/step - loss: 0.6859 - accuracy: 0.5587 - val_loss: 0.6770 - val_accuracy: 0.6000
# Epoch 25/350
# 8/8 [==============================] - 18s 2s/step - loss: 0.6873 - accuracy: 0.5587 - val_loss: 0.6773 - val_accuracy: 0.6000
# Epoch 26/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6878 - accuracy: 0.5587 - val_loss: 0.6774 - val_accuracy: 0.6000
# Epoch 27/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6862 - accuracy: 0.5587 - val_loss: 0.6770 - val_accuracy: 0.6000
# Epoch 28/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6864 - accuracy: 0.5587 - val_loss: 0.6772 - val_accuracy: 0.6000
# Epoch 29/350
# 8/8 [==============================] - 18s 2s/step - loss: 0.6854 - accuracy: 0.5587 - val_loss: 0.6766 - val_accuracy: 0.6000
# Epoch 30/350
# 8/8 [==============================] - 16s 2s/step - loss: 0.6863 - accuracy: 0.5587 - val_loss: 0.6773 - val_accuracy: 0.6000
# Epoch 31/350
# 8/8 [==============================] - 16s 2s/step - loss: 0.6880 - accuracy: 0.5587 - val_loss: 0.6779 - val_accuracy: 0.6000
# Epoch 32/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6857 - accuracy: 0.5587 - val_loss: 0.6774 - val_accuracy: 0.6000
# Epoch 33/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6867 - accuracy: 0.5587 - val_loss: 0.6770 - val_accuracy: 0.6000
# Epoch 34/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6865 - accuracy: 0.5587 - val_loss: 0.6771 - val_accuracy: 0.6000
# Epoch 35/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6874 - accuracy: 0.5587 - val_loss: 0.6774 - val_accuracy: 0.6000
# Epoch 36/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6868 - accuracy: 0.5587 - val_loss: 0.6773 - val_accuracy: 0.6000
# Epoch 37/350
# 8/8 [==============================] - 18s 2s/step - loss: 0.6874 - accuracy: 0.5587 - val_loss: 0.6772 - val_accuracy: 0.6000
# Epoch 38/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6871 - accuracy: 0.5592 - val_loss: 0.6773 - val_accuracy: 0.6000
# Epoch 39/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6872 - accuracy: 0.5587 - val_loss: 0.6771 - val_accuracy: 0.6000
# Epoch 40/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6873 - accuracy: 0.5587 - val_loss: 0.6772 - val_accuracy: 0.6000
# Epoch 41/350
# 8/8 [==============================] - 18s 2s/step - loss: 0.6872 - accuracy: 0.5587 - val_loss: 0.6773 - val_accuracy: 0.6000
# Epoch 42/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6873 - accuracy: 0.5587 - val_loss: 0.6774 - val_accuracy: 0.6000
# Epoch 43/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6877 - accuracy: 0.5587 - val_loss: 0.6772 - val_accuracy: 0.6000
# Epoch 44/350
# 8/8 [==============================] - 18s 2s/step - loss: 0.6873 - accuracy: 0.5587 - val_loss: 0.6772 - val_accuracy: 0.6000
# Epoch 45/350
# 8/8 [==============================] - 18s 2s/step - loss: 0.6868 - accuracy: 0.5587 - val_loss: 0.6773 - val_accuracy: 0.6000
# Epoch 46/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6856 - accuracy: 0.5587 - val_loss: 0.6768 - val_accuracy: 0.6000
# Epoch 47/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6877 - accuracy: 0.5587 - val_loss: 0.6769 - val_accuracy: 0.6000
# Epoch 48/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6870 - accuracy: 0.5587 - val_loss: 0.6770 - val_accuracy: 0.6000
# Epoch 49/350
# 8/8 [==============================] - 18s 2s/step - loss: 0.6859 - accuracy: 0.5587 - val_loss: 0.6768 - val_accuracy: 0.6000
# Epoch 50/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6873 - accuracy: 0.5587 - val_loss: 0.6773 - val_accuracy: 0.6000
# Epoch 51/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6874 - accuracy: 0.5587 - val_loss: 0.6770 - val_accuracy: 0.6000
# Epoch 52/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6869 - accuracy: 0.5587 - val_loss: 0.6772 - val_accuracy: 0.6000
# Epoch 53/350
# 8/8 [==============================] - 18s 2s/step - loss: 0.6868 - accuracy: 0.5587 - val_loss: 0.6771 - val_accuracy: 0.6000
# Epoch 54/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6866 - accuracy: 0.5587 - val_loss: 0.6771 - val_accuracy: 0.6000
# Epoch 55/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6859 - accuracy: 0.5587 - val_loss: 0.6766 - val_accuracy: 0.6000
# Epoch 56/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6868 - accuracy: 0.5587 - val_loss: 0.6770 - val_accuracy: 0.6000
# Epoch 57/350
# 8/8 [==============================] - 18s 2s/step - loss: 0.6875 - accuracy: 0.5587 - val_loss: 0.6773 - val_accuracy: 0.6000
# Epoch 58/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6872 - accuracy: 0.5587 - val_loss: 0.6773 - val_accuracy: 0.6000
# Epoch 59/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6866 - accuracy: 0.5587 - val_loss: 0.6774 - val_accuracy: 0.6000
# Epoch 60/350
# 8/8 [==============================] - 20s 3s/step - loss: 0.6869 - accuracy: 0.5587 - val_loss: 0.6777 - val_accuracy: 0.6000
# Epoch 61/350
# 8/8 [==============================] - 20s 2s/step - loss: 0.6870 - accuracy: 0.5587 - val_loss: 0.6774 - val_accuracy: 0.6000
# Epoch 62/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6862 - accuracy: 0.5587 - val_loss: 0.6770 - val_accuracy: 0.6000
# Epoch 63/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6857 - accuracy: 0.5587 - val_loss: 0.6767 - val_accuracy: 0.6000
# Epoch 64/350
# 8/8 [==============================] - 18s 2s/step - loss: 0.6865 - accuracy: 0.5587 - val_loss: 0.6768 - val_accuracy: 0.6000
# Epoch 65/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6868 - accuracy: 0.5587 - val_loss: 0.6769 - val_accuracy: 0.6000
# Epoch 66/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6868 - accuracy: 0.5587 - val_loss: 0.6767 - val_accuracy: 0.6000
# Epoch 67/350
# 8/8 [==============================] - 18s 2s/step - loss: 0.6864 - accuracy: 0.5587 - val_loss: 0.6770 - val_accuracy: 0.6000
# Epoch 68/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6855 - accuracy: 0.5587 - val_loss: 0.6769 - val_accuracy: 0.6000
# Epoch 69/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6869 - accuracy: 0.5587 - val_loss: 0.6771 - val_accuracy: 0.6000
# Epoch 70/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6868 - accuracy: 0.5587 - val_loss: 0.6770 - val_accuracy: 0.6000
# Epoch 71/350
# 8/8 [==============================] - 18s 2s/step - loss: 0.6864 - accuracy: 0.5587 - val_loss: 0.6773 - val_accuracy: 0.6000
# Epoch 72/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6868 - accuracy: 0.5587 - val_loss: 0.6770 - val_accuracy: 0.6000
# Epoch 73/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6864 - accuracy: 0.5587 - val_loss: 0.6769 - val_accuracy: 0.6000
# Epoch 74/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6866 - accuracy: 0.5587 - val_loss: 0.6769 - val_accuracy: 0.6000
# Epoch 75/350
# 8/8 [==============================] - 18s 2s/step - loss: 0.6862 - accuracy: 0.5587 - val_loss: 0.6767 - val_accuracy: 0.6000
# Epoch 76/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6877 - accuracy: 0.5587 - val_loss: 0.6769 - val_accuracy: 0.6000
# Epoch 77/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6864 - accuracy: 0.5587 - val_loss: 0.6766 - val_accuracy: 0.6000
# Epoch 78/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6871 - accuracy: 0.5587 - val_loss: 0.6766 - val_accuracy: 0.6000
# Epoch 79/350
# 8/8 [==============================] - 20s 2s/step - loss: 0.6861 - accuracy: 0.5587 - val_loss: 0.6766 - val_accuracy: 0.6000
# Epoch 80/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6863 - accuracy: 0.5587 - val_loss: 0.6766 - val_accuracy: 0.6000
# Epoch 81/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6871 - accuracy: 0.5587 - val_loss: 0.6768 - val_accuracy: 0.6000
# Epoch 82/350
# 8/8 [==============================] - 18s 2s/step - loss: 0.6867 - accuracy: 0.5587 - val_loss: 0.6771 - val_accuracy: 0.6000
# Epoch 83/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6870 - accuracy: 0.5587 - val_loss: 0.6773 - val_accuracy: 0.6000
# Epoch 84/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6865 - accuracy: 0.5587 - val_loss: 0.6771 - val_accuracy: 0.6000
# Epoch 85/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6863 - accuracy: 0.5587 - val_loss: 0.6769 - val_accuracy: 0.6000
# Epoch 86/350
# 8/8 [==============================] - 18s 2s/step - loss: 0.6871 - accuracy: 0.5587 - val_loss: 0.6771 - val_accuracy: 0.6000
# Epoch 87/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6867 - accuracy: 0.5587 - val_loss: 0.6771 - val_accuracy: 0.6000
# Epoch 88/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6862 - accuracy: 0.5587 - val_loss: 0.6771 - val_accuracy: 0.6000
# Epoch 89/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6864 - accuracy: 0.5587 - val_loss: 0.6771 - val_accuracy: 0.6000
# Epoch 90/350
# 8/8 [==============================] - 20s 2s/step - loss: 0.6866 - accuracy: 0.5587 - val_loss: 0.6770 - val_accuracy: 0.6000
# Epoch 91/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6861 - accuracy: 0.5587 - val_loss: 0.6770 - val_accuracy: 0.6000
# Epoch 92/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6862 - accuracy: 0.5587 - val_loss: 0.6770 - val_accuracy: 0.6000
# Epoch 93/350
# 8/8 [==============================] - 19s 2s/step - loss: 0.6859 - accuracy: 0.5587 - val_loss: 0.6767 - val_accuracy: 0.6000
# Epoch 94/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6871 - accuracy: 0.5587 - val_loss: 0.6768 - val_accuracy: 0.6000
# Epoch 95/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6866 - accuracy: 0.5587 - val_loss: 0.6768 - val_accuracy: 0.6000
# Epoch 96/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6867 - accuracy: 0.5587 - val_loss: 0.6769 - val_accuracy: 0.6000
# Epoch 97/350
# 8/8 [==============================] - 18s 2s/step - loss: 0.6860 - accuracy: 0.5587 - val_loss: 0.6768 - val_accuracy: 0.6000
# Epoch 98/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6860 - accuracy: 0.5587 - val_loss: 0.6768 - val_accuracy: 0.6000
# Epoch 99/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6861 - accuracy: 0.5587 - val_loss: 0.6769 - val_accuracy: 0.6000
# Epoch 100/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6864 - accuracy: 0.5587 - val_loss: 0.6770 - val_accuracy: 0.6000
# Epoch 101/350
# 8/8 [==============================] - 18s 2s/step - loss: 0.6863 - accuracy: 0.5587 - val_loss: 0.6769 - val_accuracy: 0.6000
# Epoch 102/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6870 - accuracy: 0.5587 - val_loss: 0.6772 - val_accuracy: 0.6000
# Epoch 103/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6873 - accuracy: 0.5587 - val_loss: 0.6775 - val_accuracy: 0.6000
# Epoch 104/350
# 8/8 [==============================] - 18s 2s/step - loss: 0.6867 - accuracy: 0.5587 - val_loss: 0.6773 - val_accuracy: 0.6000
# Epoch 105/350
# 8/8 [==============================] - 18s 2s/step - loss: 0.6869 - accuracy: 0.5587 - val_loss: 0.6773 - val_accuracy: 0.6000
# Epoch 106/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6867 - accuracy: 0.5587 - val_loss: 0.6772 - val_accuracy: 0.6000
# Epoch 107/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6862 - accuracy: 0.5587 - val_loss: 0.6771 - val_accuracy: 0.6000
# Epoch 108/350
# 8/8 [==============================] - 18s 2s/step - loss: 0.6867 - accuracy: 0.5587 - val_loss: 0.6770 - val_accuracy: 0.6000
# Epoch 109/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6867 - accuracy: 0.5587 - val_loss: 0.6768 - val_accuracy: 0.6000
# Epoch 110/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6862 - accuracy: 0.5587 - val_loss: 0.6768 - val_accuracy: 0.6000
# Epoch 111/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6872 - accuracy: 0.5587 - val_loss: 0.6767 - val_accuracy: 0.6000
# Epoch 112/350
# 8/8 [==============================] - 18s 2s/step - loss: 0.6865 - accuracy: 0.5587 - val_loss: 0.6766 - val_accuracy: 0.6000
# Epoch 113/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6861 - accuracy: 0.5587 - val_loss: 0.6765 - val_accuracy: 0.6000
# Epoch 114/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6861 - accuracy: 0.5587 - val_loss: 0.6762 - val_accuracy: 0.6000
# Epoch 115/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6858 - accuracy: 0.5587 - val_loss: 0.6761 - val_accuracy: 0.6000
# Epoch 116/350
# 8/8 [==============================] - 18s 2s/step - loss: 0.6864 - accuracy: 0.5587 - val_loss: 0.6762 - val_accuracy: 0.6000
# Epoch 117/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6866 - accuracy: 0.5587 - val_loss: 0.6763 - val_accuracy: 0.6000
# Epoch 118/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6868 - accuracy: 0.5587 - val_loss: 0.6767 - val_accuracy: 0.6000
# Epoch 119/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6867 - accuracy: 0.5587 - val_loss: 0.6769 - val_accuracy: 0.6000
# Epoch 120/350
# 8/8 [==============================] - 18s 2s/step - loss: 0.6860 - accuracy: 0.5587 - val_loss: 0.6766 - val_accuracy: 0.6000
# Epoch 121/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6867 - accuracy: 0.5587 - val_loss: 0.6768 - val_accuracy: 0.6000
# Epoch 122/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6869 - accuracy: 0.5587 - val_loss: 0.6768 - val_accuracy: 0.6000
# Epoch 123/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6863 - accuracy: 0.5587 - val_loss: 0.6765 - val_accuracy: 0.6000
# Epoch 124/350
# 8/8 [==============================] - 19s 2s/step - loss: 0.6865 - accuracy: 0.5587 - val_loss: 0.6764 - val_accuracy: 0.6000
# Epoch 125/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6867 - accuracy: 0.5587 - val_loss: 0.6766 - val_accuracy: 0.6000
# Epoch 126/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6873 - accuracy: 0.5587 - val_loss: 0.6770 - val_accuracy: 0.6000
# Epoch 127/350
# 8/8 [==============================] - 18s 2s/step - loss: 0.6867 - accuracy: 0.5587 - val_loss: 0.6771 - val_accuracy: 0.6000
# Epoch 128/350
# 8/8 [==============================] - 18s 2s/step - loss: 0.6862 - accuracy: 0.5587 - val_loss: 0.6768 - val_accuracy: 0.6000
# Epoch 129/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6864 - accuracy: 0.5587 - val_loss: 0.6767 - val_accuracy: 0.6000
# Epoch 130/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6872 - accuracy: 0.5587 - val_loss: 0.6768 - val_accuracy: 0.6000
# Epoch 131/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6870 - accuracy: 0.5587 - val_loss: 0.6768 - val_accuracy: 0.6000
# Epoch 132/350
# 8/8 [==============================] - 18s 2s/step - loss: 0.6866 - accuracy: 0.5587 - val_loss: 0.6769 - val_accuracy: 0.6000
# Epoch 133/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6866 - accuracy: 0.5587 - val_loss: 0.6766 - val_accuracy: 0.6000
# Epoch 134/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6865 - accuracy: 0.5587 - val_loss: 0.6768 - val_accuracy: 0.6000
# Epoch 135/350
# 8/8 [==============================] - 18s 2s/step - loss: 0.6864 - accuracy: 0.5587 - val_loss: 0.6766 - val_accuracy: 0.6000
# Epoch 136/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6864 - accuracy: 0.5587 - val_loss: 0.6766 - val_accuracy: 0.6000
# Epoch 137/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6862 - accuracy: 0.5587 - val_loss: 0.6765 - val_accuracy: 0.6000
# Epoch 138/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6864 - accuracy: 0.5587 - val_loss: 0.6765 - val_accuracy: 0.6000
# Epoch 139/350
# 8/8 [==============================] - 19s 2s/step - loss: 0.6862 - accuracy: 0.5587 - val_loss: 0.6765 - val_accuracy: 0.6000
# Epoch 140/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6860 - accuracy: 0.5587 - val_loss: 0.6763 - val_accuracy: 0.6000
# Epoch 141/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6863 - accuracy: 0.5587 - val_loss: 0.6762 - val_accuracy: 0.6000
# Epoch 142/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6867 - accuracy: 0.5587 - val_loss: 0.6765 - val_accuracy: 0.6000
# Epoch 143/350
# 8/8 [==============================] - 18s 2s/step - loss: 0.6861 - accuracy: 0.5587 - val_loss: 0.6764 - val_accuracy: 0.6000
# Epoch 144/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6865 - accuracy: 0.5587 - val_loss: 0.6763 - val_accuracy: 0.6000
# Epoch 145/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6858 - accuracy: 0.5587 - val_loss: 0.6763 - val_accuracy: 0.6000
# Epoch 146/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6862 - accuracy: 0.5587 - val_loss: 0.6763 - val_accuracy: 0.6000
# Epoch 147/350
# 8/8 [==============================] - 18s 2s/step - loss: 0.6872 - accuracy: 0.5587 - val_loss: 0.6765 - val_accuracy: 0.6000
# Epoch 148/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6862 - accuracy: 0.5587 - val_loss: 0.6767 - val_accuracy: 0.6000
# Epoch 149/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6865 - accuracy: 0.5587 - val_loss: 0.6767 - val_accuracy: 0.6000
# Epoch 150/350
# 8/8 [==============================] - 18s 2s/step - loss: 0.6864 - accuracy: 0.5587 - val_loss: 0.6768 - val_accuracy: 0.6000
# Epoch 151/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6866 - accuracy: 0.5587 - val_loss: 0.6768 - val_accuracy: 0.6000
# Epoch 152/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6865 - accuracy: 0.5587 - val_loss: 0.6768 - val_accuracy: 0.6000
# Epoch 153/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6861 - accuracy: 0.5587 - val_loss: 0.6766 - val_accuracy: 0.6000
# Epoch 154/350
# 8/8 [==============================] - 18s 2s/step - loss: 0.6864 - accuracy: 0.5587 - val_loss: 0.6768 - val_accuracy: 0.6000
# Epoch 155/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6863 - accuracy: 0.5587 - val_loss: 0.6768 - val_accuracy: 0.6000
# Epoch 156/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6863 - accuracy: 0.5587 - val_loss: 0.6768 - val_accuracy: 0.6000
# Epoch 157/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6864 - accuracy: 0.5587 - val_loss: 0.6768 - val_accuracy: 0.6000
# Epoch 158/350
# 8/8 [==============================] - 18s 2s/step - loss: 0.6862 - accuracy: 0.5587 - val_loss: 0.6767 - val_accuracy: 0.6000
# Epoch 159/350
# 8/8 [==============================] - 18s 2s/step - loss: 0.6864 - accuracy: 0.5587 - val_loss: 0.6766 - val_accuracy: 0.6000
# Epoch 160/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6863 - accuracy: 0.5587 - val_loss: 0.6767 - val_accuracy: 0.6000
# Epoch 161/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6864 - accuracy: 0.5587 - val_loss: 0.6768 - val_accuracy: 0.6000
# Epoch 162/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6865 - accuracy: 0.5587 - val_loss: 0.6769 - val_accuracy: 0.6000
# Epoch 163/350
# 8/8 [==============================] - 18s 2s/step - loss: 0.6863 - accuracy: 0.5587 - val_loss: 0.6768 - val_accuracy: 0.6000
# Epoch 164/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6871 - accuracy: 0.5587 - val_loss: 0.6770 - val_accuracy: 0.6000
# Epoch 165/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6863 - accuracy: 0.5587 - val_loss: 0.6770 - val_accuracy: 0.6000
# Epoch 166/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6865 - accuracy: 0.5587 - val_loss: 0.6770 - val_accuracy: 0.6000
# Epoch 167/350
# 8/8 [==============================] - 18s 2s/step - loss: 0.6860 - accuracy: 0.5587 - val_loss: 0.6768 - val_accuracy: 0.6000
# Epoch 168/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6865 - accuracy: 0.5587 - val_loss: 0.6768 - val_accuracy: 0.6000
# Epoch 169/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6868 - accuracy: 0.5587 - val_loss: 0.6768 - val_accuracy: 0.6000
# Epoch 170/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6863 - accuracy: 0.5587 - val_loss: 0.6769 - val_accuracy: 0.6000
# Epoch 171/350
# 8/8 [==============================] - 18s 2s/step - loss: 0.6862 - accuracy: 0.5587 - val_loss: 0.6769 - val_accuracy: 0.6000
# Epoch 172/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6865 - accuracy: 0.5587 - val_loss: 0.6768 - val_accuracy: 0.6000
# Epoch 173/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6861 - accuracy: 0.5587 - val_loss: 0.6769 - val_accuracy: 0.6000
# Epoch 174/350
# 8/8 [==============================] - 19s 2s/step - loss: 0.6866 - accuracy: 0.5587 - val_loss: 0.6767 - val_accuracy: 0.6000
# Epoch 175/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6864 - accuracy: 0.5587 - val_loss: 0.6766 - val_accuracy: 0.6000
# Epoch 176/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6865 - accuracy: 0.5587 - val_loss: 0.6765 - val_accuracy: 0.6000
# Epoch 177/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6860 - accuracy: 0.5587 - val_loss: 0.6763 - val_accuracy: 0.6000
# Epoch 178/350
# 8/8 [==============================] - 19s 2s/step - loss: 0.6869 - accuracy: 0.5587 - val_loss: 0.6765 - val_accuracy: 0.6000
# Epoch 179/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6860 - accuracy: 0.5587 - val_loss: 0.6765 - val_accuracy: 0.6000
# Epoch 180/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6866 - accuracy: 0.5587 - val_loss: 0.6766 - val_accuracy: 0.6000
# Epoch 181/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6857 - accuracy: 0.5587 - val_loss: 0.6766 - val_accuracy: 0.6000
# Epoch 182/350
# 8/8 [==============================] - 18s 2s/step - loss: 0.6866 - accuracy: 0.5587 - val_loss: 0.6765 - val_accuracy: 0.6000
# Epoch 183/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6864 - accuracy: 0.5587 - val_loss: 0.6765 - val_accuracy: 0.6000
# Epoch 184/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6870 - accuracy: 0.5587 - val_loss: 0.6767 - val_accuracy: 0.6000
# Epoch 185/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6860 - accuracy: 0.5587 - val_loss: 0.6768 - val_accuracy: 0.6000
# Epoch 186/350
# 8/8 [==============================] - 19s 2s/step - loss: 0.6866 - accuracy: 0.5587 - val_loss: 0.6769 - val_accuracy: 0.6000
# Epoch 187/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6865 - accuracy: 0.5587 - val_loss: 0.6768 - val_accuracy: 0.6000
# Epoch 188/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6862 - accuracy: 0.5587 - val_loss: 0.6767 - val_accuracy: 0.6000
# Epoch 189/350
# 8/8 [==============================] - 18s 2s/step - loss: 0.6862 - accuracy: 0.5587 - val_loss: 0.6768 - val_accuracy: 0.6000
# Epoch 190/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6866 - accuracy: 0.5587 - val_loss: 0.6769 - val_accuracy: 0.6000
# Epoch 191/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6869 - accuracy: 0.5587 - val_loss: 0.6770 - val_accuracy: 0.6000
# Epoch 192/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6866 - accuracy: 0.5587 - val_loss: 0.6768 - val_accuracy: 0.6000
# Epoch 193/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6864 - accuracy: 0.5587 - val_loss: 0.6768 - val_accuracy: 0.6000
# Epoch 194/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6860 - accuracy: 0.5587 - val_loss: 0.6766 - val_accuracy: 0.6000
# Epoch 195/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6856 - accuracy: 0.5587 - val_loss: 0.6764 - val_accuracy: 0.6000
# Epoch 196/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6863 - accuracy: 0.5587 - val_loss: 0.6764 - val_accuracy: 0.6000
# Epoch 197/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6866 - accuracy: 0.5587 - val_loss: 0.6764 - val_accuracy: 0.6000
# Epoch 198/350
# 8/8 [==============================] - 18s 2s/step - loss: 0.6863 - accuracy: 0.5587 - val_loss: 0.6764 - val_accuracy: 0.6000
# Epoch 199/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6860 - accuracy: 0.5587 - val_loss: 0.6764 - val_accuracy: 0.6000
# Epoch 200/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6863 - accuracy: 0.5587 - val_loss: 0.6765 - val_accuracy: 0.6000
# Epoch 201/350
# 8/8 [==============================] - 18s 2s/step - loss: 0.6865 - accuracy: 0.5587 - val_loss: 0.6765 - val_accuracy: 0.6000
# Epoch 202/350
# 8/8 [==============================] - 18s 2s/step - loss: 0.6860 - accuracy: 0.5587 - val_loss: 0.6763 - val_accuracy: 0.6000
# Epoch 203/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6863 - accuracy: 0.5587 - val_loss: 0.6764 - val_accuracy: 0.6000
# Epoch 204/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6868 - accuracy: 0.5587 - val_loss: 0.6767 - val_accuracy: 0.6000
# Epoch 205/350
# 8/8 [==============================] - 19s 2s/step - loss: 0.6871 - accuracy: 0.5587 - val_loss: 0.6769 - val_accuracy: 0.6000
# Epoch 206/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6861 - accuracy: 0.5587 - val_loss: 0.6768 - val_accuracy: 0.6000
# Epoch 207/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6863 - accuracy: 0.5587 - val_loss: 0.6770 - val_accuracy: 0.6000
# Epoch 208/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6865 - accuracy: 0.5587 - val_loss: 0.6771 - val_accuracy: 0.6000
# Epoch 209/350
# 8/8 [==============================] - 19s 2s/step - loss: 0.6862 - accuracy: 0.5587 - val_loss: 0.6769 - val_accuracy: 0.6000
# Epoch 210/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6862 - accuracy: 0.5587 - val_loss: 0.6768 - val_accuracy: 0.6000
# Epoch 211/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6863 - accuracy: 0.5587 - val_loss: 0.6768 - val_accuracy: 0.6000
# Epoch 212/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6862 - accuracy: 0.5587 - val_loss: 0.6767 - val_accuracy: 0.6000
# Epoch 213/350
# 8/8 [==============================] - 18s 2s/step - loss: 0.6864 - accuracy: 0.5587 - val_loss: 0.6767 - val_accuracy: 0.6000
# Epoch 214/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6868 - accuracy: 0.5587 - val_loss: 0.6769 - val_accuracy: 0.6000
# Epoch 215/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6860 - accuracy: 0.5587 - val_loss: 0.6768 - val_accuracy: 0.6000
# Epoch 216/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6860 - accuracy: 0.5587 - val_loss: 0.6767 - val_accuracy: 0.6000
# Epoch 217/350
# 8/8 [==============================] - 18s 2s/step - loss: 0.6858 - accuracy: 0.5587 - val_loss: 0.6765 - val_accuracy: 0.6000
# Epoch 218/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6860 - accuracy: 0.5587 - val_loss: 0.6766 - val_accuracy: 0.6000
# Epoch 219/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6868 - accuracy: 0.5587 - val_loss: 0.6767 - val_accuracy: 0.6000
# Epoch 220/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6870 - accuracy: 0.5587 - val_loss: 0.6770 - val_accuracy: 0.6000
# Epoch 221/350
# 8/8 [==============================] - 18s 2s/step - loss: 0.6864 - accuracy: 0.5587 - val_loss: 0.6771 - val_accuracy: 0.6000
# Epoch 222/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6864 - accuracy: 0.5587 - val_loss: 0.6769 - val_accuracy: 0.6000
# Epoch 223/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6857 - accuracy: 0.5587 - val_loss: 0.6766 - val_accuracy: 0.6000
# Epoch 224/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6863 - accuracy: 0.5587 - val_loss: 0.6766 - val_accuracy: 0.6000
# Epoch 225/350
# 8/8 [==============================] - 18s 2s/step - loss: 0.6861 - accuracy: 0.5587 - val_loss: 0.6765 - val_accuracy: 0.6000
# Epoch 226/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6870 - accuracy: 0.5587 - val_loss: 0.6767 - val_accuracy: 0.6000
# Epoch 227/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6865 - accuracy: 0.5587 - val_loss: 0.6766 - val_accuracy: 0.6000
# Epoch 228/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6864 - accuracy: 0.5587 - val_loss: 0.6765 - val_accuracy: 0.6000
# Epoch 229/350
# 8/8 [==============================] - 18s 2s/step - loss: 0.6863 - accuracy: 0.5587 - val_loss: 0.6766 - val_accuracy: 0.6000
# Epoch 230/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6864 - accuracy: 0.5587 - val_loss: 0.6767 - val_accuracy: 0.6000
# Epoch 231/350
# 8/8 [==============================] - 17s 2s/step - loss: 0.6859 - accuracy: 0.5587 - val_loss: 0.6766 - val_accuracy: 0.6000
# Epoch 232/350
# 2/8 [======>.......................] - ETA: 11s - loss: 0.6831 - accuracy: 0.5742
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-0cd452c041dc> in <cell line: 54>()
#      52 # Compile and train the model
#      53 model.compile(optimizer='rmsprop', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
# ---> 54 model.fit(x=x_train, y=y_train, batch_size=256, epochs=350, validation_data=(x_val, y_val))
#      55
#      56 # Plotting
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1805                         ):
#    1806                             callbacks.on_train_batch_begin(step)
# -> 1807                             tmp_logs = self.train_function(iterator)
#    1808                             if data_handler.should_sync:
#    1809                                 context.async_wait()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     830
#     831       with OptionalXlaContext(self._jit_compile):
# --> 832         result = self._call(*args, **kwds)
#     833
#     834       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     866       # In this case we have created variables on the first call, so we run the
#     867       # defunned version which is guaranteed to never create variables.
# --> 868       return tracing_compilation.call_function(
#     869           args, kwds, self._no_variable_creation_config
#     870       )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in call_function(args, kwargs, tracing_options)
#     137   bound_args = function.function_type.bind(*args, **kwargs)
#     138   flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139   return function._call_flat(  # pylint: disable=protected-access
#     140       flat_inputs, captured_inputs=function.captured_inputs
#     141   )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py in _call_flat(self, tensor_inputs, captured_inputs)
#    1321         and executing_eagerly):
#    1322       # No tape is watching; skip to running the function.
# -> 1323       return self._inference_function.call_preflattened(args)
#    1324     forward_backward = self._select_forward_and_backward_functions(
#    1325         args,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_preflattened(self, args)
#     214   def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215     """Calls with flattened tensor inputs and returns the structured output."""
# --> 216     flat_outputs = self.call_flat(*args)
#     217     return self.function_type.pack_output(flat_outputs)
#     218
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_flat(self, *args)
#     249         with record.stop_recording():
#     250           if self._bound_context.executing_eagerly():
# --> 251             outputs = self._bound_context.call_function(
#     252                 self.name,
#     253                 list(args),
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/context.py in call_function(self, name, tensor_inputs, num_outputs)
#    1484     cancellation_context = cancellation.context()
#    1485     if cancellation_context is None:
# -> 1486       outputs = execute.execute(
#    1487           name.decode("utf-8"),
#    1488           num_outputs=num_outputs,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51   try:
#      52     ctx.ensure_initialized()
# ---> 53     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                         inputs, attrs, num_outputs)
#      55   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:
