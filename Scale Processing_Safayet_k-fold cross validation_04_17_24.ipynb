# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Assumes scale images are on your Drive under "Images"

# !ls /content/drive/MyDrive/Images/*csv
# Out:
# /content/drive/MyDrive/Images/labels.csv
# /content/drive/MyDrive/Images/SalmonFishScalesCoordinates-V2.csv

# %%
import os.path
import numpy as np
import math
from matplotlib.image import imread
import matplotlib.pyplot as plt
import skimage.draw as drw

SCALE_WIDTH = 1500
SCALE_HEIGHT = 2000
IMAGE_HEIGHT = 1920
TRANSECT_LENGTH = 750
NUM_FOLDS = 10

PATH=os.sep + os.path.join("content", "drive", "MyDrive", "Images")

def rgb2gray(rgb):
    return np.dot(rgb[...,:3], [0.2989, 0.5870, 0.1140])

def fill_boarder(gray_img, thickness, fill_value=255):
  gray_img[:thickness,:] = fill_value
  gray_img[-thickness:,:] = fill_value
  gray_img[:,:thickness] = fill_value
  gray_img[:,-thickness:] = fill_value

def scale_edge_detector(x,index, window_size, frequency_factor, orientation):
  if not (orientation == 'LR' or orientation == 'RL'):
    raise Exception("Edge detection orientation must be 'LR' or 'RL'.")

  if window_size % 2 != 1:
    raise Exception("Window size must be an odd number.")

  l_sum = np.sum(x[index - int(window_size / 2): index])
  r_sum = np.sum(x[index + 1: index + int(window_size / 2)])

  if orientation == 'LR':
    if r_sum > l_sum * frequency_factor:
      return True
    else:
      return False
  else:
    if r_sum * frequency_factor > l_sum:
      return True
    else:
      return False

def mask1d(gray_img, kernel_size, threshold=20):
  if kernel_size % 2 != 1:
    raise Exception("Kernel size must be an odd number.")


  mask = np.zeros(gray_img.shape, dtype=np.uint8)
  filter = np.ones(kernel_size) / kernel_size

  for y in range(gray_img.shape[0]):
    delta = np.convolve(gray_img[y,:], filter, mode='same') - gray_img[y,:]
    mask[y, (np.abs(delta) > threshold)] = 255.

  return mask

def mask(gray_img, kernel_size, threshold=20):
  if kernel_size % 2 != 1:
    raise Exception("Kernel size must be an odd number.")

  xd = mask1d(gray_img, 9, 20)
  yd = mask1d(np.transpose(gray_img), 9, 20).transpose()
  mask = xd /2 + yd / 2

  return mask

def denoise(gray_img, kernel_size, percent_activated_threshold=0.4):
  if kernel_size % 2 != 1:
    raise Exception("Kernel size must be an odd number.")

  activation_cutoff = percent_activated_threshold * kernel_size * kernel_size * 255
  denoised_img = gray_img.copy()

  for j in range(int(kernel_size / 2), gray_img.shape[0] - int(kernel_size / 2)):
    for k in range(int(kernel_size / 2), gray_img.shape[1] - int(kernel_size / 2)):
      if gray_img[j, k] > 120:
        if np.sum(gray_img[j:j+kernel_size,k:k+kernel_size]) < activation_cutoff:
          denoised_img[j, k] = 0

  return denoised_img

def detect_scale_contour(gray_img, padding=25):
  contour = []

  for j in range(padding, gray_img.shape[0] - padding):
    k = padding
    k_min = padding

    # Burn in period to make sure we are not detecting a scale on the edge
    while k < gray_img.shape[1] - padding and np.sum(gray_img[j, k-10:k+25]) > 30 * 255:
      k = k + 1

    while k < gray_img.shape[1] - padding:
      if gray_img[j, k] > 0 and scale_edge_detector(gray_img[j,:], k, 25, 5, 'LR'):
        contour.append((j, k))
        k_min = k
        k = gray_img.shape[1] - padding
      k = k + 1

    # Burn in period to make sure we are not detecting a scale on the edge
    while k > k_min and np.sum(gray_img[j, k-25:k+10]) > 30 * 255:
      k = k - 1

    while k > k_min:
      if gray_img[j, k] > 0 and scale_edge_detector(gray_img[j,:], k, 25, 5, 'RL'):
        contour.append((j, k))
        k = 0
      k = k - 1

  return contour

def dilate_contour(contour, thickness):

  dialated_contour = set()
  for (j, k) in contour:
    for l in range(j - thickness, j + thickness):
      for m in range(k - thickness, k + thickness):
        dialated_contour.add((l, m))

  return list(dialated_contour)

def draw_box(gray_img, top_left_point, bottom_right_point, color=255):
  j1, k1 = top_left_point
  j2, k2 = bottom_right_point

  gray_img[j1,k1:k2+1] = color
  gray_img[j2,k1:k2+1] = color
  gray_img[j1:j2+1,k1] = color
  gray_img[j1:j2+1,k2] = color

def draw_line(gray_img, mid_point, end_point, color=255):

  rr, cc = drw.line(*mid_point, *end_point)
  gray_img[rr, cc] = color

def draw_contour(size, contour, color=255):

  img = np.zeros(size, dtype=np.uint8)
  for (j, k) in contour:
    img[j, k] = color

  return img

def load_img_to_gray(file):
  img = imread(file)
  gray = rgb2gray(img)

  return gray

def show_image_and_contour(gray):

  plt.imshow(gray, cmap=plt.get_cmap('gray'))
  plt.show()

  masked_image = mask(gray, 9, 20)
  denoised_mask = denoise(masked_image, 101, .025)

  contour = detect_scale_contour(denoised_mask, 100)
  dilated_contour = dilate_contour(contour, 5)
  drawn_contour = draw_contour(denoised_mask.shape, dilated_contour)

  plt.imshow(np.abs(drawn_contour - 255), cmap=plt.get_cmap('gray'))
  plt.show()

def frame_image_w_mean(gray, j_m, k_m):
  mean_pixel_value = np.mean(gray)

  if j_m - SCALE_HEIGHT // 2 > 0:
    gray[0:j_m - SCALE_HEIGHT // 2,:] = mean_pixel_value
    gray[j_m + SCALE_HEIGHT // 2:,:] = mean_pixel_value

  if k_m - SCALE_WIDTH // 2 > 0:
    gray[:, 0:k_m - SCALE_WIDTH // 2] = mean_pixel_value
    gray[:,k_m + SCALE_WIDTH // 2:] = mean_pixel_value

  #return gray

def calculate_transect_endpoint(mid_point, offset, length):
  """
  Given an offset from a line extending direclty down from the
  mid-point, determine the coordinates of the other endpoint of
  a line that starts at the mid-point and extends in the direction
  of the offset of specified length

  :param mid_point: the coordinates of the mid-point in row-major format
  :param offset: offset angle in radians from 6 o'clock applied counter-clockwise
  :param length: describe about parameter p3
  :return: the coordinates of the endpoint in row-major format
  """
  j, k = mid_point

  return (j + int(length * math.cos(offset)),
          k + int(length * math.sin(offset)))

def calculate_transect_angle(mid_point, end_point):
  """
  Given two points, calculated the angle between a line that
  extends down from the mid-point, opens counter-clockwise
  to the line that is defined by the mid_point and end_point

  :param mid_point: the coordinates of the mid-point in row-major format
  :param end_point: the coordinates of the end-point of the transect
     in row-major format
  :return: angle in radians
  """

  offset = 0

  # if the transect angle is at pi/2 or 3 pi/2, the atan will be undefined
  if abs(mid_point[0] - end_point[0]) < 1e-5:
    if mid_point[0] < end_point[0]:
      offset = math.pi / 2
    else:
      offset = 3 * math.pi / 2

  else:
    offset = math.atan((mid_point[1] - end_point[1]) /
                       (mid_point[0] - end_point[0]))

    # if end point is above mid point, add pi to offset as it would have
    #  been caculated relative to line extending above mid point.
    if(end_point[0] < mid_point[0]):
      offset = offset + math.pi

    # if offset is negative, add to 2pi
    if(end_point[1] < mid_point[1]):
      offset = 2 * math.pi + offset

  return offset

def calculate_coordinates_of_transects(mid_point, transect_angle, offset_step_size, transect_count):
  """
  Determine the coordintates of points along transect lines at specified offsets
  from an initial trasect.

  :param mid_point: the coordinates of the mid-point in row-major format
  :param offset: transect angle in radians from 6 o'clock applied counter-clockwise
  :param offset_step_size: Offset in radians between transects
  :param transect_count: The number of transects to generate in addition to
    main transect
  :return: a list of lists containing the coordinates of points on transects
    extending out from the mid_point.  Indexing of transects alternates out
    from main transect.
  """
  transects_coordinates = []
  calculate_transect_endpoint(mid_point, transect_angle, TRANSECT_LENGTH)
  transects_coordinates.append(drw.line(*mid_point,
                                        *calculate_transect_endpoint(mid_point, transect_angle, TRANSECT_LENGTH))
                               )

  for offset in [o for i in range(1, int(transect_count / 2) + 1) for o in (i * offset_step_size, -i * offset_step_size)]:
    transects_coordinates.append(drw.line(*mid_point,
                                          *calculate_transect_endpoint(mid_point, transect_angle + offset, TRANSECT_LENGTH))
                                 )

  return transects_coordinates

def draw_transects(gray_img, transects_coordinates, color = 250):
  """
  Draws transects on a copy of grayscale image.

  :param gray_img: 2d array of a grayscale image
  :param trasects_coordinates: a list of lists containing the coordinates of points on transects
    extending out from the mid_point.  Indexing of transects alternates out
    from main transect.
  :param color: pixel value for drawn transect
  :return: 2d array representing grayscale image with transects applied
  """
  img_w_transects = np.copy(gray_img)
  j_max = gray_img.shape[0]
  k_max = gray_img.shape[1]

  for i, transect in enumerate(transects_coordinates):
    rr, cc = transect
    rr[rr >= j_max] = j_max - 1
    cc[cc >= k_max] = k_max - 1

    img_w_transects[rr, cc] = color

  return img_w_transects

def extract_transects_signals(gray_img, transects_coordinates):

  transect_signals = []
  for i, transect in enumerate(transects_coordinates):
    signal = []
    rr, cc = transect
    for j, k in zip(rr, cc):
      signal.append(gray_img[j, k])
    transect_signals.append(signal)

  return transect_signals

def convolve_transects_signals(transects_signals, kernel_size):

  filter = np.ones(kernel_size) / kernel_size
  convolved_signals = []

  for signal in transects_signals:
    convolved_signals.append(convolve_transects_signal(signal, kernel_size))

  return convolved_signals

def convolve_transects_signal(transects_signal, kernel_size):

  filter = np.ones(kernel_size) / kernel_size
  signal_length = max(len(transects_signal), kernel_size) - min(len(transects_signal), kernel_size) + 1
  offset = int((len(transects_signal) - signal_length) / 2)
  return(np.convolve(transects_signal, filter, mode='valid') - transects_signal[offset:-offset])


def plot_transect_signals(transects_signals, figure_path, figure_filename):
  n = len(transects)

  fig, axes = plt.subplots(2 * n)
  for i, signal in enumerate(transects_signals):
    axes[i].plot(signal)

  convolved_signals = convolve_transects_signals(transects_signals, 5)
  for i, signal in enumerate(convolved_signals):
    axes[i + n].plot(signal)

  fig.savefig(os.path.join(figure_path, figure_filename +".png"), format="png",
              bbox_inches="tight")

def plot_transect_signals_for_image(filepath, mid_point, transect_angle,
                                    offset_step_size, transect_count,
                                    figure_path):
  gray = load_img_to_gray(filepath)
  filename = os.path.splitext(os.path.basename(filepath))[0]

  transects = calculate_coordinates_of_transects(mid_point, transect_angle,
                                                 offset_step_size, transect_count)
  transects_signals = extract_transects_signals(gray, transects)

  plot_transect_signals(transects_signals, figure_path, filename)

# %%
import pandas as pd
from ast import literal_eval

scale_data = pd.read_csv('/content/drive/MyDrive/Images/SalmonFishScalesCoordinates-V2.csv', sep=",",
                          names=['filename', 'lt_center', 'br_center', 'end_point'],
                          dtype={'filename': 'string'},
                          converters={'lt_center': literal_eval,
                                      'br_center': literal_eval,
                                      'end_point': literal_eval},
                          header=0)
scale_data['filepath'] = scale_data.apply(lambda row: os.path.join(PATH, row['filename']) +  ".tif", axis=1)

# Switch from column-major to row major
scale_data['lt_center'] = scale_data.apply(lambda row: (row['lt_center'][1], row['lt_center'][0]) , axis = 1)
scale_data['br_center'] = scale_data.apply(lambda row: (row['br_center'][1], row['br_center'][0]) , axis = 1)
scale_data['end_point'] = scale_data.apply(lambda row: (row['end_point'][1], row['end_point'][0]) , axis = 1)

scale_data['mid_center'] = scale_data.apply(lambda row: (int((row['lt_center'][0] + row['br_center'][0]) / 2),
                                                         int((row['lt_center'][1] + row['br_center'][1]) / 2)) , axis=1)
scale_data['transect_angle'] = scale_data.apply(lambda row: calculate_transect_angle(row['mid_center'], row['end_point']), axis=1)

scale_data['id'] = scale_data.apply(lambda row: int(row['filename'].split('_')[0]), axis=1)

# Bring in labels
label_data = pd.read_csv('/content/drive/MyDrive/Images/labels.csv', sep=",",
                          names=['id', 'age', 'type', 'fold'],
                          dtype={'filename': 'int64', 'age': 'int32', 'type': 'int32', 'fold': 'int32'},
                          header=0)

# Fold in labels with scale data
scale_data = scale_data.merge(label_data, on='id', how='left', validate='many_to_one')

# Drop any rows with NaNs, recast ints
scale_data = scale_data.dropna().astype({'fold': int, 'type': int})

# %%
# Get transect signals
transects_signals = []

for index, row in scale_data.iterrows():
  #print(index, row['id'], row['filename'], row['fold'])

  gray = load_img_to_gray(row['filepath'])
  transects = calculate_coordinates_of_transects(row['mid_center'],
                                                 row['transect_angle'],
                                                 .1, 11)

  transects_signals.append([row['id'],
                           extract_transects_signals(gray, transects)],
                           )

transects_signals_df = pd.DataFrame(transects_signals, columns=['id', 'signals'])

# Merge with labels and explode
transects_signals_df = transects_signals_df.merge(label_data, on='id',
                                                  how='left',
                                                  validate='many_to_one')\
                                                  .explode('signals', ignore_index=True)\
                                                  .rename(columns={"signals": "signal"})
transects_signals_df['signal'] = transects_signals_df['signal'].apply(lambda x: np.array(x))

# Add convolved signals
transects_signals_df['convolved_signal'] = transects_signals_df.apply(lambda row: convolve_transects_signal(row['signal'], 5), axis=1)

# %% [markdown]
# ## K-fold Cross validation

# %%
# Create a copy of transects_signals_df so that it doesn't have to be generated
#  each time
from numpy.fft import fft, ifft
from sklearn.model_selection import StratifiedKFold
import keras

def rolling_window(a, window, step):
    shape = a.shape[:-1] + ((a.shape[-1] - window + 1)//step, window)
    strides = (a.strides[0] * step,) + (a.strides[-1],)
    return np.lib.stride_tricks.as_strided(a, shape=shape, strides=strides)

df = transects_signals_df.copy(deep=True)
df['signal'] = df['signal'].apply(lambda x: np.pad(x, (0, int(1.4 * TRANSECT_LENGTH) - x.size), 'constant', constant_values=(0, 0)))
df['signal'] = df['signal'].apply(lambda x: np.flip(x))
df['convolved_signal'] = df['convolved_signal'].apply(lambda x: np.pad(x, (0, int(1.4 * TRANSECT_LENGTH) - x.size), 'constant', constant_values=(0, 0)))
df['convolved_signal'] = df['convolved_signal'].apply(lambda x: np.flip(x))
df['convolved_freq'] = df['signal'].apply(lambda x: np.abs(fft(x))[0:75])

# Cross-validation
skf = StratifiedKFold(n_splits=NUM_FOLDS, shuffle=True, random_state=42)

# Iterate over each fold for cross-validation
for fold, (train_index, val_index) in enumerate(skf.split(df['convolved_freq'], df['type'])):
    print(f"Fold {fold + 1}/{NUM_FOLDS}")

    # Split the data into training and validation sets for this fold
    x_train, x_val = df['convolved_freq'][train_index], df['convolved_freq'][val_index]
    y_train, y_val = df['type'][train_index], df['type'][val_index]

    # Normalize the data
    x_train = np.stack(x_train)
    x_max = np.max(x_train, axis=1, keepdims=True)
    x_train = x_train / x_max
    x_train = x_train.reshape(x_train.shape[0], -1)  # Flatten the array

    # Normalize validation data using the maximum value of the training data
    x_val = np.stack(x_val)
    x_val = x_val / np.max(x_train)

    # Create and compile the model for this fold
    model = keras.Sequential([
        keras.layers.Dense(256, activation='relu'),
        keras.layers.Dropout(.5),
        keras.layers.Dense(256, activation='relu'),
        keras.layers.Dropout(.75),
        keras.layers.Dense(124, activation='relu'),
        keras.layers.Dropout(.75),
        keras.layers.Dense(2, activation='softmax')
    ])
    model.compile(optimizer='rmsprop', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

    # Train the model
    model.fit(x=x_train, y=y_train, batch_size=256, epochs=350, validation_data=(x_val, y_val))
# Out:
# Streaming output truncated to the last 5000 lines.
# Epoch 305/350
# 9/9 [==============================] - 0s 23ms/step - loss: 0.6640 - accuracy: 0.6072 - val_loss: 14098.7412 - val_accuracy: 0.6186
# Epoch 306/350
# 9/9 [==============================] - 0s 23ms/step - loss: 0.6573 - accuracy: 0.6133 - val_loss: 15641.6074 - val_accuracy: 0.6229
# Epoch 307/350
# 9/9 [==============================] - 0s 23ms/step - loss: 0.6592 - accuracy: 0.6128 - val_loss: 16576.4414 - val_accuracy: 0.6229
# Epoch 308/350
# 9/9 [==============================] - 0s 23ms/step - loss: 0.6594 - accuracy: 0.6081 - val_loss: 16401.8320 - val_accuracy: 0.6102
# Epoch 309/350
# 9/9 [==============================] - 0s 24ms/step - loss: 0.6547 - accuracy: 0.6180 - val_loss: 14873.3486 - val_accuracy: 0.6144
# Epoch 310/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.6556 - accuracy: 0.6143 - val_loss: 14957.1748 - val_accuracy: 0.6144
# Epoch 311/350
# 9/9 [==============================] - 0s 20ms/step - loss: 0.6619 - accuracy: 0.6180 - val_loss: 17056.8262 - val_accuracy: 0.6059
# Epoch 312/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.6588 - accuracy: 0.6076 - val_loss: 16814.4414 - val_accuracy: 0.6102
# Epoch 313/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.6518 - accuracy: 0.6171 - val_loss: 14283.6123 - val_accuracy: 0.6059
# Epoch 314/350
# 9/9 [==============================] - 0s 19ms/step - loss: 0.6598 - accuracy: 0.6020 - val_loss: 15445.1553 - val_accuracy: 0.6229
# Epoch 315/350
# 9/9 [==============================] - 0s 23ms/step - loss: 0.6614 - accuracy: 0.6143 - val_loss: 17379.3262 - val_accuracy: 0.6271
# Epoch 316/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.6597 - accuracy: 0.6105 - val_loss: 17082.2715 - val_accuracy: 0.6186
# Epoch 317/350
# 9/9 [==============================] - 0s 23ms/step - loss: 0.6590 - accuracy: 0.6110 - val_loss: 15889.6221 - val_accuracy: 0.6017
# Epoch 318/350
# 9/9 [==============================] - 0s 27ms/step - loss: 0.6546 - accuracy: 0.6176 - val_loss: 17498.4727 - val_accuracy: 0.6186
# Epoch 319/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.6559 - accuracy: 0.6124 - val_loss: 14181.4580 - val_accuracy: 0.6102
# Epoch 320/350
# 9/9 [==============================] - 0s 25ms/step - loss: 0.6558 - accuracy: 0.6157 - val_loss: 14387.5625 - val_accuracy: 0.6271
# Epoch 321/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.6579 - accuracy: 0.6133 - val_loss: 19103.4297 - val_accuracy: 0.6102
# Epoch 322/350
# 9/9 [==============================] - 0s 23ms/step - loss: 0.6570 - accuracy: 0.6072 - val_loss: 14424.3008 - val_accuracy: 0.6229
# Epoch 323/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.6493 - accuracy: 0.6133 - val_loss: 15673.5830 - val_accuracy: 0.6059
# Epoch 324/350
# 9/9 [==============================] - 0s 23ms/step - loss: 0.6568 - accuracy: 0.6152 - val_loss: 13552.7578 - val_accuracy: 0.6102
# Epoch 325/350
# 9/9 [==============================] - 0s 25ms/step - loss: 0.6551 - accuracy: 0.6185 - val_loss: 15339.7002 - val_accuracy: 0.6186
# Epoch 326/350
# 9/9 [==============================] - 0s 24ms/step - loss: 0.6524 - accuracy: 0.6199 - val_loss: 21393.4141 - val_accuracy: 0.6017
# Epoch 327/350
# 9/9 [==============================] - 0s 20ms/step - loss: 0.6551 - accuracy: 0.6124 - val_loss: 15923.5010 - val_accuracy: 0.6186
# Epoch 328/350
# 9/9 [==============================] - 0s 16ms/step - loss: 0.6556 - accuracy: 0.6228 - val_loss: 19212.9922 - val_accuracy: 0.6186
# Epoch 329/350
# 9/9 [==============================] - 0s 15ms/step - loss: 0.6510 - accuracy: 0.6251 - val_loss: 15680.1260 - val_accuracy: 0.6144
# Epoch 330/350
# 9/9 [==============================] - 0s 15ms/step - loss: 0.6573 - accuracy: 0.6095 - val_loss: 19529.7715 - val_accuracy: 0.6271
# Epoch 331/350
# 9/9 [==============================] - 0s 15ms/step - loss: 0.6548 - accuracy: 0.6195 - val_loss: 15462.9424 - val_accuracy: 0.6102
# Epoch 332/350
# 9/9 [==============================] - 0s 15ms/step - loss: 0.6529 - accuracy: 0.6176 - val_loss: 15454.8467 - val_accuracy: 0.6102
# Epoch 333/350
# 9/9 [==============================] - 0s 20ms/step - loss: 0.6572 - accuracy: 0.6161 - val_loss: 16207.6738 - val_accuracy: 0.6144
# Epoch 334/350
# 9/9 [==============================] - 0s 17ms/step - loss: 0.6560 - accuracy: 0.6138 - val_loss: 16310.2471 - val_accuracy: 0.6186
# Epoch 335/350
# 9/9 [==============================] - 0s 15ms/step - loss: 0.6576 - accuracy: 0.6176 - val_loss: 18997.5859 - val_accuracy: 0.6271
# Epoch 336/350
# 9/9 [==============================] - 0s 15ms/step - loss: 0.6533 - accuracy: 0.6195 - val_loss: 17282.3340 - val_accuracy: 0.6271
# Epoch 337/350
# 9/9 [==============================] - 0s 17ms/step - loss: 0.6543 - accuracy: 0.6152 - val_loss: 14336.9014 - val_accuracy: 0.6017
# Epoch 338/350
# 9/9 [==============================] - 0s 15ms/step - loss: 0.6543 - accuracy: 0.6062 - val_loss: 19505.7188 - val_accuracy: 0.6186
# Epoch 339/350
# 9/9 [==============================] - 0s 17ms/step - loss: 0.6550 - accuracy: 0.6095 - val_loss: 16675.0352 - val_accuracy: 0.6271
# Epoch 340/350
# 9/9 [==============================] - 0s 16ms/step - loss: 0.6553 - accuracy: 0.6114 - val_loss: 13796.5293 - val_accuracy: 0.6017
# Epoch 341/350
# 9/9 [==============================] - 0s 16ms/step - loss: 0.6552 - accuracy: 0.6232 - val_loss: 15900.3008 - val_accuracy: 0.6229
# Epoch 342/350
# 9/9 [==============================] - 0s 15ms/step - loss: 0.6548 - accuracy: 0.6180 - val_loss: 18711.0781 - val_accuracy: 0.6186
# Epoch 343/350
# 9/9 [==============================] - 0s 14ms/step - loss: 0.6509 - accuracy: 0.6180 - val_loss: 17427.6367 - val_accuracy: 0.6059
# Epoch 344/350
# 9/9 [==============================] - 0s 15ms/step - loss: 0.6530 - accuracy: 0.6242 - val_loss: 25396.5586 - val_accuracy: 0.6059
# Epoch 345/350
# 9/9 [==============================] - 0s 14ms/step - loss: 0.6534 - accuracy: 0.6204 - val_loss: 17110.1230 - val_accuracy: 0.6102
# Epoch 346/350
# 9/9 [==============================] - 0s 15ms/step - loss: 0.6515 - accuracy: 0.6185 - val_loss: 18620.0840 - val_accuracy: 0.6144
# Epoch 347/350
# 9/9 [==============================] - 0s 20ms/step - loss: 0.6493 - accuracy: 0.6223 - val_loss: 19289.3203 - val_accuracy: 0.6229
# Epoch 348/350
# 9/9 [==============================] - 0s 15ms/step - loss: 0.6474 - accuracy: 0.6298 - val_loss: 14621.6777 - val_accuracy: 0.6144
# Epoch 349/350
# 9/9 [==============================] - 0s 15ms/step - loss: 0.6541 - accuracy: 0.6232 - val_loss: 16072.1768 - val_accuracy: 0.6059
# Epoch 350/350
# 9/9 [==============================] - 0s 17ms/step - loss: 0.6558 - accuracy: 0.6114 - val_loss: 17036.8320 - val_accuracy: 0.6186
# Fold 4/10
# Epoch 1/350
# 9/9 [==============================] - 1s 37ms/step - loss: 0.7126 - accuracy: 0.5028 - val_loss: 9553.8623 - val_accuracy: 0.5636
# Epoch 2/350
# 9/9 [==============================] - 0s 18ms/step - loss: 0.6951 - accuracy: 0.5364 - val_loss: 7336.5229 - val_accuracy: 0.5636
# Epoch 3/350
# 9/9 [==============================] - 0s 18ms/step - loss: 0.6933 - accuracy: 0.5378 - val_loss: 6543.2598 - val_accuracy: 0.5636
# Epoch 4/350
# 9/9 [==============================] - 0s 15ms/step - loss: 0.6939 - accuracy: 0.5312 - val_loss: 4563.9058 - val_accuracy: 0.5636
# Epoch 5/350
# 9/9 [==============================] - 0s 15ms/step - loss: 0.6906 - accuracy: 0.5425 - val_loss: 4960.1392 - val_accuracy: 0.5636
# Epoch 6/350
# 9/9 [==============================] - 0s 15ms/step - loss: 0.6935 - accuracy: 0.5373 - val_loss: 3020.2009 - val_accuracy: 0.5636
# Epoch 7/350
# 9/9 [==============================] - 0s 15ms/step - loss: 0.6889 - accuracy: 0.5585 - val_loss: 3493.5527 - val_accuracy: 0.5636
# Epoch 8/350
# 9/9 [==============================] - 0s 15ms/step - loss: 0.6872 - accuracy: 0.5406 - val_loss: 3329.5056 - val_accuracy: 0.5636
# Epoch 9/350
# 9/9 [==============================] - 0s 17ms/step - loss: 0.6880 - accuracy: 0.5548 - val_loss: 2434.2913 - val_accuracy: 0.5636
# Epoch 10/350
# 9/9 [==============================] - 0s 16ms/step - loss: 0.6881 - accuracy: 0.5614 - val_loss: 2564.2668 - val_accuracy: 0.5636
# Epoch 11/350
# 9/9 [==============================] - 0s 17ms/step - loss: 0.6859 - accuracy: 0.5557 - val_loss: 3193.0435 - val_accuracy: 0.5636
# Epoch 12/350
# 9/9 [==============================] - 0s 16ms/step - loss: 0.6870 - accuracy: 0.5585 - val_loss: 3009.2158 - val_accuracy: 0.5636
# Epoch 13/350
# 9/9 [==============================] - 0s 15ms/step - loss: 0.6864 - accuracy: 0.5614 - val_loss: 3786.3989 - val_accuracy: 0.5636
# Epoch 14/350
# 9/9 [==============================] - 0s 16ms/step - loss: 0.6857 - accuracy: 0.5604 - val_loss: 4170.6787 - val_accuracy: 0.5636
# Epoch 15/350
# 9/9 [==============================] - 0s 15ms/step - loss: 0.6872 - accuracy: 0.5595 - val_loss: 3479.5374 - val_accuracy: 0.5636
# Epoch 16/350
# 9/9 [==============================] - 0s 19ms/step - loss: 0.6879 - accuracy: 0.5590 - val_loss: 2954.1479 - val_accuracy: 0.5636
# Epoch 17/350
# 9/9 [==============================] - 0s 14ms/step - loss: 0.6864 - accuracy: 0.5619 - val_loss: 3220.6614 - val_accuracy: 0.5636
# Epoch 18/350
# 9/9 [==============================] - 0s 15ms/step - loss: 0.6861 - accuracy: 0.5628 - val_loss: 3049.5715 - val_accuracy: 0.5636
# Epoch 19/350
# 9/9 [==============================] - 0s 15ms/step - loss: 0.6871 - accuracy: 0.5623 - val_loss: 3076.0330 - val_accuracy: 0.5636
# Epoch 20/350
# 9/9 [==============================] - 0s 16ms/step - loss: 0.6871 - accuracy: 0.5628 - val_loss: 3630.2627 - val_accuracy: 0.5636
# Epoch 21/350
# 9/9 [==============================] - 0s 16ms/step - loss: 0.6868 - accuracy: 0.5642 - val_loss: 3238.8469 - val_accuracy: 0.5636
# Epoch 22/350
# 9/9 [==============================] - 0s 18ms/step - loss: 0.6858 - accuracy: 0.5661 - val_loss: 2790.0759 - val_accuracy: 0.5636
# Epoch 23/350
# 9/9 [==============================] - 0s 19ms/step - loss: 0.6861 - accuracy: 0.5666 - val_loss: 2059.7146 - val_accuracy: 0.5636
# Epoch 24/350
# 9/9 [==============================] - 0s 15ms/step - loss: 0.6844 - accuracy: 0.5661 - val_loss: 2789.9622 - val_accuracy: 0.5636
# Epoch 25/350
# 9/9 [==============================] - 0s 15ms/step - loss: 0.6870 - accuracy: 0.5652 - val_loss: 2165.8069 - val_accuracy: 0.5636
# Epoch 26/350
# 9/9 [==============================] - 0s 14ms/step - loss: 0.6855 - accuracy: 0.5661 - val_loss: 1677.1187 - val_accuracy: 0.5636
# Epoch 27/350
# 9/9 [==============================] - 0s 16ms/step - loss: 0.6857 - accuracy: 0.5647 - val_loss: 1511.9404 - val_accuracy: 0.5636
# Epoch 28/350
# 9/9 [==============================] - 0s 16ms/step - loss: 0.6857 - accuracy: 0.5652 - val_loss: 1180.6572 - val_accuracy: 0.5636
# Epoch 29/350
# 9/9 [==============================] - 0s 15ms/step - loss: 0.6860 - accuracy: 0.5633 - val_loss: 1321.8447 - val_accuracy: 0.5636
# Epoch 30/350
# 9/9 [==============================] - 0s 17ms/step - loss: 0.6864 - accuracy: 0.5642 - val_loss: 1340.1649 - val_accuracy: 0.5636
# Epoch 31/350
# 9/9 [==============================] - 0s 15ms/step - loss: 0.6870 - accuracy: 0.5633 - val_loss: 1560.9061 - val_accuracy: 0.5636
# Epoch 32/350
# 9/9 [==============================] - 0s 15ms/step - loss: 0.6848 - accuracy: 0.5661 - val_loss: 1902.2670 - val_accuracy: 0.5636
# Epoch 33/350
# 9/9 [==============================] - 0s 15ms/step - loss: 0.6852 - accuracy: 0.5656 - val_loss: 1802.5721 - val_accuracy: 0.5636
# Epoch 34/350
# 9/9 [==============================] - 0s 19ms/step - loss: 0.6855 - accuracy: 0.5656 - val_loss: 1704.0284 - val_accuracy: 0.5636
# Epoch 35/350
# 9/9 [==============================] - 0s 19ms/step - loss: 0.6843 - accuracy: 0.5652 - val_loss: 1988.6296 - val_accuracy: 0.5636
# Epoch 36/350
# 9/9 [==============================] - 0s 20ms/step - loss: 0.6854 - accuracy: 0.5661 - val_loss: 1743.4170 - val_accuracy: 0.5636
# Epoch 37/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.6853 - accuracy: 0.5656 - val_loss: 1602.0409 - val_accuracy: 0.5636
# Epoch 38/350
# 9/9 [==============================] - 0s 26ms/step - loss: 0.6848 - accuracy: 0.5661 - val_loss: 1318.8185 - val_accuracy: 0.5636
# Epoch 39/350
# 9/9 [==============================] - 0s 26ms/step - loss: 0.6860 - accuracy: 0.5656 - val_loss: 1118.0072 - val_accuracy: 0.5636
# Epoch 40/350
# 9/9 [==============================] - 0s 24ms/step - loss: 0.6851 - accuracy: 0.5661 - val_loss: 1002.4595 - val_accuracy: 0.5636
# Epoch 41/350
# 9/9 [==============================] - 0s 23ms/step - loss: 0.6832 - accuracy: 0.5652 - val_loss: 1511.0052 - val_accuracy: 0.5636
# Epoch 42/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.6841 - accuracy: 0.5661 - val_loss: 2178.5774 - val_accuracy: 0.5636
# Epoch 43/350
# 9/9 [==============================] - 0s 25ms/step - loss: 0.6840 - accuracy: 0.5652 - val_loss: 1834.8134 - val_accuracy: 0.5636
# Epoch 44/350
# 9/9 [==============================] - 0s 24ms/step - loss: 0.6845 - accuracy: 0.5656 - val_loss: 1326.6395 - val_accuracy: 0.5636
# Epoch 45/350
# 9/9 [==============================] - 0s 27ms/step - loss: 0.6849 - accuracy: 0.5661 - val_loss: 1224.9669 - val_accuracy: 0.5636
# Epoch 46/350
# 9/9 [==============================] - 0s 23ms/step - loss: 0.6845 - accuracy: 0.5666 - val_loss: 1303.9031 - val_accuracy: 0.5636
# Epoch 47/350
# 9/9 [==============================] - 0s 23ms/step - loss: 0.6848 - accuracy: 0.5652 - val_loss: 667.1118 - val_accuracy: 0.5551
# Epoch 48/350
# 9/9 [==============================] - 0s 23ms/step - loss: 0.6854 - accuracy: 0.5661 - val_loss: 816.0393 - val_accuracy: 0.5593
# Epoch 49/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.6846 - accuracy: 0.5652 - val_loss: 1186.9069 - val_accuracy: 0.5593
# Epoch 50/350
# 9/9 [==============================] - 0s 24ms/step - loss: 0.6842 - accuracy: 0.5656 - val_loss: 1782.8247 - val_accuracy: 0.5636
# Epoch 51/350
# 9/9 [==============================] - 0s 25ms/step - loss: 0.6845 - accuracy: 0.5656 - val_loss: 1322.5083 - val_accuracy: 0.5593
# Epoch 52/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.6861 - accuracy: 0.5656 - val_loss: 1276.4562 - val_accuracy: 0.5593
# Epoch 53/350
# 9/9 [==============================] - 0s 24ms/step - loss: 0.6836 - accuracy: 0.5661 - val_loss: 894.5522 - val_accuracy: 0.5847
# Epoch 54/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.6839 - accuracy: 0.5656 - val_loss: 848.2358 - val_accuracy: 0.5805
# Epoch 55/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.6852 - accuracy: 0.5656 - val_loss: 704.4965 - val_accuracy: 0.5805
# Epoch 56/350
# 9/9 [==============================] - 0s 23ms/step - loss: 0.6853 - accuracy: 0.5656 - val_loss: 667.2924 - val_accuracy: 0.5890
# Epoch 57/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.6838 - accuracy: 0.5656 - val_loss: 1552.8011 - val_accuracy: 0.5551
# Epoch 58/350
# 9/9 [==============================] - 0s 23ms/step - loss: 0.6846 - accuracy: 0.5652 - val_loss: 680.5056 - val_accuracy: 0.5975
# Epoch 59/350
# 9/9 [==============================] - 0s 19ms/step - loss: 0.6840 - accuracy: 0.5666 - val_loss: 1010.5352 - val_accuracy: 0.5847
# Epoch 60/350
# 9/9 [==============================] - 0s 26ms/step - loss: 0.6846 - accuracy: 0.5647 - val_loss: 1122.4677 - val_accuracy: 0.5805
# Epoch 61/350
# 9/9 [==============================] - 0s 24ms/step - loss: 0.6845 - accuracy: 0.5656 - val_loss: 1320.5636 - val_accuracy: 0.5678
# Epoch 62/350
# 9/9 [==============================] - 0s 23ms/step - loss: 0.6836 - accuracy: 0.5661 - val_loss: 1411.5450 - val_accuracy: 0.5720
# Epoch 63/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.6842 - accuracy: 0.5656 - val_loss: 1445.7899 - val_accuracy: 0.5636
# Epoch 64/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.6840 - accuracy: 0.5656 - val_loss: 1516.7506 - val_accuracy: 0.5551
# Epoch 65/350
# 9/9 [==============================] - 0s 19ms/step - loss: 0.6829 - accuracy: 0.5656 - val_loss: 2013.9301 - val_accuracy: 0.5593
# Epoch 66/350
# 9/9 [==============================] - 0s 20ms/step - loss: 0.6848 - accuracy: 0.5647 - val_loss: 1538.4229 - val_accuracy: 0.5551
# Epoch 67/350
# 9/9 [==============================] - 0s 19ms/step - loss: 0.6837 - accuracy: 0.5656 - val_loss: 1302.0432 - val_accuracy: 0.5720
# Epoch 68/350
# 9/9 [==============================] - 0s 20ms/step - loss: 0.6847 - accuracy: 0.5647 - val_loss: 1388.8834 - val_accuracy: 0.5763
# Epoch 69/350
# 9/9 [==============================] - 0s 19ms/step - loss: 0.6837 - accuracy: 0.5656 - val_loss: 2132.9565 - val_accuracy: 0.5636
# Epoch 70/350
# 9/9 [==============================] - 0s 16ms/step - loss: 0.6834 - accuracy: 0.5656 - val_loss: 2130.2444 - val_accuracy: 0.5551
# Epoch 71/350
# 9/9 [==============================] - 0s 16ms/step - loss: 0.6850 - accuracy: 0.5652 - val_loss: 1748.8457 - val_accuracy: 0.5720
# Epoch 72/350
# 9/9 [==============================] - 0s 15ms/step - loss: 0.6855 - accuracy: 0.5656 - val_loss: 941.1649 - val_accuracy: 0.5890
# Epoch 73/350
# 9/9 [==============================] - 0s 17ms/step - loss: 0.6839 - accuracy: 0.5637 - val_loss: 1935.8951 - val_accuracy: 0.5551
# Epoch 74/350
# 9/9 [==============================] - 0s 14ms/step - loss: 0.6854 - accuracy: 0.5652 - val_loss: 2132.1489 - val_accuracy: 0.5593
# Epoch 75/350
# 9/9 [==============================] - 0s 16ms/step - loss: 0.6825 - accuracy: 0.5656 - val_loss: 1326.4489 - val_accuracy: 0.5932
# Epoch 76/350
# 9/9 [==============================] - 0s 16ms/step - loss: 0.6827 - accuracy: 0.5656 - val_loss: 1468.9436 - val_accuracy: 0.5847
# Epoch 77/350
# 9/9 [==============================] - 0s 15ms/step - loss: 0.6840 - accuracy: 0.5661 - val_loss: 1385.7253 - val_accuracy: 0.5890
# Epoch 78/350
# 9/9 [==============================] - 0s 15ms/step - loss: 0.6845 - accuracy: 0.5661 - val_loss: 1369.5973 - val_accuracy: 0.5890
# Epoch 79/350
# 9/9 [==============================] - 0s 18ms/step - loss: 0.6844 - accuracy: 0.5656 - val_loss: 1487.5319 - val_accuracy: 0.5847
# Epoch 80/350
# 9/9 [==============================] - 0s 18ms/step - loss: 0.6808 - accuracy: 0.5656 - val_loss: 2049.0625 - val_accuracy: 0.5890
# Epoch 81/350
# 9/9 [==============================] - 0s 18ms/step - loss: 0.6843 - accuracy: 0.5652 - val_loss: 2320.8733 - val_accuracy: 0.5678
# Epoch 82/350
# 9/9 [==============================] - 0s 20ms/step - loss: 0.6827 - accuracy: 0.5656 - val_loss: 2638.2495 - val_accuracy: 0.5636
# Epoch 83/350
# 9/9 [==============================] - 0s 15ms/step - loss: 0.6822 - accuracy: 0.5647 - val_loss: 1705.2778 - val_accuracy: 0.5890
# Epoch 84/350
# 9/9 [==============================] - 0s 16ms/step - loss: 0.6834 - accuracy: 0.5656 - val_loss: 2434.8210 - val_accuracy: 0.5678
# Epoch 85/350
# 9/9 [==============================] - 0s 16ms/step - loss: 0.6840 - accuracy: 0.5656 - val_loss: 2351.5413 - val_accuracy: 0.5763
# Epoch 86/350
# 9/9 [==============================] - 0s 15ms/step - loss: 0.6844 - accuracy: 0.5652 - val_loss: 1129.9739 - val_accuracy: 0.6271
# Epoch 87/350
# 9/9 [==============================] - 0s 15ms/step - loss: 0.6839 - accuracy: 0.5661 - val_loss: 1782.4857 - val_accuracy: 0.5975
# Epoch 88/350
# 9/9 [==============================] - 0s 18ms/step - loss: 0.6818 - accuracy: 0.5652 - val_loss: 2061.0356 - val_accuracy: 0.5932
# Epoch 89/350
# 9/9 [==============================] - 0s 16ms/step - loss: 0.6796 - accuracy: 0.5666 - val_loss: 3717.2932 - val_accuracy: 0.5720
# Epoch 90/350
# 9/9 [==============================] - 0s 16ms/step - loss: 0.6816 - accuracy: 0.5647 - val_loss: 2752.0955 - val_accuracy: 0.6059
# Epoch 91/350
# 9/9 [==============================] - 0s 15ms/step - loss: 0.6829 - accuracy: 0.5680 - val_loss: 1740.4496 - val_accuracy: 0.6102
# Epoch 92/350
# 9/9 [==============================] - 0s 16ms/step - loss: 0.6814 - accuracy: 0.5656 - val_loss: 1999.5610 - val_accuracy: 0.6186
# Epoch 93/350
# 9/9 [==============================] - 0s 16ms/step - loss: 0.6825 - accuracy: 0.5647 - val_loss: 2141.1636 - val_accuracy: 0.6102
# Epoch 94/350
# 9/9 [==============================] - 0s 17ms/step - loss: 0.6835 - accuracy: 0.5666 - val_loss: 1925.9792 - val_accuracy: 0.6102
# Epoch 95/350
# 9/9 [==============================] - 0s 16ms/step - loss: 0.6817 - accuracy: 0.5666 - val_loss: 2078.6663 - val_accuracy: 0.6144
# Epoch 96/350
# 9/9 [==============================] - 0s 17ms/step - loss: 0.6816 - accuracy: 0.5656 - val_loss: 2913.9053 - val_accuracy: 0.6102
# Epoch 97/350
# 9/9 [==============================] - 0s 15ms/step - loss: 0.6781 - accuracy: 0.5661 - val_loss: 2630.3372 - val_accuracy: 0.6144
# Epoch 98/350
# 9/9 [==============================] - 0s 16ms/step - loss: 0.6819 - accuracy: 0.5652 - val_loss: 3601.6526 - val_accuracy: 0.6059
# Epoch 99/350
# 9/9 [==============================] - 0s 17ms/step - loss: 0.6801 - accuracy: 0.5652 - val_loss: 3244.3748 - val_accuracy: 0.6314
# Epoch 100/350
# 9/9 [==============================] - 0s 16ms/step - loss: 0.6793 - accuracy: 0.5652 - val_loss: 3500.2175 - val_accuracy: 0.6186
# Epoch 101/350
# 9/9 [==============================] - 0s 14ms/step - loss: 0.6802 - accuracy: 0.5680 - val_loss: 4762.4331 - val_accuracy: 0.5932
# Epoch 102/350
# 9/9 [==============================] - 0s 15ms/step - loss: 0.6797 - accuracy: 0.5661 - val_loss: 2267.3135 - val_accuracy: 0.6017
# Epoch 103/350
# 9/9 [==============================] - 0s 16ms/step - loss: 0.6792 - accuracy: 0.5685 - val_loss: 2008.9036 - val_accuracy: 0.5636
# Epoch 104/350
# 9/9 [==============================] - 0s 16ms/step - loss: 0.6787 - accuracy: 0.5609 - val_loss: 4330.9229 - val_accuracy: 0.6144
# Epoch 105/350
# 9/9 [==============================] - 0s 16ms/step - loss: 0.6792 - accuracy: 0.5652 - val_loss: 3836.1077 - val_accuracy: 0.6186
# Epoch 106/350
# 9/9 [==============================] - 0s 15ms/step - loss: 0.6777 - accuracy: 0.5670 - val_loss: 3505.1106 - val_accuracy: 0.6271
# Epoch 107/350
# 9/9 [==============================] - 0s 15ms/step - loss: 0.6778 - accuracy: 0.5703 - val_loss: 7422.9209 - val_accuracy: 0.5847
# Epoch 108/350
# 9/9 [==============================] - 0s 15ms/step - loss: 0.6812 - accuracy: 0.5713 - val_loss: 4706.3979 - val_accuracy: 0.6229
# Epoch 109/350
# 9/9 [==============================] - 0s 18ms/step - loss: 0.6738 - accuracy: 0.5737 - val_loss: 5448.7729 - val_accuracy: 0.6144
# Epoch 110/350
# 9/9 [==============================] - 0s 16ms/step - loss: 0.6788 - accuracy: 0.5713 - val_loss: 4402.3110 - val_accuracy: 0.6102
# Epoch 111/350
# 9/9 [==============================] - 0s 17ms/step - loss: 0.6774 - accuracy: 0.5675 - val_loss: 4056.7268 - val_accuracy: 0.6059
# Epoch 112/350
# 9/9 [==============================] - 0s 16ms/step - loss: 0.6752 - accuracy: 0.5755 - val_loss: 5255.6748 - val_accuracy: 0.6144
# Epoch 113/350
# 9/9 [==============================] - 0s 17ms/step - loss: 0.6779 - accuracy: 0.5784 - val_loss: 5555.8521 - val_accuracy: 0.6144
# Epoch 114/350
# 9/9 [==============================] - 0s 18ms/step - loss: 0.6731 - accuracy: 0.5737 - val_loss: 3531.2522 - val_accuracy: 0.6144
# Epoch 115/350
# 9/9 [==============================] - 0s 16ms/step - loss: 0.6805 - accuracy: 0.5633 - val_loss: 3566.1467 - val_accuracy: 0.6271
# Epoch 116/350
# 9/9 [==============================] - 0s 15ms/step - loss: 0.6793 - accuracy: 0.5755 - val_loss: 4827.6914 - val_accuracy: 0.6144
# Epoch 117/350
# 9/9 [==============================] - 0s 19ms/step - loss: 0.6735 - accuracy: 0.5713 - val_loss: 5090.2451 - val_accuracy: 0.6059
# Epoch 118/350
# 9/9 [==============================] - 0s 15ms/step - loss: 0.6768 - accuracy: 0.5788 - val_loss: 5205.9126 - val_accuracy: 0.6102
# Epoch 119/350
# 9/9 [==============================] - 0s 16ms/step - loss: 0.6777 - accuracy: 0.5751 - val_loss: 4301.5537 - val_accuracy: 0.6229
# Epoch 120/350
# 9/9 [==============================] - 0s 17ms/step - loss: 0.6754 - accuracy: 0.5666 - val_loss: 8093.3486 - val_accuracy: 0.6059
# Epoch 121/350
# 9/9 [==============================] - 0s 15ms/step - loss: 0.6761 - accuracy: 0.5826 - val_loss: 4109.2202 - val_accuracy: 0.6229
# Epoch 122/350
# 9/9 [==============================] - 0s 16ms/step - loss: 0.6771 - accuracy: 0.5732 - val_loss: 4925.6421 - val_accuracy: 0.6102
# Epoch 123/350
# 9/9 [==============================] - 0s 18ms/step - loss: 0.6750 - accuracy: 0.5685 - val_loss: 10284.8506 - val_accuracy: 0.5805
# Epoch 124/350
# 9/9 [==============================] - 0s 19ms/step - loss: 0.6781 - accuracy: 0.5718 - val_loss: 6117.7622 - val_accuracy: 0.6229
# Epoch 125/350
# 9/9 [==============================] - 0s 15ms/step - loss: 0.6764 - accuracy: 0.5803 - val_loss: 5355.5303 - val_accuracy: 0.6102
# Epoch 126/350
# 9/9 [==============================] - 0s 17ms/step - loss: 0.6796 - accuracy: 0.5741 - val_loss: 3504.0403 - val_accuracy: 0.6017
# Epoch 127/350
# 9/9 [==============================] - 0s 16ms/step - loss: 0.6751 - accuracy: 0.5770 - val_loss: 4464.1074 - val_accuracy: 0.6059
# Epoch 128/350
# 9/9 [==============================] - 0s 18ms/step - loss: 0.6751 - accuracy: 0.5779 - val_loss: 6074.0024 - val_accuracy: 0.6144
# Epoch 129/350
# 9/9 [==============================] - 0s 15ms/step - loss: 0.6736 - accuracy: 0.5883 - val_loss: 6557.9053 - val_accuracy: 0.6144
# Epoch 130/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.6770 - accuracy: 0.5803 - val_loss: 6479.6836 - val_accuracy: 0.6186
# Epoch 131/350
# 9/9 [==============================] - 0s 25ms/step - loss: 0.6739 - accuracy: 0.5817 - val_loss: 6064.7231 - val_accuracy: 0.6102
# Epoch 132/350
# 9/9 [==============================] - 0s 27ms/step - loss: 0.6749 - accuracy: 0.5751 - val_loss: 5214.7402 - val_accuracy: 0.6186
# Epoch 133/350
# 9/9 [==============================] - 0s 25ms/step - loss: 0.6741 - accuracy: 0.5817 - val_loss: 7727.4043 - val_accuracy: 0.6229
# Epoch 134/350
# 9/9 [==============================] - 0s 26ms/step - loss: 0.6717 - accuracy: 0.5817 - val_loss: 6742.5229 - val_accuracy: 0.6186
# Epoch 135/350
# 9/9 [==============================] - 0s 24ms/step - loss: 0.6743 - accuracy: 0.5784 - val_loss: 5812.5186 - val_accuracy: 0.6144
# Epoch 136/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.6724 - accuracy: 0.5869 - val_loss: 8647.7441 - val_accuracy: 0.6017
# Epoch 137/350
# 9/9 [==============================] - 0s 24ms/step - loss: 0.6745 - accuracy: 0.5722 - val_loss: 6869.9141 - val_accuracy: 0.6144
# Epoch 138/350
# 9/9 [==============================] - 0s 26ms/step - loss: 0.6761 - accuracy: 0.5793 - val_loss: 4906.3784 - val_accuracy: 0.6144
# Epoch 139/350
# 9/9 [==============================] - 0s 28ms/step - loss: 0.6780 - accuracy: 0.5788 - val_loss: 4072.4565 - val_accuracy: 0.6102
# Epoch 140/350
# 9/9 [==============================] - 0s 25ms/step - loss: 0.6753 - accuracy: 0.5873 - val_loss: 7209.9512 - val_accuracy: 0.6144
# Epoch 141/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.6746 - accuracy: 0.5746 - val_loss: 4398.4746 - val_accuracy: 0.6017
# Epoch 142/350
# 9/9 [==============================] - 0s 26ms/step - loss: 0.6717 - accuracy: 0.5977 - val_loss: 6261.3599 - val_accuracy: 0.6229
# Epoch 143/350
# 9/9 [==============================] - 0s 25ms/step - loss: 0.6739 - accuracy: 0.5869 - val_loss: 4104.4829 - val_accuracy: 0.5805
# Epoch 144/350
# 9/9 [==============================] - 0s 24ms/step - loss: 0.6752 - accuracy: 0.5765 - val_loss: 7244.2441 - val_accuracy: 0.6186
# Epoch 145/350
# 9/9 [==============================] - 0s 26ms/step - loss: 0.6741 - accuracy: 0.5760 - val_loss: 8329.1826 - val_accuracy: 0.6144
# Epoch 146/350
# 9/9 [==============================] - 0s 24ms/step - loss: 0.6743 - accuracy: 0.5760 - val_loss: 4405.1733 - val_accuracy: 0.6102
# Epoch 147/350
# 9/9 [==============================] - 0s 25ms/step - loss: 0.6771 - accuracy: 0.5826 - val_loss: 8188.8613 - val_accuracy: 0.6144
# Epoch 148/350
# 9/9 [==============================] - 0s 25ms/step - loss: 0.6751 - accuracy: 0.5855 - val_loss: 9285.5469 - val_accuracy: 0.5932
# Epoch 149/350
# 9/9 [==============================] - 0s 27ms/step - loss: 0.6703 - accuracy: 0.5807 - val_loss: 8086.7910 - val_accuracy: 0.6144
# Epoch 150/350
# 9/9 [==============================] - 0s 23ms/step - loss: 0.6744 - accuracy: 0.5850 - val_loss: 7758.2666 - val_accuracy: 0.6102
# Epoch 151/350
# 9/9 [==============================] - 0s 24ms/step - loss: 0.6680 - accuracy: 0.5949 - val_loss: 5282.5825 - val_accuracy: 0.6144
# Epoch 152/350
# 9/9 [==============================] - 0s 23ms/step - loss: 0.6712 - accuracy: 0.5859 - val_loss: 8367.8789 - val_accuracy: 0.6102
# Epoch 153/350
# 9/9 [==============================] - 0s 24ms/step - loss: 0.6680 - accuracy: 0.5944 - val_loss: 6748.1699 - val_accuracy: 0.6229
# Epoch 154/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.6664 - accuracy: 0.6015 - val_loss: 9165.9785 - val_accuracy: 0.6102
# Epoch 155/350
# 9/9 [==============================] - 0s 25ms/step - loss: 0.6723 - accuracy: 0.5845 - val_loss: 9678.6670 - val_accuracy: 0.6059
# Epoch 156/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.6715 - accuracy: 0.5883 - val_loss: 6366.7334 - val_accuracy: 0.6144
# Epoch 157/350
# 9/9 [==============================] - 0s 25ms/step - loss: 0.6703 - accuracy: 0.5935 - val_loss: 9927.8887 - val_accuracy: 0.6102
# Epoch 158/350
# 9/9 [==============================] - 0s 19ms/step - loss: 0.6698 - accuracy: 0.5949 - val_loss: 6665.3784 - val_accuracy: 0.6059
# Epoch 159/350
# 9/9 [==============================] - 0s 16ms/step - loss: 0.6748 - accuracy: 0.5897 - val_loss: 10683.0820 - val_accuracy: 0.6059
# Epoch 160/350
# 9/9 [==============================] - 0s 18ms/step - loss: 0.6746 - accuracy: 0.5921 - val_loss: 6156.2759 - val_accuracy: 0.6059
# Epoch 161/350
# 9/9 [==============================] - 0s 19ms/step - loss: 0.6747 - accuracy: 0.5803 - val_loss: 6112.2144 - val_accuracy: 0.5932
# Epoch 162/350
# 9/9 [==============================] - 0s 17ms/step - loss: 0.6758 - accuracy: 0.5831 - val_loss: 8082.8384 - val_accuracy: 0.6144
# Epoch 163/350
# 9/9 [==============================] - 0s 18ms/step - loss: 0.6699 - accuracy: 0.5888 - val_loss: 4556.3208 - val_accuracy: 0.6102
# Epoch 164/350
# 9/9 [==============================] - 0s 20ms/step - loss: 0.6676 - accuracy: 0.5940 - val_loss: 5664.0371 - val_accuracy: 0.5932
# Epoch 165/350
# 9/9 [==============================] - 0s 17ms/step - loss: 0.6744 - accuracy: 0.5755 - val_loss: 9478.3906 - val_accuracy: 0.6059
# Epoch 166/350
# 9/9 [==============================] - 0s 15ms/step - loss: 0.6748 - accuracy: 0.5907 - val_loss: 5914.3071 - val_accuracy: 0.6144
# Epoch 167/350
# 9/9 [==============================] - 0s 17ms/step - loss: 0.6696 - accuracy: 0.5982 - val_loss: 10123.4824 - val_accuracy: 0.6102
# Epoch 168/350
# 9/9 [==============================] - 0s 15ms/step - loss: 0.6733 - accuracy: 0.5869 - val_loss: 8256.8232 - val_accuracy: 0.6229
# Epoch 169/350
# 9/9 [==============================] - 0s 15ms/step - loss: 0.6687 - accuracy: 0.5826 - val_loss: 7939.7954 - val_accuracy: 0.6271
# Epoch 170/350
# 9/9 [==============================] - 0s 17ms/step - loss: 0.6707 - accuracy: 0.5864 - val_loss: 7233.8931 - val_accuracy: 0.6271
# Epoch 171/350
# 9/9 [==============================] - 0s 17ms/step - loss: 0.6710 - accuracy: 0.5779 - val_loss: 9674.2617 - val_accuracy: 0.6102
# Epoch 172/350
# 9/9 [==============================] - 0s 15ms/step - loss: 0.6745 - accuracy: 0.5883 - val_loss: 8957.0986 - val_accuracy: 0.6144
# Epoch 173/350
# 9/9 [==============================] - 0s 15ms/step - loss: 0.6733 - accuracy: 0.5973 - val_loss: 6657.4473 - val_accuracy: 0.6102
# Epoch 174/350
# 9/9 [==============================] - 0s 17ms/step - loss: 0.6727 - accuracy: 0.5822 - val_loss: 9023.3848 - val_accuracy: 0.6144
# Epoch 175/350
# 9/9 [==============================] - 0s 18ms/step - loss: 0.6709 - accuracy: 0.5897 - val_loss: 6376.5063 - val_accuracy: 0.5975
# Epoch 176/350
# 9/9 [==============================] - 0s 15ms/step - loss: 0.6726 - accuracy: 0.5822 - val_loss: 5991.9043 - val_accuracy: 0.6144
# Epoch 177/350
# 9/9 [==============================] - 0s 17ms/step - loss: 0.6708 - accuracy: 0.5897 - val_loss: 7744.7861 - val_accuracy: 0.6186
# Epoch 178/350
# 9/9 [==============================] - 0s 16ms/step - loss: 0.6695 - accuracy: 0.5992 - val_loss: 7709.5171 - val_accuracy: 0.6186
# Epoch 179/350
# 9/9 [==============================] - 0s 15ms/step - loss: 0.6694 - accuracy: 0.5888 - val_loss: 6592.1055 - val_accuracy: 0.5975
# Epoch 180/350
# 9/9 [==============================] - 0s 15ms/step - loss: 0.6709 - accuracy: 0.5836 - val_loss: 7773.0229 - val_accuracy: 0.6229
# Epoch 181/350
# 9/9 [==============================] - 0s 20ms/step - loss: 0.6738 - accuracy: 0.5836 - val_loss: 8356.1553 - val_accuracy: 0.6059
# Epoch 182/350
# 9/9 [==============================] - 0s 15ms/step - loss: 0.6723 - accuracy: 0.5892 - val_loss: 6585.2837 - val_accuracy: 0.6017
# Epoch 183/350
# 9/9 [==============================] - 0s 15ms/step - loss: 0.6708 - accuracy: 0.5888 - val_loss: 9787.6377 - val_accuracy: 0.6102
# Epoch 184/350
# 9/9 [==============================] - 0s 15ms/step - loss: 0.6679 - accuracy: 0.6010 - val_loss: 10034.3779 - val_accuracy: 0.6059
# Epoch 185/350
# 9/9 [==============================] - 0s 15ms/step - loss: 0.6737 - accuracy: 0.5840 - val_loss: 6310.3105 - val_accuracy: 0.6059
# Epoch 186/350
# 9/9 [==============================] - 0s 16ms/step - loss: 0.6660 - accuracy: 0.5958 - val_loss: 7686.1665 - val_accuracy: 0.6314
# Epoch 187/350
# 9/9 [==============================] - 0s 18ms/step - loss: 0.6700 - accuracy: 0.5859 - val_loss: 8300.5449 - val_accuracy: 0.6186
# Epoch 188/350
# 9/9 [==============================] - 0s 19ms/step - loss: 0.6725 - accuracy: 0.5840 - val_loss: 7810.7393 - val_accuracy: 0.6229
# Epoch 189/350
# 9/9 [==============================] - 0s 15ms/step - loss: 0.6690 - accuracy: 0.5940 - val_loss: 8493.1357 - val_accuracy: 0.6186
# Epoch 190/350
# 9/9 [==============================] - 0s 18ms/step - loss: 0.6696 - accuracy: 0.5869 - val_loss: 8007.8438 - val_accuracy: 0.6186
# Epoch 191/350
# 9/9 [==============================] - 0s 16ms/step - loss: 0.6686 - accuracy: 0.5836 - val_loss: 9128.2354 - val_accuracy: 0.6186
# Epoch 192/350
# 9/9 [==============================] - 0s 17ms/step - loss: 0.6704 - accuracy: 0.5888 - val_loss: 8606.1611 - val_accuracy: 0.6186
# Epoch 193/350
# 9/9 [==============================] - 0s 17ms/step - loss: 0.6694 - accuracy: 0.5897 - val_loss: 7885.3584 - val_accuracy: 0.6229
# Epoch 194/350
# 9/9 [==============================] - 0s 16ms/step - loss: 0.6654 - accuracy: 0.5977 - val_loss: 9932.0908 - val_accuracy: 0.6144
# Epoch 195/350
# 9/9 [==============================] - 0s 17ms/step - loss: 0.6682 - accuracy: 0.5925 - val_loss: 11584.9170 - val_accuracy: 0.6059
# Epoch 196/350
# 9/9 [==============================] - 0s 16ms/step - loss: 0.6696 - accuracy: 0.5954 - val_loss: 9587.2969 - val_accuracy: 0.6102
# Epoch 197/350
# 9/9 [==============================] - 0s 15ms/step - loss: 0.6699 - accuracy: 0.5873 - val_loss: 12482.0361 - val_accuracy: 0.6102
# Epoch 198/350
# 9/9 [==============================] - 0s 17ms/step - loss: 0.6684 - accuracy: 0.5958 - val_loss: 8992.6533 - val_accuracy: 0.6186
# Epoch 199/350
# 9/9 [==============================] - 0s 16ms/step - loss: 0.6632 - accuracy: 0.6001 - val_loss: 9383.4375 - val_accuracy: 0.6186
# Epoch 200/350
# 9/9 [==============================] - 0s 16ms/step - loss: 0.6660 - accuracy: 0.5944 - val_loss: 6812.1567 - val_accuracy: 0.6059
# Epoch 201/350
# 9/9 [==============================] - 0s 16ms/step - loss: 0.6743 - accuracy: 0.5907 - val_loss: 10008.5654 - val_accuracy: 0.6102
# Epoch 202/350
# 9/9 [==============================] - 0s 18ms/step - loss: 0.6649 - accuracy: 0.5878 - val_loss: 9183.1514 - val_accuracy: 0.6186
# Epoch 203/350
# 9/9 [==============================] - 0s 16ms/step - loss: 0.6667 - accuracy: 0.5892 - val_loss: 7764.8535 - val_accuracy: 0.6144
# Epoch 204/350
# 9/9 [==============================] - 0s 15ms/step - loss: 0.6700 - accuracy: 0.5873 - val_loss: 11099.5879 - val_accuracy: 0.6102
# Epoch 205/350
# 9/9 [==============================] - 0s 15ms/step - loss: 0.6638 - accuracy: 0.5935 - val_loss: 10698.3193 - val_accuracy: 0.6102
# Epoch 206/350
# 9/9 [==============================] - 0s 16ms/step - loss: 0.6682 - accuracy: 0.5963 - val_loss: 10387.9590 - val_accuracy: 0.6144
# Epoch 207/350
# 9/9 [==============================] - 0s 16ms/step - loss: 0.6682 - accuracy: 0.5916 - val_loss: 10610.4736 - val_accuracy: 0.6144
# Epoch 208/350
# 9/9 [==============================] - 0s 15ms/step - loss: 0.6671 - accuracy: 0.5888 - val_loss: 9886.5225 - val_accuracy: 0.6229
# Epoch 209/350
# 9/9 [==============================] - 0s 18ms/step - loss: 0.6674 - accuracy: 0.6034 - val_loss: 14983.0713 - val_accuracy: 0.6102
# Epoch 210/350
# 9/9 [==============================] - 0s 17ms/step - loss: 0.6687 - accuracy: 0.5873 - val_loss: 10839.7139 - val_accuracy: 0.6271
# Epoch 211/350
# 9/9 [==============================] - 0s 16ms/step - loss: 0.6697 - accuracy: 0.5883 - val_loss: 9926.9102 - val_accuracy: 0.6229
# Epoch 212/350
# 9/9 [==============================] - 0s 15ms/step - loss: 0.6659 - accuracy: 0.6048 - val_loss: 11872.3223 - val_accuracy: 0.5932
# Epoch 213/350
# 9/9 [==============================] - 0s 15ms/step - loss: 0.6617 - accuracy: 0.6072 - val_loss: 13956.2637 - val_accuracy: 0.6144
# Epoch 214/350
# 9/9 [==============================] - 0s 17ms/step - loss: 0.6695 - accuracy: 0.5883 - val_loss: 14152.9219 - val_accuracy: 0.6144
# Epoch 215/350
# 9/9 [==============================] - 0s 15ms/step - loss: 0.6662 - accuracy: 0.5973 - val_loss: 10910.7119 - val_accuracy: 0.6144
# Epoch 216/350
# 9/9 [==============================] - 0s 19ms/step - loss: 0.6664 - accuracy: 0.5930 - val_loss: 12101.1953 - val_accuracy: 0.6102
# Epoch 217/350
# 9/9 [==============================] - 0s 20ms/step - loss: 0.6667 - accuracy: 0.5930 - val_loss: 14042.0371 - val_accuracy: 0.5975
# Epoch 218/350
# 9/9 [==============================] - 0s 16ms/step - loss: 0.6668 - accuracy: 0.5873 - val_loss: 10742.4736 - val_accuracy: 0.6229
# Epoch 219/350
# 9/9 [==============================] - 0s 15ms/step - loss: 0.6686 - accuracy: 0.5968 - val_loss: 10371.8467 - val_accuracy: 0.6229
# Epoch 220/350
# 9/9 [==============================] - 0s 17ms/step - loss: 0.6708 - accuracy: 0.5916 - val_loss: 10075.6055 - val_accuracy: 0.6229
# Epoch 221/350
# 9/9 [==============================] - 0s 16ms/step - loss: 0.6708 - accuracy: 0.5892 - val_loss: 11079.5850 - val_accuracy: 0.6059
# Epoch 222/350
# 9/9 [==============================] - 0s 20ms/step - loss: 0.6681 - accuracy: 0.5897 - val_loss: 9838.4121 - val_accuracy: 0.6186
# Epoch 223/350
# 9/9 [==============================] - 0s 28ms/step - loss: 0.6610 - accuracy: 0.6034 - val_loss: 14755.5430 - val_accuracy: 0.6059
# Epoch 224/350
# 9/9 [==============================] - 0s 24ms/step - loss: 0.6671 - accuracy: 0.5925 - val_loss: 12824.6592 - val_accuracy: 0.6059
# Epoch 225/350
# 9/9 [==============================] - 0s 25ms/step - loss: 0.6626 - accuracy: 0.6043 - val_loss: 11231.7832 - val_accuracy: 0.6229
# Epoch 226/350
# 9/9 [==============================] - 0s 23ms/step - loss: 0.6665 - accuracy: 0.5883 - val_loss: 11203.9268 - val_accuracy: 0.6229
# Epoch 227/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.6697 - accuracy: 0.5944 - val_loss: 10549.1367 - val_accuracy: 0.6271
# Epoch 228/350
# 9/9 [==============================] - 0s 26ms/step - loss: 0.6670 - accuracy: 0.5916 - val_loss: 11178.7852 - val_accuracy: 0.6186
# Epoch 229/350
# 9/9 [==============================] - 0s 26ms/step - loss: 0.6621 - accuracy: 0.6105 - val_loss: 16478.6328 - val_accuracy: 0.6229
# Epoch 230/350
# 9/9 [==============================] - 0s 26ms/step - loss: 0.6675 - accuracy: 0.6058 - val_loss: 11463.1895 - val_accuracy: 0.6314
# Epoch 231/350
# 9/9 [==============================] - 0s 24ms/step - loss: 0.6648 - accuracy: 0.5968 - val_loss: 9422.5020 - val_accuracy: 0.6229
# Epoch 232/350
# 9/9 [==============================] - 0s 26ms/step - loss: 0.6637 - accuracy: 0.6001 - val_loss: 15369.6514 - val_accuracy: 0.6144
# Epoch 233/350
# 9/9 [==============================] - 0s 20ms/step - loss: 0.6702 - accuracy: 0.5859 - val_loss: 19492.3281 - val_accuracy: 0.6017
# Epoch 234/350
# 9/9 [==============================] - 0s 23ms/step - loss: 0.6659 - accuracy: 0.5958 - val_loss: 10026.8125 - val_accuracy: 0.6186
# Epoch 235/350
# 9/9 [==============================] - 0s 26ms/step - loss: 0.6682 - accuracy: 0.5907 - val_loss: 13166.1133 - val_accuracy: 0.6017
# Epoch 236/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.6651 - accuracy: 0.5963 - val_loss: 10982.1660 - val_accuracy: 0.6229
# Epoch 237/350
# 9/9 [==============================] - 0s 26ms/step - loss: 0.6663 - accuracy: 0.5921 - val_loss: 13901.4385 - val_accuracy: 0.5975
# Epoch 238/350
# 9/9 [==============================] - 0s 29ms/step - loss: 0.6600 - accuracy: 0.6029 - val_loss: 10570.1025 - val_accuracy: 0.6102
# Epoch 239/350
# 9/9 [==============================] - 0s 25ms/step - loss: 0.6653 - accuracy: 0.6001 - val_loss: 15578.9111 - val_accuracy: 0.6102
# Epoch 240/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.6655 - accuracy: 0.5949 - val_loss: 10716.2490 - val_accuracy: 0.6144
# Epoch 241/350
# 9/9 [==============================] - 0s 26ms/step - loss: 0.6661 - accuracy: 0.5963 - val_loss: 10813.3018 - val_accuracy: 0.6229
# Epoch 242/350
# 9/9 [==============================] - 0s 26ms/step - loss: 0.6650 - accuracy: 0.6025 - val_loss: 9013.6885 - val_accuracy: 0.6271
# Epoch 243/350
# 9/9 [==============================] - 0s 23ms/step - loss: 0.6614 - accuracy: 0.5973 - val_loss: 16244.9121 - val_accuracy: 0.6059
# Epoch 244/350
# 9/9 [==============================] - 0s 23ms/step - loss: 0.6655 - accuracy: 0.5897 - val_loss: 16620.2188 - val_accuracy: 0.6186
# Epoch 245/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.6677 - accuracy: 0.6015 - val_loss: 13951.0264 - val_accuracy: 0.6017
# Epoch 246/350
# 9/9 [==============================] - 0s 24ms/step - loss: 0.6641 - accuracy: 0.5996 - val_loss: 10030.4375 - val_accuracy: 0.6144
# Epoch 247/350
# 9/9 [==============================] - 0s 23ms/step - loss: 0.6651 - accuracy: 0.5968 - val_loss: 16892.6055 - val_accuracy: 0.5975
# Epoch 248/350
# 9/9 [==============================] - 0s 20ms/step - loss: 0.6665 - accuracy: 0.5949 - val_loss: 12342.0576 - val_accuracy: 0.6186
# Epoch 249/350
# 9/9 [==============================] - 0s 27ms/step - loss: 0.6669 - accuracy: 0.6029 - val_loss: 9958.9619 - val_accuracy: 0.6186
# Epoch 250/350
# 9/9 [==============================] - 0s 24ms/step - loss: 0.6644 - accuracy: 0.5977 - val_loss: 8702.4746 - val_accuracy: 0.6102
# Epoch 251/350
# 9/9 [==============================] - 0s 23ms/step - loss: 0.6673 - accuracy: 0.5963 - val_loss: 14457.6455 - val_accuracy: 0.6017
# Epoch 252/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.6614 - accuracy: 0.5940 - val_loss: 15663.9072 - val_accuracy: 0.6017
# Epoch 253/350
# 9/9 [==============================] - 0s 20ms/step - loss: 0.6597 - accuracy: 0.6039 - val_loss: 12137.8701 - val_accuracy: 0.6186
# Epoch 254/350
# 9/9 [==============================] - 0s 18ms/step - loss: 0.6627 - accuracy: 0.6081 - val_loss: 16723.5898 - val_accuracy: 0.6144
# Epoch 255/350
# 9/9 [==============================] - 0s 20ms/step - loss: 0.6669 - accuracy: 0.5940 - val_loss: 12247.2881 - val_accuracy: 0.6229
# Epoch 256/350
# 9/9 [==============================] - 0s 18ms/step - loss: 0.6640 - accuracy: 0.5996 - val_loss: 16968.5957 - val_accuracy: 0.6059
# Epoch 257/350
# 9/9 [==============================] - 0s 17ms/step - loss: 0.6642 - accuracy: 0.5973 - val_loss: 18693.1289 - val_accuracy: 0.6144
# Epoch 258/350
# 9/9 [==============================] - 0s 23ms/step - loss: 0.6649 - accuracy: 0.6039 - val_loss: 17964.1562 - val_accuracy: 0.6186
# Epoch 259/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.6633 - accuracy: 0.6039 - val_loss: 12039.8506 - val_accuracy: 0.6271
# Epoch 260/350
# 9/9 [==============================] - 0s 24ms/step - loss: 0.6660 - accuracy: 0.5963 - val_loss: 12304.9473 - val_accuracy: 0.6229
# Epoch 261/350
# 9/9 [==============================] - 0s 25ms/step - loss: 0.6617 - accuracy: 0.6015 - val_loss: 11633.5547 - val_accuracy: 0.6144
# Epoch 262/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.6593 - accuracy: 0.6095 - val_loss: 10519.8164 - val_accuracy: 0.6102
# Epoch 263/350
# 9/9 [==============================] - 0s 24ms/step - loss: 0.6644 - accuracy: 0.6062 - val_loss: 16237.9453 - val_accuracy: 0.6186
# Epoch 264/350
# 9/9 [==============================] - 0s 25ms/step - loss: 0.6619 - accuracy: 0.5963 - val_loss: 22435.9902 - val_accuracy: 0.6144
# Epoch 265/350
# 9/9 [==============================] - 0s 23ms/step - loss: 0.6642 - accuracy: 0.5987 - val_loss: 18621.8418 - val_accuracy: 0.6017
# Epoch 266/350
# 9/9 [==============================] - 0s 25ms/step - loss: 0.6611 - accuracy: 0.6095 - val_loss: 20580.4805 - val_accuracy: 0.6102
# Epoch 267/350
# 9/9 [==============================] - 0s 25ms/step - loss: 0.6589 - accuracy: 0.6105 - val_loss: 15571.9229 - val_accuracy: 0.6102
# Epoch 268/350
# 9/9 [==============================] - 0s 24ms/step - loss: 0.6644 - accuracy: 0.5925 - val_loss: 12067.9395 - val_accuracy: 0.6144
# Epoch 269/350
# 9/9 [==============================] - 0s 23ms/step - loss: 0.6646 - accuracy: 0.5949 - val_loss: 17933.7715 - val_accuracy: 0.6017
# Epoch 270/350
# 9/9 [==============================] - 0s 20ms/step - loss: 0.6606 - accuracy: 0.6114 - val_loss: 22751.3105 - val_accuracy: 0.6017
# Epoch 271/350
# 9/9 [==============================] - 0s 24ms/step - loss: 0.6591 - accuracy: 0.6053 - val_loss: 15229.6514 - val_accuracy: 0.6229
# Epoch 272/350
# 9/9 [==============================] - 0s 30ms/step - loss: 0.6616 - accuracy: 0.6062 - val_loss: 12957.1963 - val_accuracy: 0.6229
# Epoch 273/350
# 9/9 [==============================] - 0s 23ms/step - loss: 0.6632 - accuracy: 0.6086 - val_loss: 17072.4062 - val_accuracy: 0.6059
# Epoch 274/350
# 9/9 [==============================] - 0s 24ms/step - loss: 0.6608 - accuracy: 0.6020 - val_loss: 19289.3516 - val_accuracy: 0.6059
# Epoch 275/350
# 9/9 [==============================] - 0s 23ms/step - loss: 0.6568 - accuracy: 0.6119 - val_loss: 14719.2178 - val_accuracy: 0.6271
# Epoch 276/350
# 9/9 [==============================] - 0s 24ms/step - loss: 0.6615 - accuracy: 0.6058 - val_loss: 22285.5176 - val_accuracy: 0.6059
# Epoch 277/350
# 9/9 [==============================] - 0s 25ms/step - loss: 0.6680 - accuracy: 0.5892 - val_loss: 17768.9043 - val_accuracy: 0.6017
# Epoch 278/350
# 9/9 [==============================] - 0s 24ms/step - loss: 0.6663 - accuracy: 0.6048 - val_loss: 15014.8477 - val_accuracy: 0.6229
# Epoch 279/350
# 9/9 [==============================] - 0s 25ms/step - loss: 0.6628 - accuracy: 0.5996 - val_loss: 19531.1348 - val_accuracy: 0.6017
# Epoch 280/350
# 9/9 [==============================] - 0s 24ms/step - loss: 0.6567 - accuracy: 0.6025 - val_loss: 17943.3008 - val_accuracy: 0.6102
# Epoch 281/350
# 9/9 [==============================] - 0s 27ms/step - loss: 0.6614 - accuracy: 0.6100 - val_loss: 15690.7764 - val_accuracy: 0.6314
# Epoch 282/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.6649 - accuracy: 0.6001 - val_loss: 22402.0430 - val_accuracy: 0.6017
# Epoch 283/350
# 9/9 [==============================] - 0s 26ms/step - loss: 0.6656 - accuracy: 0.6020 - val_loss: 18451.7422 - val_accuracy: 0.6017
# Epoch 284/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.6626 - accuracy: 0.6029 - val_loss: 17083.2285 - val_accuracy: 0.6017
# Epoch 285/350
# ...
# Epoch 242/350
# 9/9 [==============================] - 0s 19ms/step - loss: 0.6617 - accuracy: 0.5979 - val_loss: 29153.1953 - val_accuracy: 0.5532
# Epoch 243/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.6572 - accuracy: 0.6159 - val_loss: 25469.6270 - val_accuracy: 0.5447
# Epoch 244/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.6532 - accuracy: 0.6277 - val_loss: 19699.0312 - val_accuracy: 0.5489
# Epoch 245/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.6576 - accuracy: 0.6168 - val_loss: 27884.2559 - val_accuracy: 0.5532
# Epoch 246/350
# 9/9 [==============================] - 0s 19ms/step - loss: 0.6541 - accuracy: 0.6192 - val_loss: 26846.0430 - val_accuracy: 0.5532
# Epoch 247/350
# 9/9 [==============================] - 0s 20ms/step - loss: 0.6581 - accuracy: 0.6173 - val_loss: 21248.4180 - val_accuracy: 0.5447
# Epoch 248/350
# 9/9 [==============================] - 0s 19ms/step - loss: 0.6600 - accuracy: 0.6116 - val_loss: 23982.9785 - val_accuracy: 0.5532
# Epoch 249/350
# 9/9 [==============================] - 0s 19ms/step - loss: 0.6546 - accuracy: 0.6177 - val_loss: 23733.6387 - val_accuracy: 0.5532
# Epoch 250/350
# 9/9 [==============================] - 0s 18ms/step - loss: 0.6554 - accuracy: 0.6192 - val_loss: 36978.5977 - val_accuracy: 0.5660
# Epoch 251/350
# 9/9 [==============================] - 0s 20ms/step - loss: 0.6599 - accuracy: 0.6055 - val_loss: 28882.5547 - val_accuracy: 0.5574
# Epoch 252/350
# 9/9 [==============================] - 0s 19ms/step - loss: 0.6525 - accuracy: 0.6135 - val_loss: 23570.4824 - val_accuracy: 0.5532
# Epoch 253/350
# 9/9 [==============================] - 0s 19ms/step - loss: 0.6584 - accuracy: 0.6196 - val_loss: 30877.6230 - val_accuracy: 0.5660
# Epoch 254/350
# 9/9 [==============================] - 0s 19ms/step - loss: 0.6567 - accuracy: 0.6107 - val_loss: 26095.8438 - val_accuracy: 0.5489
# Epoch 255/350
# 9/9 [==============================] - 0s 19ms/step - loss: 0.6528 - accuracy: 0.6220 - val_loss: 23560.3535 - val_accuracy: 0.5447
# Epoch 256/350
# 9/9 [==============================] - 0s 20ms/step - loss: 0.6569 - accuracy: 0.6017 - val_loss: 22238.0293 - val_accuracy: 0.5574
# Epoch 257/350
# 9/9 [==============================] - 0s 20ms/step - loss: 0.6581 - accuracy: 0.6064 - val_loss: 20691.2559 - val_accuracy: 0.5362
# Epoch 258/350
# 9/9 [==============================] - 0s 20ms/step - loss: 0.6587 - accuracy: 0.6159 - val_loss: 26694.8906 - val_accuracy: 0.5574
# Epoch 259/350
# 9/9 [==============================] - 0s 19ms/step - loss: 0.6537 - accuracy: 0.6092 - val_loss: 29883.7852 - val_accuracy: 0.5447
# Epoch 260/350
# 9/9 [==============================] - 0s 19ms/step - loss: 0.6561 - accuracy: 0.6149 - val_loss: 26671.6641 - val_accuracy: 0.5574
# Epoch 261/350
# 9/9 [==============================] - 0s 19ms/step - loss: 0.6517 - accuracy: 0.6092 - val_loss: 32460.6719 - val_accuracy: 0.5532
# Epoch 262/350
# 9/9 [==============================] - 0s 19ms/step - loss: 0.6563 - accuracy: 0.6111 - val_loss: 22626.1523 - val_accuracy: 0.5532
# Epoch 263/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.6576 - accuracy: 0.6102 - val_loss: 24544.2363 - val_accuracy: 0.5617
# Epoch 264/350
# 9/9 [==============================] - 0s 19ms/step - loss: 0.6556 - accuracy: 0.6239 - val_loss: 27315.4824 - val_accuracy: 0.5362
# Epoch 265/350
# 9/9 [==============================] - 0s 19ms/step - loss: 0.6596 - accuracy: 0.5956 - val_loss: 25523.7090 - val_accuracy: 0.5447
# Epoch 266/350
# 9/9 [==============================] - 0s 19ms/step - loss: 0.6551 - accuracy: 0.6201 - val_loss: 31709.9941 - val_accuracy: 0.5447
# Epoch 267/350
# 9/9 [==============================] - 0s 19ms/step - loss: 0.6571 - accuracy: 0.6041 - val_loss: 25671.4395 - val_accuracy: 0.5574
# Epoch 268/350
# 9/9 [==============================] - 0s 17ms/step - loss: 0.6503 - accuracy: 0.6173 - val_loss: 21634.0391 - val_accuracy: 0.5404
# Epoch 269/350
# 9/9 [==============================] - 0s 20ms/step - loss: 0.6569 - accuracy: 0.6097 - val_loss: 30957.6621 - val_accuracy: 0.5532
# Epoch 270/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.6510 - accuracy: 0.6135 - val_loss: 22317.4688 - val_accuracy: 0.5404
# Epoch 271/350
# 9/9 [==============================] - 0s 17ms/step - loss: 0.6559 - accuracy: 0.6168 - val_loss: 25916.8379 - val_accuracy: 0.5532
# Epoch 272/350
# 9/9 [==============================] - 0s 18ms/step - loss: 0.6540 - accuracy: 0.6144 - val_loss: 22112.0332 - val_accuracy: 0.5319
# Epoch 273/350
# 9/9 [==============================] - 0s 24ms/step - loss: 0.6582 - accuracy: 0.6055 - val_loss: 26326.3203 - val_accuracy: 0.5532
# Epoch 274/350
# 9/9 [==============================] - 0s 25ms/step - loss: 0.6524 - accuracy: 0.6116 - val_loss: 28525.5684 - val_accuracy: 0.5447
# Epoch 275/350
# 9/9 [==============================] - 0s 25ms/step - loss: 0.6537 - accuracy: 0.6130 - val_loss: 23845.7949 - val_accuracy: 0.5574
# Epoch 276/350
# 9/9 [==============================] - 0s 23ms/step - loss: 0.6569 - accuracy: 0.6050 - val_loss: 34726.0117 - val_accuracy: 0.5447
# Epoch 277/350
# 9/9 [==============================] - 0s 24ms/step - loss: 0.6523 - accuracy: 0.6196 - val_loss: 24232.3145 - val_accuracy: 0.5532
# Epoch 278/350
# 9/9 [==============================] - 0s 26ms/step - loss: 0.6551 - accuracy: 0.6097 - val_loss: 26596.1348 - val_accuracy: 0.5574
# Epoch 279/350
# 9/9 [==============================] - 0s 25ms/step - loss: 0.6549 - accuracy: 0.6130 - val_loss: 37416.2266 - val_accuracy: 0.5489
# Epoch 280/350
# 9/9 [==============================] - 0s 25ms/step - loss: 0.6559 - accuracy: 0.6182 - val_loss: 30653.5820 - val_accuracy: 0.5447
# Epoch 281/350
# 9/9 [==============================] - 0s 27ms/step - loss: 0.6477 - accuracy: 0.6310 - val_loss: 25126.6465 - val_accuracy: 0.5362
# Epoch 282/350
# 9/9 [==============================] - 0s 28ms/step - loss: 0.6588 - accuracy: 0.6159 - val_loss: 31108.1523 - val_accuracy: 0.5447
# Epoch 283/350
# 9/9 [==============================] - 0s 28ms/step - loss: 0.6551 - accuracy: 0.5956 - val_loss: 25568.7578 - val_accuracy: 0.5532
# Epoch 284/350
# 9/9 [==============================] - 0s 27ms/step - loss: 0.6506 - accuracy: 0.6206 - val_loss: 27658.8984 - val_accuracy: 0.5617
# Epoch 285/350
# 9/9 [==============================] - 0s 23ms/step - loss: 0.6521 - accuracy: 0.6159 - val_loss: 40606.2656 - val_accuracy: 0.5660
# Epoch 286/350
# 9/9 [==============================] - 0s 27ms/step - loss: 0.6503 - accuracy: 0.6295 - val_loss: 27163.5625 - val_accuracy: 0.5574
# Epoch 287/350
# 9/9 [==============================] - 0s 28ms/step - loss: 0.6466 - accuracy: 0.6272 - val_loss: 40977.0820 - val_accuracy: 0.5660
# Epoch 288/350
# 9/9 [==============================] - 0s 25ms/step - loss: 0.6549 - accuracy: 0.6187 - val_loss: 32508.1699 - val_accuracy: 0.5574
# Epoch 289/350
# 9/9 [==============================] - 0s 24ms/step - loss: 0.6493 - accuracy: 0.6182 - val_loss: 31703.0723 - val_accuracy: 0.5532
# Epoch 290/350
# 9/9 [==============================] - 0s 27ms/step - loss: 0.6515 - accuracy: 0.6262 - val_loss: 37058.9062 - val_accuracy: 0.5489
# Epoch 291/350
# 9/9 [==============================] - 0s 23ms/step - loss: 0.6507 - accuracy: 0.6121 - val_loss: 30634.5137 - val_accuracy: 0.5532
# Epoch 292/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.6489 - accuracy: 0.6206 - val_loss: 31310.5801 - val_accuracy: 0.5489
# Epoch 293/350
# 9/9 [==============================] - 0s 24ms/step - loss: 0.6524 - accuracy: 0.6168 - val_loss: 37703.0508 - val_accuracy: 0.5447
# Epoch 294/350
# 9/9 [==============================] - 0s 24ms/step - loss: 0.6497 - accuracy: 0.6140 - val_loss: 30927.4434 - val_accuracy: 0.5574
# Epoch 295/350
# 9/9 [==============================] - 0s 25ms/step - loss: 0.6500 - accuracy: 0.6083 - val_loss: 39976.2656 - val_accuracy: 0.5660
# Epoch 296/350
# 9/9 [==============================] - 0s 27ms/step - loss: 0.6497 - accuracy: 0.6262 - val_loss: 35463.7656 - val_accuracy: 0.5532
# Epoch 297/350
# 9/9 [==============================] - 0s 25ms/step - loss: 0.6459 - accuracy: 0.6168 - val_loss: 40028.1445 - val_accuracy: 0.5532
# Epoch 298/350
# 9/9 [==============================] - 0s 24ms/step - loss: 0.6512 - accuracy: 0.6244 - val_loss: 30770.8750 - val_accuracy: 0.5532
# Epoch 299/350
# 9/9 [==============================] - 0s 24ms/step - loss: 0.6489 - accuracy: 0.6154 - val_loss: 36292.9844 - val_accuracy: 0.5574
# Epoch 300/350
# 9/9 [==============================] - 0s 27ms/step - loss: 0.6479 - accuracy: 0.6366 - val_loss: 31651.6602 - val_accuracy: 0.5532
# Epoch 301/350
# 9/9 [==============================] - 0s 25ms/step - loss: 0.6530 - accuracy: 0.6173 - val_loss: 31153.6094 - val_accuracy: 0.5532
# Epoch 302/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.6510 - accuracy: 0.6187 - val_loss: 37799.7617 - val_accuracy: 0.5532
# Epoch 303/350
# 9/9 [==============================] - 0s 23ms/step - loss: 0.6522 - accuracy: 0.6163 - val_loss: 43091.0742 - val_accuracy: 0.5660
# Epoch 304/350
# 9/9 [==============================] - 0s 20ms/step - loss: 0.6473 - accuracy: 0.6192 - val_loss: 48526.4219 - val_accuracy: 0.5660
# Epoch 305/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.6490 - accuracy: 0.6272 - val_loss: 32086.4922 - val_accuracy: 0.5489
# Epoch 306/350
# 9/9 [==============================] - 0s 20ms/step - loss: 0.6465 - accuracy: 0.6234 - val_loss: 45748.8086 - val_accuracy: 0.5660
# Epoch 307/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.6521 - accuracy: 0.6045 - val_loss: 40310.3750 - val_accuracy: 0.5532
# Epoch 308/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.6461 - accuracy: 0.6300 - val_loss: 38523.2422 - val_accuracy: 0.5532
# Epoch 309/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.6537 - accuracy: 0.6206 - val_loss: 41051.0391 - val_accuracy: 0.5574
# Epoch 310/350
# 9/9 [==============================] - 0s 20ms/step - loss: 0.6464 - accuracy: 0.6234 - val_loss: 38170.5234 - val_accuracy: 0.5447
# Epoch 311/350
# 9/9 [==============================] - 0s 20ms/step - loss: 0.6510 - accuracy: 0.6163 - val_loss: 38179.0625 - val_accuracy: 0.5617
# Epoch 312/350
# 9/9 [==============================] - 0s 20ms/step - loss: 0.6499 - accuracy: 0.6239 - val_loss: 41862.4492 - val_accuracy: 0.5532
# Epoch 313/350
# 9/9 [==============================] - 0s 20ms/step - loss: 0.6491 - accuracy: 0.6234 - val_loss: 45518.6523 - val_accuracy: 0.5489
# Epoch 314/350
# 9/9 [==============================] - 0s 19ms/step - loss: 0.6492 - accuracy: 0.6092 - val_loss: 41665.0391 - val_accuracy: 0.5532
# Epoch 315/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.6499 - accuracy: 0.6234 - val_loss: 34302.7695 - val_accuracy: 0.5574
# Epoch 316/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.6497 - accuracy: 0.6154 - val_loss: 51707.2227 - val_accuracy: 0.5660
# Epoch 317/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.6429 - accuracy: 0.6206 - val_loss: 48137.2227 - val_accuracy: 0.5617
# Epoch 318/350
# 9/9 [==============================] - 0s 18ms/step - loss: 0.6444 - accuracy: 0.6343 - val_loss: 50930.4180 - val_accuracy: 0.5574
# Epoch 319/350
# 9/9 [==============================] - 0s 18ms/step - loss: 0.6476 - accuracy: 0.6177 - val_loss: 48655.7539 - val_accuracy: 0.5489
# Epoch 320/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.6470 - accuracy: 0.6182 - val_loss: 50185.0195 - val_accuracy: 0.5532
# Epoch 321/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.6418 - accuracy: 0.6442 - val_loss: 38447.6836 - val_accuracy: 0.5532
# Epoch 322/350
# 9/9 [==============================] - 0s 20ms/step - loss: 0.6464 - accuracy: 0.6210 - val_loss: 44643.1797 - val_accuracy: 0.5447
# Epoch 323/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.6518 - accuracy: 0.6177 - val_loss: 39082.9844 - val_accuracy: 0.5489
# Epoch 324/350
# 9/9 [==============================] - 0s 18ms/step - loss: 0.6440 - accuracy: 0.6305 - val_loss: 45697.7891 - val_accuracy: 0.5574
# Epoch 325/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.6474 - accuracy: 0.6338 - val_loss: 44154.6133 - val_accuracy: 0.5574
# Epoch 326/350
# 9/9 [==============================] - 0s 20ms/step - loss: 0.6414 - accuracy: 0.6376 - val_loss: 44525.4375 - val_accuracy: 0.5574
# Epoch 327/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.6384 - accuracy: 0.6361 - val_loss: 43914.0898 - val_accuracy: 0.5617
# Epoch 328/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.6449 - accuracy: 0.6258 - val_loss: 49206.2656 - val_accuracy: 0.5532
# Epoch 329/350
# 9/9 [==============================] - 0s 19ms/step - loss: 0.6445 - accuracy: 0.6338 - val_loss: 35489.0273 - val_accuracy: 0.5532
# Epoch 330/350
# 9/9 [==============================] - 0s 17ms/step - loss: 0.6486 - accuracy: 0.6234 - val_loss: 48236.9805 - val_accuracy: 0.5489
# Epoch 331/350
# 9/9 [==============================] - 0s 19ms/step - loss: 0.6454 - accuracy: 0.6173 - val_loss: 48297.0781 - val_accuracy: 0.5574
# Epoch 332/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.6431 - accuracy: 0.6295 - val_loss: 46280.1953 - val_accuracy: 0.5489
# Epoch 333/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.6408 - accuracy: 0.6428 - val_loss: 54922.6016 - val_accuracy: 0.5574
# Epoch 334/350
# 9/9 [==============================] - 0s 20ms/step - loss: 0.6476 - accuracy: 0.6201 - val_loss: 50067.8398 - val_accuracy: 0.5447
# Epoch 335/350
# 9/9 [==============================] - 0s 18ms/step - loss: 0.6443 - accuracy: 0.6192 - val_loss: 46768.6094 - val_accuracy: 0.5532
# Epoch 336/350
# 9/9 [==============================] - 0s 19ms/step - loss: 0.6448 - accuracy: 0.6371 - val_loss: 57581.2031 - val_accuracy: 0.5617
# Epoch 337/350
# 9/9 [==============================] - 0s 24ms/step - loss: 0.6417 - accuracy: 0.6380 - val_loss: 53310.1328 - val_accuracy: 0.5532
# Epoch 338/350
# 9/9 [==============================] - 0s 20ms/step - loss: 0.6483 - accuracy: 0.6229 - val_loss: 43310.4023 - val_accuracy: 0.5532
# Epoch 339/350
# 9/9 [==============================] - 0s 19ms/step - loss: 0.6449 - accuracy: 0.6295 - val_loss: 42842.7109 - val_accuracy: 0.5617
# Epoch 340/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.6456 - accuracy: 0.6291 - val_loss: 44869.7695 - val_accuracy: 0.5532
# Epoch 341/350
# 9/9 [==============================] - 0s 20ms/step - loss: 0.6430 - accuracy: 0.6333 - val_loss: 54862.3828 - val_accuracy: 0.5532
# Epoch 342/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.6449 - accuracy: 0.6239 - val_loss: 38602.4766 - val_accuracy: 0.5489
# Epoch 343/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.6410 - accuracy: 0.6286 - val_loss: 43263.3516 - val_accuracy: 0.5574
# Epoch 344/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.6375 - accuracy: 0.6385 - val_loss: 39815.8945 - val_accuracy: 0.5489
# Epoch 345/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.6449 - accuracy: 0.6366 - val_loss: 47860.8984 - val_accuracy: 0.5489
# Epoch 346/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.6475 - accuracy: 0.6319 - val_loss: 39640.3516 - val_accuracy: 0.5532
# Epoch 347/350
# 9/9 [==============================] - 0s 20ms/step - loss: 0.6453 - accuracy: 0.6314 - val_loss: 47376.6133 - val_accuracy: 0.5574
# Epoch 348/350
# 9/9 [==============================] - 0s 20ms/step - loss: 0.6399 - accuracy: 0.6239 - val_loss: 48495.9414 - val_accuracy: 0.5532
# Epoch 349/350
# 9/9 [==============================] - 0s 19ms/step - loss: 0.6386 - accuracy: 0.6300 - val_loss: 50649.5273 - val_accuracy: 0.5489
# Epoch 350/350
# 9/9 [==============================] - 0s 20ms/step - loss: 0.6442 - accuracy: 0.6267 - val_loss: 44346.8164 - val_accuracy: 0.5489
