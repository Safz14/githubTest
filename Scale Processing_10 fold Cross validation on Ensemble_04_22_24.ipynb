# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Assumes scale images are on your Drive under "Images"

# !ls /content/drive/MyDrive/Images/*csv
# Out:
# /content/drive/MyDrive/Images/labels.csv
# /content/drive/MyDrive/Images/SalmonFishScalesCoordinates-V2.csv

# %%
import os.path
import numpy as np
import math
from matplotlib.image import imread
import matplotlib.pyplot as plt
import skimage.draw as drw

SCALE_WIDTH = 1500
SCALE_HEIGHT = 2000
IMAGE_HEIGHT = 1920
TRANSECT_LENGTH = 750

PATH=os.sep + os.path.join("content", "drive", "MyDrive", "Images")

def rgb2gray(rgb):
    return np.dot(rgb[...,:3], [0.2989, 0.5870, 0.1140])

def fill_boarder(gray_img, thickness, fill_value=255):
  gray_img[:thickness,:] = fill_value
  gray_img[-thickness:,:] = fill_value
  gray_img[:,:thickness] = fill_value
  gray_img[:,-thickness:] = fill_value

def scale_edge_detector(x,index, window_size, frequency_factor, orientation):
  if not (orientation == 'LR' or orientation == 'RL'):
    raise Exception("Edge detection orientation must be 'LR' or 'RL'.")

  if window_size % 2 != 1:
    raise Exception("Window size must be an odd number.")

  l_sum = np.sum(x[index - int(window_size / 2): index])
  r_sum = np.sum(x[index + 1: index + int(window_size / 2)])

  if orientation == 'LR':
    if r_sum > l_sum * frequency_factor:
      return True
    else:
      return False
  else:
    if r_sum * frequency_factor > l_sum:
      return True
    else:
      return False

def mask1d(gray_img, kernel_size, threshold=20):
  if kernel_size % 2 != 1:
    raise Exception("Kernel size must be an odd number.")


  mask = np.zeros(gray_img.shape, dtype=np.uint8)
  filter = np.ones(kernel_size) / kernel_size

  for y in range(gray_img.shape[0]):
    delta = np.convolve(gray_img[y,:], filter, mode='same') - gray_img[y,:]
    mask[y, (np.abs(delta) > threshold)] = 255.

  return mask

def mask(gray_img, kernel_size, threshold=20):
  if kernel_size % 2 != 1:
    raise Exception("Kernel size must be an odd number.")

  xd = mask1d(gray_img, 9, 20)
  yd = mask1d(np.transpose(gray_img), 9, 20).transpose()
  mask = xd /2 + yd / 2

  return mask

def denoise(gray_img, kernel_size, percent_activated_threshold=0.4):
  if kernel_size % 2 != 1:
    raise Exception("Kernel size must be an odd number.")

  activation_cutoff = percent_activated_threshold * kernel_size * kernel_size * 255
  denoised_img = gray_img.copy()

  for j in range(int(kernel_size / 2), gray_img.shape[0] - int(kernel_size / 2)):
    for k in range(int(kernel_size / 2), gray_img.shape[1] - int(kernel_size / 2)):
      if gray_img[j, k] > 120:
        if np.sum(gray_img[j:j+kernel_size,k:k+kernel_size]) < activation_cutoff:
          denoised_img[j, k] = 0

  return denoised_img

def detect_scale_contour(gray_img, padding=25):
  contour = []

  for j in range(padding, gray_img.shape[0] - padding):
    k = padding
    k_min = padding

    # Burn in period to make sure we are not detecting a scale on the edge
    while k < gray_img.shape[1] - padding and np.sum(gray_img[j, k-10:k+25]) > 30 * 255:
      k = k + 1

    while k < gray_img.shape[1] - padding:
      if gray_img[j, k] > 0 and scale_edge_detector(gray_img[j,:], k, 25, 5, 'LR'):
        contour.append((j, k))
        k_min = k
        k = gray_img.shape[1] - padding
      k = k + 1

    # Burn in period to make sure we are not detecting a scale on the edge
    while k > k_min and np.sum(gray_img[j, k-25:k+10]) > 30 * 255:
      k = k - 1

    while k > k_min:
      if gray_img[j, k] > 0 and scale_edge_detector(gray_img[j,:], k, 25, 5, 'RL'):
        contour.append((j, k))
        k = 0
      k = k - 1

  return contour

def dilate_contour(contour, thickness):

  dialated_contour = set()
  for (j, k) in contour:
    for l in range(j - thickness, j + thickness):
      for m in range(k - thickness, k + thickness):
        dialated_contour.add((l, m))

  return list(dialated_contour)

def draw_box(gray_img, top_left_point, bottom_right_point, color=255):
  j1, k1 = top_left_point
  j2, k2 = bottom_right_point

  gray_img[j1,k1:k2+1] = color
  gray_img[j2,k1:k2+1] = color
  gray_img[j1:j2+1,k1] = color
  gray_img[j1:j2+1,k2] = color

def draw_line(gray_img, mid_point, end_point, color=255):

  rr, cc = drw.line(*mid_point, *end_point)
  gray_img[rr, cc] = color

def draw_contour(size, contour, color=255):

  img = np.zeros(size, dtype=np.uint8)
  for (j, k) in contour:
    img[j, k] = color

  return img

def load_img_to_gray(file):
  img = imread(file)
  gray = rgb2gray(img)

  return gray

def show_image_and_contour(gray):

  plt.imshow(gray, cmap=plt.get_cmap('gray'))
  plt.show()

  masked_image = mask(gray, 9, 20)
  denoised_mask = denoise(masked_image, 101, .025)

  contour = detect_scale_contour(denoised_mask, 100)
  dilated_contour = dilate_contour(contour, 5)
  drawn_contour = draw_contour(denoised_mask.shape, dilated_contour)

  plt.imshow(np.abs(drawn_contour - 255), cmap=plt.get_cmap('gray'))
  plt.show()

def frame_image_w_mean(gray, j_m, k_m):
  mean_pixel_value = np.mean(gray)

  if j_m - SCALE_HEIGHT // 2 > 0:
    gray[0:j_m - SCALE_HEIGHT // 2,:] = mean_pixel_value
    gray[j_m + SCALE_HEIGHT // 2:,:] = mean_pixel_value

  if k_m - SCALE_WIDTH // 2 > 0:
    gray[:, 0:k_m - SCALE_WIDTH // 2] = mean_pixel_value
    gray[:,k_m + SCALE_WIDTH // 2:] = mean_pixel_value

  #return gray

def calculate_transect_endpoint(mid_point, offset, length):
  """
  Given an offset from a line extending direclty down from the
  mid-point, determine the coordinates of the other endpoint of
  a line that starts at the mid-point and extends in the direction
  of the offset of specified length

  :param mid_point: the coordinates of the mid-point in row-major format
  :param offset: offset angle in radians from 6 o'clock applied counter-clockwise
  :param length: describe about parameter p3
  :return: the coordinates of the endpoint in row-major format
  """
  j, k = mid_point

  return (j + int(length * math.cos(offset)),
          k + int(length * math.sin(offset)))

def calculate_transect_angle(mid_point, end_point):
  """
  Given two points, calculated the angle between a line that
  extends down from the mid-point, opens counter-clockwise
  to the line that is defined by the mid_point and end_point

  :param mid_point: the coordinates of the mid-point in row-major format
  :param end_point: the coordinates of the end-point of the transect
     in row-major format
  :return: angle in radians
  """

  offset = 0

  # if the transect angle is at pi/2 or 3 pi/2, the atan will be undefined
  if abs(mid_point[0] - end_point[0]) < 1e-5:
    if mid_point[0] < end_point[0]:
      offset = math.pi / 2
    else:
      offset = 3 * math.pi / 2

  else:
    offset = math.atan((mid_point[1] - end_point[1]) /
                       (mid_point[0] - end_point[0]))

    # if end point is above mid point, add pi to offset as it would have
    #  been caculated relative to line extending above mid point.
    if(end_point[0] < mid_point[0]):
      offset = offset + math.pi

    # if offset is negative, add to 2pi
    if(end_point[1] < mid_point[1]):
      offset = 2 * math.pi + offset

  return offset

def calculate_coordinates_of_transects(mid_point, transect_angle, offset_step_size, transect_count):
  """
  Determine the coordintates of points along transect lines at specified offsets
  from an initial trasect.

  :param mid_point: the coordinates of the mid-point in row-major format
  :param offset: transect angle in radians from 6 o'clock applied counter-clockwise
  :param offset_step_size: Offset in radians between transects
  :param transect_count: The number of transects to generate in addition to
    main transect
  :return: a list of lists containing the coordinates of points on transects
    extending out from the mid_point.  Indexing of transects alternates out
    from main transect.
  """
  transects_coordinates = []
  calculate_transect_endpoint(mid_point, transect_angle, TRANSECT_LENGTH)
  transects_coordinates.append(drw.line(*mid_point,
                                        *calculate_transect_endpoint(mid_point, transect_angle, TRANSECT_LENGTH))
                               )

  for offset in [o for i in range(1, int(transect_count / 2) + 1) for o in (i * offset_step_size, -i * offset_step_size)]:
    transects_coordinates.append(drw.line(*mid_point,
                                          *calculate_transect_endpoint(mid_point, transect_angle + offset, TRANSECT_LENGTH))
                                 )

  return transects_coordinates

def draw_transects(gray_img, transects_coordinates, color = 250):
  """
  Draws transects on a copy of grayscale image.

  :param gray_img: 2d array of a grayscale image
  :param trasects_coordinates: a list of lists containing the coordinates of points on transects
    extending out from the mid_point.  Indexing of transects alternates out
    from main transect.
  :param color: pixel value for drawn transect
  :return: 2d array representing grayscale image with transects applied
  """
  img_w_transects = np.copy(gray_img)
  j_max = gray_img.shape[0]
  k_max = gray_img.shape[1]

  for i, transect in enumerate(transects_coordinates):
    rr, cc = transect
    rr[rr >= j_max] = j_max - 1
    cc[cc >= k_max] = k_max - 1

    img_w_transects[rr, cc] = color

  return img_w_transects

def extract_transects_signals(gray_img, transects_coordinates):

  transect_signals = []
  for i, transect in enumerate(transects_coordinates):
    signal = []
    rr, cc = transect
    for j, k in zip(rr, cc):
      signal.append(gray_img[j, k])
    transect_signals.append(signal)

  return transect_signals

def convolve_transects_signals(transects_signals, kernel_size):

  filter = np.ones(kernel_size) / kernel_size
  convolved_signals = []

  for signal in transects_signals:
    convolved_signals.append(convolve_transects_signal(signal, kernel_size))

  return convolved_signals

def convolve_transects_signal(transects_signal, kernel_size):

  filter = np.ones(kernel_size) / kernel_size
  signal_length = max(len(transects_signal), kernel_size) - min(len(transects_signal), kernel_size) + 1
  offset = int((len(transects_signal) - signal_length) / 2)
  return(np.convolve(transects_signal, filter, mode='valid') - transects_signal[offset:-offset])


def plot_transect_signals(transects_signals, figure_path, figure_filename):
  n = len(transects)

  fig, axes = plt.subplots(2 * n)
  for i, signal in enumerate(transects_signals):
    axes[i].plot(signal)

  convolved_signals = convolve_transects_signals(transects_signals, 5)
  for i, signal in enumerate(convolved_signals):
    axes[i + n].plot(signal)

  fig.savefig(os.path.join(figure_path, figure_filename +".png"), format="png",
              bbox_inches="tight")

def plot_transect_signals_for_image(filepath, mid_point, transect_angle,
                                    offset_step_size, transect_count,
                                    figure_path):
  gray = load_img_to_gray(filepath)
  filename = os.path.splitext(os.path.basename(filepath))[0]

  transects = calculate_coordinates_of_transects(mid_point, transect_angle,
                                                 offset_step_size, transect_count)
  transects_signals = extract_transects_signals(gray, transects)

  plot_transect_signals(transects_signals, figure_path, filename)

# %%
import pandas as pd
from ast import literal_eval

scale_data = pd.read_csv('/content/drive/MyDrive/Images/SalmonFishScalesCoordinates-V2.csv', sep=",",
                          names=['filename', 'lt_center', 'br_center', 'end_point'],
                          dtype={'filename': 'string'},
                          converters={'lt_center': literal_eval,
                                      'br_center': literal_eval,
                                      'end_point': literal_eval},
                          header=0)
scale_data['filepath'] = scale_data.apply(lambda row: os.path.join(PATH, row['filename']) +  ".tif", axis=1)

# Switch from column-major to row major
scale_data['lt_center'] = scale_data.apply(lambda row: (row['lt_center'][1], row['lt_center'][0]) , axis = 1)
scale_data['br_center'] = scale_data.apply(lambda row: (row['br_center'][1], row['br_center'][0]) , axis = 1)
scale_data['end_point'] = scale_data.apply(lambda row: (row['end_point'][1], row['end_point'][0]) , axis = 1)

scale_data['mid_center'] = scale_data.apply(lambda row: (int((row['lt_center'][0] + row['br_center'][0]) / 2),
                                                         int((row['lt_center'][1] + row['br_center'][1]) / 2)) , axis=1)
scale_data['transect_angle'] = scale_data.apply(lambda row: calculate_transect_angle(row['mid_center'], row['end_point']), axis=1)

scale_data['id'] = scale_data.apply(lambda row: int(row['filename'].split('_')[0]), axis=1)

# Bring in labels
label_data = pd.read_csv('/content/drive/MyDrive/Images/labels.csv', sep=",",
                          names=['id', 'age', 'type', 'fold'],
                          dtype={'filename': 'int64', 'age': 'int32', 'type': 'int32', 'fold': 'int32'},
                          header=0)

# Fold in labels with scale data
scale_data = scale_data.merge(label_data, on='id', how='left', validate='many_to_one')

# Drop any rows with NaNs, recast ints
scale_data = scale_data.dropna().astype({'fold': int, 'type': int})

# %%
# Get transect signals
transects_signals = []

for index, row in scale_data.iterrows():
  #print(index, row['id'], row['filename'], row['fold'])

  gray = load_img_to_gray(row['filepath'])
  transects = calculate_coordinates_of_transects(row['mid_center'],
                                                 row['transect_angle'],
                                                 .1, 11)

  transects_signals.append([row['id'],
                           extract_transects_signals(gray, transects)],
                           )

transects_signals_df = pd.DataFrame(transects_signals, columns=['id', 'signals'])

# Merge with labels and explode
transects_signals_df = transects_signals_df.merge(label_data, on='id',
                                                  how='left',
                                                  validate='many_to_one')\
                                                  .explode('signals', ignore_index=True)\
                                                  .rename(columns={"signals": "signal"})
transects_signals_df['signal'] = transects_signals_df['signal'].apply(lambda x: np.array(x))

# Add convolved signals
transects_signals_df['convolved_signal'] = transects_signals_df.apply(lambda row: convolve_transects_signal(row['signal'], 5), axis=1)

# %% [markdown]
# ## 10 fold cross validation and Ensemble

# %%
import numpy as np
import keras
from numpy.fft import fft
from sklearn.model_selection import StratifiedKFold

df = transects_signals_df.copy(deep=True)
df['signal'] = df['signal'].apply(lambda x: np.pad(x, (0, int(1.4 * TRANSECT_LENGTH) - x.size), 'constant', constant_values=(0, 0)))
df['signal'] = df['signal'].apply(lambda x: np.flip(x))
df['convolved_signal'] = df['convolved_signal'].apply(lambda x: np.pad(x, (0, int(1.4 * TRANSECT_LENGTH) - x.size), 'constant', constant_values=(0, 0)))
df['convolved_signal'] = df['convolved_signal'].apply(lambda x: np.flip(x))
df['convolved_freq'] = df['signal'].apply(lambda x: np.abs(fft(x))[0:75])

# Define ensemble configurations and folds
NUM_MODELS_IN_ENSEMBLE = 3
NUM_FOLDS = 10
ensemble_models = []

# Initialize StratifiedKFold
skf = StratifiedKFold(n_splits=NUM_FOLDS, shuffle=True, random_state=42)

# Iterate over each fold for cross-validation
for fold, (train_index, val_index) in enumerate(skf.split(np.zeros(len(df)), df['type'])):  # Using dummy X data just to split indices based on y
    print(f"Training fold {fold + 1}/{NUM_FOLDS}")

    # Split data
    x_train, x_val = df.iloc[train_index]['convolved_freq'], df.iloc[val_index]['convolved_freq']
    y_train, y_val = df.iloc[train_index]['type'], df.iloc[val_index]['type']

    # Data normalization and preparation
    x_train = np.stack(x_train.tolist())
    x_val = np.stack(x_val.tolist())
    x_max = np.max(x_train, axis=0)
    x_train /= x_max
    x_val /= x_max

    # Model ensemble for this fold
    models = []
    for model_idx in range(NUM_MODELS_IN_ENSEMBLE):
        model = keras.Sequential([
            keras.layers.Dense(256, activation='relu'),
            keras.layers.Dropout(0.5),
            keras.layers.Dense(256, activation='relu'),
            keras.layers.Dropout(0.75),
            keras.layers.Dense(124, activation='relu'),
            keras.layers.Dropout(0.75),
            keras.layers.Dense(2, activation='softmax')
        ])
        model.compile(optimizer='rmsprop', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
        models.append(model)

    # Train each model in the ensemble
    for model in models:
        model.fit(x=x_train, y=y_train, batch_size=256, epochs=350, validation_data=(x_val, y_val), verbose=1)
        ensemble_models.append(model)  # Optionally store models if needed for later analysis or ensemble voting
# Out:
# Streaming output truncated to the last 5000 lines.
# 9/9 [==============================] - 0s 21ms/step - loss: 0.4712 - accuracy: 0.7754 - val_loss: 0.8559 - val_accuracy: 0.6128
# Epoch 303/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.4424 - accuracy: 0.7872 - val_loss: 0.8571 - val_accuracy: 0.5787
# Epoch 304/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.4305 - accuracy: 0.7971 - val_loss: 0.8449 - val_accuracy: 0.6085
# Epoch 305/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.4466 - accuracy: 0.7966 - val_loss: 0.8163 - val_accuracy: 0.6085
# Epoch 306/350
# 9/9 [==============================] - 0s 20ms/step - loss: 0.4480 - accuracy: 0.7853 - val_loss: 0.8234 - val_accuracy: 0.6043
# Epoch 307/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.4434 - accuracy: 0.7919 - val_loss: 0.8590 - val_accuracy: 0.5915
# Epoch 308/350
# 9/9 [==============================] - 0s 19ms/step - loss: 0.4275 - accuracy: 0.8056 - val_loss: 0.9263 - val_accuracy: 0.5872
# Epoch 309/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.4371 - accuracy: 0.7999 - val_loss: 0.8669 - val_accuracy: 0.5957
# Epoch 310/350
# 9/9 [==============================] - 0s 23ms/step - loss: 0.4390 - accuracy: 0.7975 - val_loss: 0.8265 - val_accuracy: 0.6128
# Epoch 311/350
# 9/9 [==============================] - 0s 27ms/step - loss: 0.4327 - accuracy: 0.7990 - val_loss: 0.8439 - val_accuracy: 0.6000
# Epoch 312/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.4369 - accuracy: 0.7961 - val_loss: 0.8951 - val_accuracy: 0.6170
# Epoch 313/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.4433 - accuracy: 0.7975 - val_loss: 0.8494 - val_accuracy: 0.6085
# Epoch 314/350
# 9/9 [==============================] - 0s 18ms/step - loss: 0.4180 - accuracy: 0.8046 - val_loss: 0.8961 - val_accuracy: 0.5957
# Epoch 315/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.4270 - accuracy: 0.8013 - val_loss: 0.8866 - val_accuracy: 0.5915
# Epoch 316/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.4005 - accuracy: 0.8193 - val_loss: 0.9007 - val_accuracy: 0.6170
# Epoch 317/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.4115 - accuracy: 0.8141 - val_loss: 0.9469 - val_accuracy: 0.6255
# Epoch 318/350
# 9/9 [==============================] - 0s 23ms/step - loss: 0.4401 - accuracy: 0.8008 - val_loss: 0.8684 - val_accuracy: 0.6340
# Epoch 319/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.4315 - accuracy: 0.8056 - val_loss: 0.8209 - val_accuracy: 0.6213
# Epoch 320/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.4263 - accuracy: 0.8013 - val_loss: 0.8449 - val_accuracy: 0.6383
# Epoch 321/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.4216 - accuracy: 0.8089 - val_loss: 0.8856 - val_accuracy: 0.6128
# Epoch 322/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.4445 - accuracy: 0.7961 - val_loss: 0.8983 - val_accuracy: 0.6128
# Epoch 323/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.4020 - accuracy: 0.8103 - val_loss: 0.9058 - val_accuracy: 0.5915
# Epoch 324/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.4392 - accuracy: 0.7938 - val_loss: 0.8682 - val_accuracy: 0.5915
# Epoch 325/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.4120 - accuracy: 0.8070 - val_loss: 0.8791 - val_accuracy: 0.5830
# Epoch 326/350
# 9/9 [==============================] - 0s 20ms/step - loss: 0.4166 - accuracy: 0.8164 - val_loss: 0.8578 - val_accuracy: 0.6213
# Epoch 327/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.4195 - accuracy: 0.8004 - val_loss: 0.9030 - val_accuracy: 0.6128
# Epoch 328/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.4343 - accuracy: 0.7928 - val_loss: 0.8974 - val_accuracy: 0.6128
# Epoch 329/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.4018 - accuracy: 0.8244 - val_loss: 0.8634 - val_accuracy: 0.6170
# Epoch 330/350
# 9/9 [==============================] - 0s 20ms/step - loss: 0.4084 - accuracy: 0.8108 - val_loss: 0.9263 - val_accuracy: 0.6298
# Epoch 331/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.4266 - accuracy: 0.8084 - val_loss: 0.9478 - val_accuracy: 0.5872
# Epoch 332/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.3996 - accuracy: 0.8216 - val_loss: 0.9543 - val_accuracy: 0.5787
# Epoch 333/350
# 9/9 [==============================] - 0s 24ms/step - loss: 0.4074 - accuracy: 0.8193 - val_loss: 0.8749 - val_accuracy: 0.6170
# Epoch 334/350
# 9/9 [==============================] - 0s 23ms/step - loss: 0.4133 - accuracy: 0.8174 - val_loss: 0.9320 - val_accuracy: 0.6085
# Epoch 335/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.4106 - accuracy: 0.8075 - val_loss: 0.9370 - val_accuracy: 0.6043
# Epoch 336/350
# 9/9 [==============================] - 0s 20ms/step - loss: 0.4041 - accuracy: 0.8178 - val_loss: 1.0515 - val_accuracy: 0.6043
# Epoch 337/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.4180 - accuracy: 0.8131 - val_loss: 1.0115 - val_accuracy: 0.5787
# Epoch 338/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.4300 - accuracy: 0.8032 - val_loss: 0.8525 - val_accuracy: 0.6128
# Epoch 339/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.4182 - accuracy: 0.8089 - val_loss: 0.9731 - val_accuracy: 0.6085
# Epoch 340/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.4085 - accuracy: 0.8174 - val_loss: 0.8871 - val_accuracy: 0.6255
# Epoch 341/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.4019 - accuracy: 0.8221 - val_loss: 0.9989 - val_accuracy: 0.5872
# Epoch 342/350
# 9/9 [==============================] - 0s 24ms/step - loss: 0.4189 - accuracy: 0.8079 - val_loss: 0.9469 - val_accuracy: 0.6213
# Epoch 343/350
# 9/9 [==============================] - 0s 23ms/step - loss: 0.3896 - accuracy: 0.8221 - val_loss: 0.9695 - val_accuracy: 0.5872
# Epoch 344/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.3957 - accuracy: 0.8197 - val_loss: 0.8842 - val_accuracy: 0.6128
# Epoch 345/350
# 9/9 [==============================] - 0s 26ms/step - loss: 0.4035 - accuracy: 0.8197 - val_loss: 1.0732 - val_accuracy: 0.5617
# Epoch 346/350
# 9/9 [==============================] - 0s 19ms/step - loss: 0.4216 - accuracy: 0.8150 - val_loss: 0.9020 - val_accuracy: 0.6255
# Epoch 347/350
# 9/9 [==============================] - 0s 23ms/step - loss: 0.3968 - accuracy: 0.8145 - val_loss: 0.9420 - val_accuracy: 0.6085
# Epoch 348/350
# 9/9 [==============================] - 0s 25ms/step - loss: 0.3796 - accuracy: 0.8268 - val_loss: 1.0147 - val_accuracy: 0.5957
# Epoch 349/350
# 9/9 [==============================] - 0s 24ms/step - loss: 0.4046 - accuracy: 0.8160 - val_loss: 1.0677 - val_accuracy: 0.6000
# Epoch 350/350
# 9/9 [==============================] - 0s 26ms/step - loss: 0.4360 - accuracy: 0.8032 - val_loss: 0.8910 - val_accuracy: 0.6213
# Epoch 1/350
# 9/9 [==============================] - 2s 70ms/step - loss: 0.8128 - accuracy: 0.4969 - val_loss: 0.6867 - val_accuracy: 0.5660
# Epoch 2/350
# 9/9 [==============================] - 0s 27ms/step - loss: 0.7356 - accuracy: 0.5021 - val_loss: 0.6865 - val_accuracy: 0.5660
# Epoch 3/350
# 9/9 [==============================] - 0s 26ms/step - loss: 0.7158 - accuracy: 0.5007 - val_loss: 0.6868 - val_accuracy: 0.5660
# Epoch 4/350
# 9/9 [==============================] - 0s 25ms/step - loss: 0.6975 - accuracy: 0.5413 - val_loss: 0.6865 - val_accuracy: 0.5660
# Epoch 5/350
# 9/9 [==============================] - 0s 27ms/step - loss: 0.6985 - accuracy: 0.5375 - val_loss: 0.6866 - val_accuracy: 0.5660
# Epoch 6/350
# 9/9 [==============================] - 0s 26ms/step - loss: 0.6921 - accuracy: 0.5437 - val_loss: 0.6854 - val_accuracy: 0.5660
# Epoch 7/350
# 9/9 [==============================] - 0s 27ms/step - loss: 0.6980 - accuracy: 0.5375 - val_loss: 0.6855 - val_accuracy: 0.5660
# Epoch 8/350
# 9/9 [==============================] - 0s 25ms/step - loss: 0.6949 - accuracy: 0.5399 - val_loss: 0.6868 - val_accuracy: 0.5660
# Epoch 9/350
# 9/9 [==============================] - 0s 26ms/step - loss: 0.6946 - accuracy: 0.5460 - val_loss: 0.6863 - val_accuracy: 0.5660
# Epoch 10/350
# 9/9 [==============================] - 0s 26ms/step - loss: 0.6887 - accuracy: 0.5545 - val_loss: 0.6859 - val_accuracy: 0.5660
# Epoch 11/350
# 9/9 [==============================] - 0s 24ms/step - loss: 0.6928 - accuracy: 0.5465 - val_loss: 0.6861 - val_accuracy: 0.5660
# Epoch 12/350
# 9/9 [==============================] - 0s 24ms/step - loss: 0.6902 - accuracy: 0.5606 - val_loss: 0.6852 - val_accuracy: 0.5660
# Epoch 13/350
# 9/9 [==============================] - 0s 27ms/step - loss: 0.6899 - accuracy: 0.5583 - val_loss: 0.6857 - val_accuracy: 0.5660
# Epoch 14/350
# 9/9 [==============================] - 0s 29ms/step - loss: 0.6876 - accuracy: 0.5630 - val_loss: 0.6854 - val_accuracy: 0.5660
# Epoch 15/350
# 9/9 [==============================] - 0s 27ms/step - loss: 0.6870 - accuracy: 0.5583 - val_loss: 0.6852 - val_accuracy: 0.5660
# Epoch 16/350
# 9/9 [==============================] - 0s 27ms/step - loss: 0.6899 - accuracy: 0.5602 - val_loss: 0.6848 - val_accuracy: 0.5660
# Epoch 17/350
# 9/9 [==============================] - 0s 23ms/step - loss: 0.6929 - accuracy: 0.5488 - val_loss: 0.6846 - val_accuracy: 0.5660
# Epoch 18/350
# 9/9 [==============================] - 0s 28ms/step - loss: 0.6891 - accuracy: 0.5521 - val_loss: 0.6849 - val_accuracy: 0.5660
# Epoch 19/350
# 9/9 [==============================] - 0s 25ms/step - loss: 0.6860 - accuracy: 0.5635 - val_loss: 0.6848 - val_accuracy: 0.5660
# Epoch 20/350
# 9/9 [==============================] - 0s 24ms/step - loss: 0.6865 - accuracy: 0.5677 - val_loss: 0.6845 - val_accuracy: 0.5660
# Epoch 21/350
# 9/9 [==============================] - 0s 20ms/step - loss: 0.6845 - accuracy: 0.5668 - val_loss: 0.6844 - val_accuracy: 0.5660
# Epoch 22/350
# 9/9 [==============================] - 0s 24ms/step - loss: 0.6886 - accuracy: 0.5526 - val_loss: 0.6849 - val_accuracy: 0.5660
# Epoch 23/350
# 9/9 [==============================] - 0s 26ms/step - loss: 0.6863 - accuracy: 0.5588 - val_loss: 0.6846 - val_accuracy: 0.5660
# Epoch 24/350
# 9/9 [==============================] - 0s 26ms/step - loss: 0.6875 - accuracy: 0.5597 - val_loss: 0.6844 - val_accuracy: 0.5660
# Epoch 25/350
# 9/9 [==============================] - 0s 25ms/step - loss: 0.6820 - accuracy: 0.5805 - val_loss: 0.6841 - val_accuracy: 0.5660
# Epoch 26/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.6870 - accuracy: 0.5621 - val_loss: 0.6841 - val_accuracy: 0.5660
# Epoch 27/350
# 9/9 [==============================] - 0s 25ms/step - loss: 0.6859 - accuracy: 0.5569 - val_loss: 0.6840 - val_accuracy: 0.5660
# Epoch 28/350
# 9/9 [==============================] - 0s 23ms/step - loss: 0.6832 - accuracy: 0.5710 - val_loss: 0.6840 - val_accuracy: 0.5660
# Epoch 29/350
# 9/9 [==============================] - 0s 27ms/step - loss: 0.6860 - accuracy: 0.5682 - val_loss: 0.6838 - val_accuracy: 0.5660
# Epoch 30/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.6872 - accuracy: 0.5649 - val_loss: 0.6839 - val_accuracy: 0.5660
# Epoch 31/350
# 9/9 [==============================] - 0s 20ms/step - loss: 0.6865 - accuracy: 0.5583 - val_loss: 0.6843 - val_accuracy: 0.5660
# Epoch 32/350
# 9/9 [==============================] - 0s 19ms/step - loss: 0.6853 - accuracy: 0.5715 - val_loss: 0.6840 - val_accuracy: 0.5660
# Epoch 33/350
# 9/9 [==============================] - 0s 23ms/step - loss: 0.6854 - accuracy: 0.5630 - val_loss: 0.6841 - val_accuracy: 0.5660
# Epoch 34/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.6844 - accuracy: 0.5654 - val_loss: 0.6836 - val_accuracy: 0.5660
# Epoch 35/350
# 9/9 [==============================] - 0s 24ms/step - loss: 0.6869 - accuracy: 0.5559 - val_loss: 0.6841 - val_accuracy: 0.5660
# Epoch 36/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.6833 - accuracy: 0.5710 - val_loss: 0.6840 - val_accuracy: 0.5660
# Epoch 37/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.6861 - accuracy: 0.5668 - val_loss: 0.6844 - val_accuracy: 0.5660
# Epoch 38/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.6854 - accuracy: 0.5616 - val_loss: 0.6839 - val_accuracy: 0.5660
# Epoch 39/350
# 9/9 [==============================] - 0s 26ms/step - loss: 0.6843 - accuracy: 0.5597 - val_loss: 0.6841 - val_accuracy: 0.5660
# Epoch 40/350
# 9/9 [==============================] - 0s 20ms/step - loss: 0.6803 - accuracy: 0.5743 - val_loss: 0.6837 - val_accuracy: 0.5660
# Epoch 41/350
# 9/9 [==============================] - 0s 23ms/step - loss: 0.6831 - accuracy: 0.5677 - val_loss: 0.6843 - val_accuracy: 0.5660
# Epoch 42/350
# 9/9 [==============================] - 0s 23ms/step - loss: 0.6833 - accuracy: 0.5682 - val_loss: 0.6839 - val_accuracy: 0.5660
# Epoch 43/350
# 9/9 [==============================] - 0s 23ms/step - loss: 0.6840 - accuracy: 0.5639 - val_loss: 0.6843 - val_accuracy: 0.5660
# Epoch 44/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.6863 - accuracy: 0.5569 - val_loss: 0.6847 - val_accuracy: 0.5660
# Epoch 45/350
# 9/9 [==============================] - 0s 20ms/step - loss: 0.6815 - accuracy: 0.5724 - val_loss: 0.6841 - val_accuracy: 0.5660
# Epoch 46/350
# 9/9 [==============================] - 0s 20ms/step - loss: 0.6853 - accuracy: 0.5644 - val_loss: 0.6844 - val_accuracy: 0.5660
# Epoch 47/350
# 9/9 [==============================] - 0s 20ms/step - loss: 0.6826 - accuracy: 0.5696 - val_loss: 0.6835 - val_accuracy: 0.5660
# Epoch 48/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.6801 - accuracy: 0.5658 - val_loss: 0.6833 - val_accuracy: 0.5660
# Epoch 49/350
# 9/9 [==============================] - 0s 27ms/step - loss: 0.6828 - accuracy: 0.5663 - val_loss: 0.6834 - val_accuracy: 0.5660
# Epoch 50/350
# 9/9 [==============================] - 0s 23ms/step - loss: 0.6844 - accuracy: 0.5734 - val_loss: 0.6838 - val_accuracy: 0.5660
# Epoch 51/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.6830 - accuracy: 0.5701 - val_loss: 0.6829 - val_accuracy: 0.5660
# Epoch 52/350
# 9/9 [==============================] - 0s 23ms/step - loss: 0.6833 - accuracy: 0.5715 - val_loss: 0.6830 - val_accuracy: 0.5660
# Epoch 53/350
# 9/9 [==============================] - 0s 23ms/step - loss: 0.6785 - accuracy: 0.5739 - val_loss: 0.6841 - val_accuracy: 0.5660
# Epoch 54/350
# 9/9 [==============================] - 0s 23ms/step - loss: 0.6812 - accuracy: 0.5701 - val_loss: 0.6839 - val_accuracy: 0.5660
# Epoch 55/350
# 9/9 [==============================] - 0s 23ms/step - loss: 0.6784 - accuracy: 0.5757 - val_loss: 0.6834 - val_accuracy: 0.5660
# Epoch 56/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.6816 - accuracy: 0.5720 - val_loss: 0.6833 - val_accuracy: 0.5660
# Epoch 57/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.6816 - accuracy: 0.5720 - val_loss: 0.6828 - val_accuracy: 0.5660
# Epoch 58/350
# 9/9 [==============================] - 0s 20ms/step - loss: 0.6776 - accuracy: 0.5833 - val_loss: 0.6833 - val_accuracy: 0.5660
# Epoch 59/350
# 9/9 [==============================] - 0s 25ms/step - loss: 0.6776 - accuracy: 0.5805 - val_loss: 0.6813 - val_accuracy: 0.5660
# Epoch 60/350
# 9/9 [==============================] - 0s 23ms/step - loss: 0.6802 - accuracy: 0.5772 - val_loss: 0.6833 - val_accuracy: 0.5660
# Epoch 61/350
# 9/9 [==============================] - 0s 23ms/step - loss: 0.6801 - accuracy: 0.5715 - val_loss: 0.6820 - val_accuracy: 0.5660
# Epoch 62/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.6808 - accuracy: 0.5616 - val_loss: 0.6814 - val_accuracy: 0.5660
# Epoch 63/350
# 9/9 [==============================] - 0s 19ms/step - loss: 0.6810 - accuracy: 0.5734 - val_loss: 0.6811 - val_accuracy: 0.5660
# Epoch 64/350
# 9/9 [==============================] - 0s 24ms/step - loss: 0.6796 - accuracy: 0.5739 - val_loss: 0.6819 - val_accuracy: 0.5660
# Epoch 65/350
# 9/9 [==============================] - 0s 20ms/step - loss: 0.6786 - accuracy: 0.5753 - val_loss: 0.6829 - val_accuracy: 0.5660
# Epoch 66/350
# 9/9 [==============================] - 0s 28ms/step - loss: 0.6797 - accuracy: 0.5772 - val_loss: 0.6816 - val_accuracy: 0.5660
# Epoch 67/350
# 9/9 [==============================] - 0s 23ms/step - loss: 0.6759 - accuracy: 0.5724 - val_loss: 0.6819 - val_accuracy: 0.5660
# Epoch 68/350
# 9/9 [==============================] - 0s 24ms/step - loss: 0.6765 - accuracy: 0.5790 - val_loss: 0.6812 - val_accuracy: 0.5660
# Epoch 69/350
# 9/9 [==============================] - 0s 30ms/step - loss: 0.6741 - accuracy: 0.5908 - val_loss: 0.6813 - val_accuracy: 0.5660
# Epoch 70/350
# 9/9 [==============================] - 0s 26ms/step - loss: 0.6758 - accuracy: 0.5885 - val_loss: 0.6806 - val_accuracy: 0.5660
# Epoch 71/350
# 9/9 [==============================] - 0s 26ms/step - loss: 0.6760 - accuracy: 0.5828 - val_loss: 0.6813 - val_accuracy: 0.5660
# Epoch 72/350
# 9/9 [==============================] - 0s 26ms/step - loss: 0.6772 - accuracy: 0.5814 - val_loss: 0.6830 - val_accuracy: 0.5660
# Epoch 73/350
# 9/9 [==============================] - 0s 28ms/step - loss: 0.6744 - accuracy: 0.5852 - val_loss: 0.6809 - val_accuracy: 0.5660
# Epoch 74/350
# 9/9 [==============================] - 0s 25ms/step - loss: 0.6765 - accuracy: 0.5753 - val_loss: 0.6790 - val_accuracy: 0.5660
# Epoch 75/350
# 9/9 [==============================] - 0s 30ms/step - loss: 0.6743 - accuracy: 0.5800 - val_loss: 0.6830 - val_accuracy: 0.5660
# Epoch 76/350
# 9/9 [==============================] - 0s 27ms/step - loss: 0.6737 - accuracy: 0.5871 - val_loss: 0.6834 - val_accuracy: 0.5660
# Epoch 77/350
# 9/9 [==============================] - 0s 29ms/step - loss: 0.6731 - accuracy: 0.5875 - val_loss: 0.6784 - val_accuracy: 0.5702
# Epoch 78/350
# 9/9 [==============================] - 0s 27ms/step - loss: 0.6700 - accuracy: 0.5918 - val_loss: 0.6814 - val_accuracy: 0.5660
# Epoch 79/350
# 9/9 [==============================] - 0s 25ms/step - loss: 0.6741 - accuracy: 0.5838 - val_loss: 0.6813 - val_accuracy: 0.5702
# Epoch 80/350
# 9/9 [==============================] - 0s 25ms/step - loss: 0.6741 - accuracy: 0.5838 - val_loss: 0.6821 - val_accuracy: 0.5660
# Epoch 81/350
# 9/9 [==============================] - 0s 26ms/step - loss: 0.6737 - accuracy: 0.5875 - val_loss: 0.6778 - val_accuracy: 0.5745
# Epoch 82/350
# 9/9 [==============================] - 0s 25ms/step - loss: 0.6716 - accuracy: 0.5951 - val_loss: 0.6771 - val_accuracy: 0.6085
# Epoch 83/350
# 9/9 [==============================] - 0s 26ms/step - loss: 0.6670 - accuracy: 0.6003 - val_loss: 0.6878 - val_accuracy: 0.5660
# Epoch 84/350
# 9/9 [==============================] - 0s 25ms/step - loss: 0.6710 - accuracy: 0.5923 - val_loss: 0.6760 - val_accuracy: 0.5915
# Epoch 85/350
# 9/9 [==============================] - 0s 27ms/step - loss: 0.6679 - accuracy: 0.5975 - val_loss: 0.6755 - val_accuracy: 0.5830
# Epoch 86/350
# 9/9 [==============================] - 0s 26ms/step - loss: 0.6632 - accuracy: 0.6116 - val_loss: 0.6762 - val_accuracy: 0.5787
# Epoch 87/350
# 9/9 [==============================] - 0s 29ms/step - loss: 0.6604 - accuracy: 0.6088 - val_loss: 0.6784 - val_accuracy: 0.5787
# Epoch 88/350
# 9/9 [==============================] - 0s 26ms/step - loss: 0.6578 - accuracy: 0.6173 - val_loss: 0.6735 - val_accuracy: 0.5830
# Epoch 89/350
# 9/9 [==============================] - 0s 25ms/step - loss: 0.6623 - accuracy: 0.6055 - val_loss: 0.6838 - val_accuracy: 0.5702
# Epoch 90/350
# 9/9 [==============================] - 0s 27ms/step - loss: 0.6573 - accuracy: 0.6069 - val_loss: 0.6879 - val_accuracy: 0.5702
# Epoch 91/350
# 9/9 [==============================] - 0s 23ms/step - loss: 0.6596 - accuracy: 0.6031 - val_loss: 0.6708 - val_accuracy: 0.6128
# Epoch 92/350
# 9/9 [==============================] - 0s 24ms/step - loss: 0.6608 - accuracy: 0.6107 - val_loss: 0.6763 - val_accuracy: 0.5830
# Epoch 93/350
# 9/9 [==============================] - 0s 25ms/step - loss: 0.6553 - accuracy: 0.6102 - val_loss: 0.6727 - val_accuracy: 0.6000
# Epoch 94/350
# 9/9 [==============================] - 0s 26ms/step - loss: 0.6586 - accuracy: 0.6182 - val_loss: 0.6812 - val_accuracy: 0.5787
# Epoch 95/350
# 9/9 [==============================] - 0s 27ms/step - loss: 0.6603 - accuracy: 0.6078 - val_loss: 0.6915 - val_accuracy: 0.5702
# Epoch 96/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.6565 - accuracy: 0.6177 - val_loss: 0.6926 - val_accuracy: 0.5702
# Epoch 97/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.6568 - accuracy: 0.6135 - val_loss: 0.6829 - val_accuracy: 0.5830
# Epoch 98/350
# 9/9 [==============================] - 0s 24ms/step - loss: 0.6620 - accuracy: 0.6262 - val_loss: 0.6824 - val_accuracy: 0.5745
# Epoch 99/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.6604 - accuracy: 0.6050 - val_loss: 0.6709 - val_accuracy: 0.6043
# Epoch 100/350
# 9/9 [==============================] - 0s 23ms/step - loss: 0.6540 - accuracy: 0.6210 - val_loss: 0.6687 - val_accuracy: 0.6043
# Epoch 101/350
# 9/9 [==============================] - 0s 23ms/step - loss: 0.6496 - accuracy: 0.6234 - val_loss: 0.6694 - val_accuracy: 0.5957
# Epoch 102/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.6425 - accuracy: 0.6347 - val_loss: 0.6680 - val_accuracy: 0.6043
# Epoch 103/350
# 9/9 [==============================] - 0s 20ms/step - loss: 0.6471 - accuracy: 0.6361 - val_loss: 0.6730 - val_accuracy: 0.5915
# Epoch 104/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.6579 - accuracy: 0.6182 - val_loss: 0.6788 - val_accuracy: 0.5872
# Epoch 105/350
# 9/9 [==============================] - 0s 23ms/step - loss: 0.6448 - accuracy: 0.6390 - val_loss: 0.6790 - val_accuracy: 0.5872
# Epoch 106/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.6415 - accuracy: 0.6399 - val_loss: 0.6646 - val_accuracy: 0.6128
# Epoch 107/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.6437 - accuracy: 0.6310 - val_loss: 0.6715 - val_accuracy: 0.6128
# Epoch 108/350
# 9/9 [==============================] - 0s 25ms/step - loss: 0.6458 - accuracy: 0.6272 - val_loss: 0.6850 - val_accuracy: 0.5702
# Epoch 109/350
# 9/9 [==============================] - 0s 23ms/step - loss: 0.6486 - accuracy: 0.6262 - val_loss: 0.6730 - val_accuracy: 0.5872
# Epoch 110/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.6383 - accuracy: 0.6357 - val_loss: 0.6679 - val_accuracy: 0.6043
# Epoch 111/350
# 9/9 [==============================] - 0s 24ms/step - loss: 0.6472 - accuracy: 0.6187 - val_loss: 0.6737 - val_accuracy: 0.6128
# Epoch 112/350
# 9/9 [==============================] - 0s 23ms/step - loss: 0.6401 - accuracy: 0.6347 - val_loss: 0.6663 - val_accuracy: 0.5957
# Epoch 113/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.6433 - accuracy: 0.6404 - val_loss: 0.6661 - val_accuracy: 0.6085
# Epoch 114/350
# 9/9 [==============================] - 0s 20ms/step - loss: 0.6378 - accuracy: 0.6314 - val_loss: 0.6709 - val_accuracy: 0.6085
# Epoch 115/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.6420 - accuracy: 0.6286 - val_loss: 0.6766 - val_accuracy: 0.6043
# Epoch 116/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.6411 - accuracy: 0.6300 - val_loss: 0.6918 - val_accuracy: 0.5830
# Epoch 117/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.6361 - accuracy: 0.6451 - val_loss: 0.6872 - val_accuracy: 0.5872
# Epoch 118/350
# 9/9 [==============================] - 0s 24ms/step - loss: 0.6376 - accuracy: 0.6442 - val_loss: 0.6652 - val_accuracy: 0.6000
# Epoch 119/350
# 9/9 [==============================] - 0s 23ms/step - loss: 0.6281 - accuracy: 0.6555 - val_loss: 0.6654 - val_accuracy: 0.6213
# Epoch 120/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.6317 - accuracy: 0.6536 - val_loss: 0.6764 - val_accuracy: 0.5915
# Epoch 121/350
# 9/9 [==============================] - 0s 23ms/step - loss: 0.6352 - accuracy: 0.6475 - val_loss: 0.6751 - val_accuracy: 0.5957
# Epoch 122/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.6315 - accuracy: 0.6456 - val_loss: 0.6664 - val_accuracy: 0.6043
# Epoch 123/350
# 9/9 [==============================] - 0s 24ms/step - loss: 0.6280 - accuracy: 0.6385 - val_loss: 0.6722 - val_accuracy: 0.5957
# Epoch 124/350
# 9/9 [==============================] - 0s 23ms/step - loss: 0.6383 - accuracy: 0.6300 - val_loss: 0.6719 - val_accuracy: 0.6170
# Epoch 125/350
# 9/9 [==============================] - 0s 23ms/step - loss: 0.6294 - accuracy: 0.6564 - val_loss: 0.6685 - val_accuracy: 0.6255
# Epoch 126/350
# 9/9 [==============================] - 0s 25ms/step - loss: 0.6213 - accuracy: 0.6560 - val_loss: 0.6747 - val_accuracy: 0.6085
# Epoch 127/350
# 9/9 [==============================] - 0s 23ms/step - loss: 0.6273 - accuracy: 0.6522 - val_loss: 0.6587 - val_accuracy: 0.6298
# Epoch 128/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.6224 - accuracy: 0.6678 - val_loss: 0.6671 - val_accuracy: 0.6213
# Epoch 129/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.6106 - accuracy: 0.6701 - val_loss: 0.6731 - val_accuracy: 0.6000
# Epoch 130/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.6260 - accuracy: 0.6531 - val_loss: 0.6780 - val_accuracy: 0.5830
# Epoch 131/350
# 9/9 [==============================] - 0s 23ms/step - loss: 0.6235 - accuracy: 0.6550 - val_loss: 0.6655 - val_accuracy: 0.6000
# Epoch 132/350
# 9/9 [==============================] - 0s 23ms/step - loss: 0.6162 - accuracy: 0.6715 - val_loss: 0.6683 - val_accuracy: 0.6085
# Epoch 133/350
# 9/9 [==============================] - 0s 23ms/step - loss: 0.6218 - accuracy: 0.6569 - val_loss: 0.6780 - val_accuracy: 0.6043
# Epoch 134/350
# 9/9 [==============================] - 0s 23ms/step - loss: 0.6130 - accuracy: 0.6711 - val_loss: 0.6563 - val_accuracy: 0.6255
# Epoch 135/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.6169 - accuracy: 0.6597 - val_loss: 0.6559 - val_accuracy: 0.6170
# Epoch 136/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.6068 - accuracy: 0.6725 - val_loss: 0.6613 - val_accuracy: 0.6170
# Epoch 137/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.6197 - accuracy: 0.6569 - val_loss: 0.6762 - val_accuracy: 0.6000
# Epoch 138/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.6085 - accuracy: 0.6701 - val_loss: 0.6573 - val_accuracy: 0.6085
# Epoch 139/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.6034 - accuracy: 0.6914 - val_loss: 0.6629 - val_accuracy: 0.6255
# Epoch 140/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.5994 - accuracy: 0.6772 - val_loss: 0.6734 - val_accuracy: 0.6000
# Epoch 141/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.6101 - accuracy: 0.6668 - val_loss: 0.6581 - val_accuracy: 0.6128
# Epoch 142/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.5904 - accuracy: 0.6937 - val_loss: 0.6644 - val_accuracy: 0.5872
# Epoch 143/350
# 9/9 [==============================] - 0s 18ms/step - loss: 0.6063 - accuracy: 0.6918 - val_loss: 0.6543 - val_accuracy: 0.6213
# Epoch 144/350
# 9/9 [==============================] - 0s 20ms/step - loss: 0.6143 - accuracy: 0.6649 - val_loss: 0.6891 - val_accuracy: 0.5957
# Epoch 145/350
# 9/9 [==============================] - 0s 27ms/step - loss: 0.6081 - accuracy: 0.6692 - val_loss: 0.6647 - val_accuracy: 0.6170
# Epoch 146/350
# 9/9 [==============================] - 0s 27ms/step - loss: 0.5970 - accuracy: 0.6819 - val_loss: 0.7088 - val_accuracy: 0.5957
# Epoch 147/350
# 9/9 [==============================] - 0s 26ms/step - loss: 0.6018 - accuracy: 0.6767 - val_loss: 0.6671 - val_accuracy: 0.6128
# Epoch 148/350
# 9/9 [==============================] - 0s 28ms/step - loss: 0.6003 - accuracy: 0.6772 - val_loss: 0.6966 - val_accuracy: 0.5362
# Epoch 149/350
# 9/9 [==============================] - 0s 23ms/step - loss: 0.6014 - accuracy: 0.6871 - val_loss: 0.6541 - val_accuracy: 0.6170
# Epoch 150/350
# 9/9 [==============================] - 0s 24ms/step - loss: 0.5996 - accuracy: 0.6857 - val_loss: 0.6729 - val_accuracy: 0.6000
# Epoch 151/350
# 9/9 [==============================] - 0s 30ms/step - loss: 0.6016 - accuracy: 0.6942 - val_loss: 0.6712 - val_accuracy: 0.5830
# Epoch 152/350
# 9/9 [==============================] - 0s 33ms/step - loss: 0.5901 - accuracy: 0.6866 - val_loss: 0.6696 - val_accuracy: 0.6085
# Epoch 153/350
# 9/9 [==============================] - 0s 30ms/step - loss: 0.5923 - accuracy: 0.6876 - val_loss: 0.6605 - val_accuracy: 0.6255
# Epoch 154/350
# 9/9 [==============================] - 0s 29ms/step - loss: 0.5896 - accuracy: 0.6966 - val_loss: 0.6609 - val_accuracy: 0.6340
# Epoch 155/350
# 9/9 [==============================] - 0s 27ms/step - loss: 0.5853 - accuracy: 0.6933 - val_loss: 0.6742 - val_accuracy: 0.6340
# Epoch 156/350
# 9/9 [==============================] - 0s 27ms/step - loss: 0.5813 - accuracy: 0.6951 - val_loss: 0.7002 - val_accuracy: 0.6170
# Epoch 157/350
# 9/9 [==============================] - 0s 30ms/step - loss: 0.5866 - accuracy: 0.6914 - val_loss: 0.6641 - val_accuracy: 0.6000
# Epoch 158/350
# 9/9 [==============================] - 0s 27ms/step - loss: 0.5909 - accuracy: 0.7017 - val_loss: 0.6773 - val_accuracy: 0.6000
# Epoch 159/350
# 9/9 [==============================] - 0s 28ms/step - loss: 0.5657 - accuracy: 0.7235 - val_loss: 0.6676 - val_accuracy: 0.6000
# Epoch 160/350
# 9/9 [==============================] - 0s 26ms/step - loss: 0.5860 - accuracy: 0.6933 - val_loss: 0.6632 - val_accuracy: 0.6340
# Epoch 161/350
# 9/9 [==============================] - 0s 25ms/step - loss: 0.5646 - accuracy: 0.7197 - val_loss: 0.6780 - val_accuracy: 0.6298
# Epoch 162/350
# 9/9 [==============================] - 0s 26ms/step - loss: 0.5690 - accuracy: 0.7206 - val_loss: 0.6638 - val_accuracy: 0.6128
# Epoch 163/350
# 9/9 [==============================] - 0s 25ms/step - loss: 0.5708 - accuracy: 0.7150 - val_loss: 0.6678 - val_accuracy: 0.6128
# Epoch 164/350
# 9/9 [==============================] - 0s 24ms/step - loss: 0.5669 - accuracy: 0.7102 - val_loss: 0.6770 - val_accuracy: 0.6043
# Epoch 165/350
# 9/9 [==============================] - 0s 28ms/step - loss: 0.5809 - accuracy: 0.7107 - val_loss: 0.6592 - val_accuracy: 0.6128
# Epoch 166/350
# 9/9 [==============================] - 0s 27ms/step - loss: 0.5739 - accuracy: 0.7131 - val_loss: 0.6935 - val_accuracy: 0.5745
# Epoch 167/350
# 9/9 [==============================] - 0s 26ms/step - loss: 0.5706 - accuracy: 0.7060 - val_loss: 0.6692 - val_accuracy: 0.6213
# Epoch 168/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.5691 - accuracy: 0.7060 - val_loss: 0.6723 - val_accuracy: 0.6085
# Epoch 169/350
# 9/9 [==============================] - 0s 26ms/step - loss: 0.5656 - accuracy: 0.7121 - val_loss: 0.6639 - val_accuracy: 0.6255
# Epoch 170/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.5569 - accuracy: 0.7102 - val_loss: 0.6670 - val_accuracy: 0.6128
# Epoch 171/350
# 9/9 [==============================] - 0s 25ms/step - loss: 0.5788 - accuracy: 0.7074 - val_loss: 0.6790 - val_accuracy: 0.5872
# Epoch 172/350
# 9/9 [==============================] - 0s 23ms/step - loss: 0.5603 - accuracy: 0.7168 - val_loss: 0.6728 - val_accuracy: 0.5830
# Epoch 173/350
# 9/9 [==============================] - 0s 28ms/step - loss: 0.5618 - accuracy: 0.7159 - val_loss: 0.7090 - val_accuracy: 0.6255
# Epoch 174/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.5611 - accuracy: 0.7178 - val_loss: 0.6998 - val_accuracy: 0.6085
# Epoch 175/350
# 9/9 [==============================] - 0s 25ms/step - loss: 0.5562 - accuracy: 0.7159 - val_loss: 0.6681 - val_accuracy: 0.6000
# Epoch 176/350
# 9/9 [==============================] - 0s 20ms/step - loss: 0.5699 - accuracy: 0.7249 - val_loss: 0.6840 - val_accuracy: 0.5830
# Epoch 177/350
# 9/9 [==============================] - 0s 20ms/step - loss: 0.5665 - accuracy: 0.7150 - val_loss: 0.6924 - val_accuracy: 0.6043
# Epoch 178/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.5623 - accuracy: 0.7239 - val_loss: 0.6924 - val_accuracy: 0.6340
# Epoch 179/350
# 9/9 [==============================] - 0s 20ms/step - loss: 0.5589 - accuracy: 0.7268 - val_loss: 0.6722 - val_accuracy: 0.6255
# Epoch 180/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.5410 - accuracy: 0.7357 - val_loss: 0.6860 - val_accuracy: 0.6085
# Epoch 181/350
# 9/9 [==============================] - 0s 23ms/step - loss: 0.5574 - accuracy: 0.7272 - val_loss: 0.6763 - val_accuracy: 0.5872
# Epoch 182/350
# 9/9 [==============================] - 0s 23ms/step - loss: 0.5581 - accuracy: 0.7135 - val_loss: 0.7003 - val_accuracy: 0.6170
# Epoch 183/350
# 9/9 [==============================] - 0s 24ms/step - loss: 0.5464 - accuracy: 0.7154 - val_loss: 0.6846 - val_accuracy: 0.6170
# Epoch 184/350
# 9/9 [==============================] - 0s 23ms/step - loss: 0.5728 - accuracy: 0.7003 - val_loss: 0.6664 - val_accuracy: 0.6128
# Epoch 185/350
# 9/9 [==============================] - 0s 24ms/step - loss: 0.5566 - accuracy: 0.7173 - val_loss: 0.7289 - val_accuracy: 0.5745
# Epoch 186/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.5401 - accuracy: 0.7244 - val_loss: 0.6936 - val_accuracy: 0.6128
# Epoch 187/350
# 9/9 [==============================] - 0s 23ms/step - loss: 0.5343 - accuracy: 0.7386 - val_loss: 0.7321 - val_accuracy: 0.5660
# Epoch 188/350
# 9/9 [==============================] - 0s 17ms/step - loss: 0.5529 - accuracy: 0.7197 - val_loss: 0.7049 - val_accuracy: 0.6043
# Epoch 189/350
# 9/9 [==============================] - 0s 19ms/step - loss: 0.5480 - accuracy: 0.7216 - val_loss: 0.6854 - val_accuracy: 0.6213
# Epoch 190/350
# 9/9 [==============================] - 0s 24ms/step - loss: 0.5373 - accuracy: 0.7353 - val_loss: 0.6824 - val_accuracy: 0.6128
# Epoch 191/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.5539 - accuracy: 0.7150 - val_loss: 0.6752 - val_accuracy: 0.6170
# Epoch 192/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.5402 - accuracy: 0.7367 - val_loss: 0.6805 - val_accuracy: 0.6170
# Epoch 193/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.5271 - accuracy: 0.7437 - val_loss: 0.6919 - val_accuracy: 0.5915
# Epoch 194/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.5488 - accuracy: 0.7239 - val_loss: 0.7049 - val_accuracy: 0.6213
# Epoch 195/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.5430 - accuracy: 0.7216 - val_loss: 0.6805 - val_accuracy: 0.5957
# Epoch 196/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.5369 - accuracy: 0.7319 - val_loss: 0.6963 - val_accuracy: 0.6000
# Epoch 197/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.5393 - accuracy: 0.7404 - val_loss: 0.7013 - val_accuracy: 0.5957
# Epoch 198/350
# 9/9 [==============================] - 0s 20ms/step - loss: 0.5177 - accuracy: 0.7409 - val_loss: 0.7181 - val_accuracy: 0.6213
# Epoch 199/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.5322 - accuracy: 0.7381 - val_loss: 0.7091 - val_accuracy: 0.6128
# Epoch 200/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.5217 - accuracy: 0.7404 - val_loss: 0.6901 - val_accuracy: 0.5830
# Epoch 201/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.5346 - accuracy: 0.7362 - val_loss: 0.6981 - val_accuracy: 0.5957
# Epoch 202/350
# 9/9 [==============================] - 0s 20ms/step - loss: 0.5359 - accuracy: 0.7400 - val_loss: 0.6861 - val_accuracy: 0.6128
# Epoch 203/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.5082 - accuracy: 0.7504 - val_loss: 0.6955 - val_accuracy: 0.6128
# Epoch 204/350
# 9/9 [==============================] - 0s 18ms/step - loss: 0.5223 - accuracy: 0.7466 - val_loss: 0.6906 - val_accuracy: 0.6170
# Epoch 205/350
# 9/9 [==============================] - 0s 20ms/step - loss: 0.5211 - accuracy: 0.7466 - val_loss: 0.6947 - val_accuracy: 0.6085
# Epoch 206/350
# 9/9 [==============================] - 0s 23ms/step - loss: 0.5100 - accuracy: 0.7499 - val_loss: 0.7244 - val_accuracy: 0.5745
# Epoch 207/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.5339 - accuracy: 0.7409 - val_loss: 0.7056 - val_accuracy: 0.5872
# Epoch 208/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.5075 - accuracy: 0.7579 - val_loss: 0.7378 - val_accuracy: 0.6128
# Epoch 209/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.5360 - accuracy: 0.7419 - val_loss: 0.7153 - val_accuracy: 0.6000
# Epoch 210/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.5262 - accuracy: 0.7480 - val_loss: 0.7048 - val_accuracy: 0.6043
# Epoch 211/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.5033 - accuracy: 0.7640 - val_loss: 0.7113 - val_accuracy: 0.5574
# Epoch 212/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.5234 - accuracy: 0.7371 - val_loss: 0.7505 - val_accuracy: 0.6128
# Epoch 213/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.5273 - accuracy: 0.7404 - val_loss: 0.6912 - val_accuracy: 0.5915
# Epoch 214/350
# 9/9 [==============================] - 0s 25ms/step - loss: 0.5140 - accuracy: 0.7508 - val_loss: 0.7199 - val_accuracy: 0.6255
# Epoch 215/350
# 9/9 [==============================] - 0s 23ms/step - loss: 0.5071 - accuracy: 0.7494 - val_loss: 0.7239 - val_accuracy: 0.6000
# Epoch 216/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.5232 - accuracy: 0.7433 - val_loss: 0.7261 - val_accuracy: 0.5234
# Epoch 217/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.5183 - accuracy: 0.7386 - val_loss: 0.6915 - val_accuracy: 0.6298
# Epoch 218/350
# 9/9 [==============================] - 0s 20ms/step - loss: 0.4947 - accuracy: 0.7622 - val_loss: 0.7236 - val_accuracy: 0.5872
# Epoch 219/350
# 9/9 [==============================] - 0s 24ms/step - loss: 0.4863 - accuracy: 0.7645 - val_loss: 0.8475 - val_accuracy: 0.5447
# Epoch 220/350
# 9/9 [==============================] - 0s 19ms/step - loss: 0.5395 - accuracy: 0.7334 - val_loss: 0.7094 - val_accuracy: 0.6043
# Epoch 221/350
# 9/9 [==============================] - 0s 20ms/step - loss: 0.4975 - accuracy: 0.7598 - val_loss: 0.7044 - val_accuracy: 0.6043
# Epoch 222/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.4948 - accuracy: 0.7631 - val_loss: 0.7183 - val_accuracy: 0.5702
# Epoch 223/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.5218 - accuracy: 0.7447 - val_loss: 0.7365 - val_accuracy: 0.6000
# Epoch 224/350
# 9/9 [==============================] - 0s 20ms/step - loss: 0.4955 - accuracy: 0.7631 - val_loss: 0.7416 - val_accuracy: 0.6170
# Epoch 225/350
# 9/9 [==============================] - 0s 27ms/step - loss: 0.4919 - accuracy: 0.7593 - val_loss: 0.7003 - val_accuracy: 0.5660
# Epoch 226/350
# 9/9 [==============================] - 0s 27ms/step - loss: 0.4948 - accuracy: 0.7706 - val_loss: 0.7695 - val_accuracy: 0.5915
# Epoch 227/350
# 9/9 [==============================] - 0s 26ms/step - loss: 0.5163 - accuracy: 0.7499 - val_loss: 0.6991 - val_accuracy: 0.5830
# Epoch 228/350
# 9/9 [==============================] - 0s 27ms/step - loss: 0.4932 - accuracy: 0.7631 - val_loss: 0.7055 - val_accuracy: 0.6085
# Epoch 229/350
# 9/9 [==============================] - 0s 25ms/step - loss: 0.5123 - accuracy: 0.7537 - val_loss: 0.7036 - val_accuracy: 0.6043
# Epoch 230/350
# 9/9 [==============================] - 0s 25ms/step - loss: 0.4886 - accuracy: 0.7697 - val_loss: 0.6976 - val_accuracy: 0.5915
# Epoch 231/350
# 9/9 [==============================] - 0s 25ms/step - loss: 0.4878 - accuracy: 0.7678 - val_loss: 0.7301 - val_accuracy: 0.5872
# Epoch 232/350
# 9/9 [==============================] - 0s 25ms/step - loss: 0.5050 - accuracy: 0.7640 - val_loss: 0.7211 - val_accuracy: 0.5830
# Epoch 233/350
# 9/9 [==============================] - 0s 29ms/step - loss: 0.4728 - accuracy: 0.7721 - val_loss: 0.7730 - val_accuracy: 0.5617
# Epoch 234/350
# 9/9 [==============================] - 0s 26ms/step - loss: 0.4954 - accuracy: 0.7702 - val_loss: 0.7537 - val_accuracy: 0.5872
# Epoch 235/350
# 9/9 [==============================] - 0s 28ms/step - loss: 0.5022 - accuracy: 0.7603 - val_loss: 0.6941 - val_accuracy: 0.6085
# Epoch 236/350
# 9/9 [==============================] - 0s 25ms/step - loss: 0.4918 - accuracy: 0.7711 - val_loss: 0.7837 - val_accuracy: 0.6213
# Epoch 237/350
# 9/9 [==============================] - 0s 24ms/step - loss: 0.4850 - accuracy: 0.7650 - val_loss: 0.7415 - val_accuracy: 0.6000
# Epoch 238/350
# 9/9 [==============================] - 0s 28ms/step - loss: 0.4867 - accuracy: 0.7716 - val_loss: 0.7207 - val_accuracy: 0.5915
# Epoch 239/350
# 9/9 [==============================] - 0s 31ms/step - loss: 0.4914 - accuracy: 0.7588 - val_loss: 0.7218 - val_accuracy: 0.5532
# Epoch 240/350
# 9/9 [==============================] - 0s 24ms/step - loss: 0.4647 - accuracy: 0.7839 - val_loss: 0.7931 - val_accuracy: 0.6043
# Epoch 241/350
# 9/9 [==============================] - 0s 25ms/step - loss: 0.4878 - accuracy: 0.7659 - val_loss: 0.7065 - val_accuracy: 0.6000
# Epoch 242/350
# 9/9 [==============================] - 0s 24ms/step - loss: 0.4844 - accuracy: 0.7801 - val_loss: 0.7493 - val_accuracy: 0.6170
# Epoch 243/350
# 9/9 [==============================] - 0s 26ms/step - loss: 0.4695 - accuracy: 0.7796 - val_loss: 0.7479 - val_accuracy: 0.5702
# Epoch 244/350
# 9/9 [==============================] - 0s 26ms/step - loss: 0.4963 - accuracy: 0.7612 - val_loss: 0.7560 - val_accuracy: 0.6000
# Epoch 245/350
# 9/9 [==============================] - 0s 30ms/step - loss: 0.4873 - accuracy: 0.7744 - val_loss: 0.7029 - val_accuracy: 0.5957
# Epoch 246/350
# 9/9 [==============================] - 0s 30ms/step - loss: 0.4609 - accuracy: 0.7739 - val_loss: 0.7576 - val_accuracy: 0.5745
# Epoch 247/350
# 9/9 [==============================] - 0s 25ms/step - loss: 0.4776 - accuracy: 0.7659 - val_loss: 0.7380 - val_accuracy: 0.5915
# Epoch 248/350
# 9/9 [==============================] - 0s 29ms/step - loss: 0.4753 - accuracy: 0.7721 - val_loss: 0.7231 - val_accuracy: 0.6043
# Epoch 249/350
# 9/9 [==============================] - 0s 27ms/step - loss: 0.4611 - accuracy: 0.7857 - val_loss: 0.7151 - val_accuracy: 0.6170
# Epoch 250/350
# 9/9 [==============================] - 0s 27ms/step - loss: 0.4870 - accuracy: 0.7773 - val_loss: 0.7779 - val_accuracy: 0.5957
# Epoch 251/350
# 9/9 [==============================] - 0s 25ms/step - loss: 0.4509 - accuracy: 0.7867 - val_loss: 0.7729 - val_accuracy: 0.6000
# Epoch 252/350
# 9/9 [==============================] - 0s 27ms/step - loss: 0.4704 - accuracy: 0.7777 - val_loss: 0.8091 - val_accuracy: 0.6170
# Epoch 253/350
# 9/9 [==============================] - 0s 27ms/step - loss: 0.4807 - accuracy: 0.7810 - val_loss: 0.7271 - val_accuracy: 0.6000
# Epoch 254/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.4747 - accuracy: 0.7711 - val_loss: 0.7754 - val_accuracy: 0.6043
# Epoch 255/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.4904 - accuracy: 0.7697 - val_loss: 0.7573 - val_accuracy: 0.6043
# Epoch 256/350
# 9/9 [==============================] - 0s 20ms/step - loss: 0.4548 - accuracy: 0.7876 - val_loss: 0.7236 - val_accuracy: 0.6128
# Epoch 257/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.4656 - accuracy: 0.7928 - val_loss: 0.7242 - val_accuracy: 0.6128
# Epoch 258/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.4559 - accuracy: 0.7862 - val_loss: 0.7490 - val_accuracy: 0.6213
# Epoch 259/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.4589 - accuracy: 0.7824 - val_loss: 0.7592 - val_accuracy: 0.6043
# Epoch 260/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.4627 - accuracy: 0.7744 - val_loss: 0.7684 - val_accuracy: 0.5787
# Epoch 261/350
# 9/9 [==============================] - 0s 19ms/step - loss: 0.4571 - accuracy: 0.7905 - val_loss: 0.7385 - val_accuracy: 0.5574
# Epoch 262/350
# 9/9 [==============================] - 0s 23ms/step - loss: 0.4634 - accuracy: 0.7820 - val_loss: 0.7547 - val_accuracy: 0.5787
# Epoch 263/350
# 9/9 [==============================] - 0s 20ms/step - loss: 0.4561 - accuracy: 0.7853 - val_loss: 0.7294 - val_accuracy: 0.5787
# Epoch 264/350
# 9/9 [==============================] - 0s 20ms/step - loss: 0.4542 - accuracy: 0.7848 - val_loss: 0.7474 - val_accuracy: 0.5872
# Epoch 265/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.4728 - accuracy: 0.7801 - val_loss: 0.7516 - val_accuracy: 0.5915
# Epoch 266/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.4563 - accuracy: 0.7900 - val_loss: 0.8405 - val_accuracy: 0.5745
# Epoch 267/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.4391 - accuracy: 0.8008 - val_loss: 0.7298 - val_accuracy: 0.6383
# Epoch 268/350
# 9/9 [==============================] - 0s 24ms/step - loss: 0.4475 - accuracy: 0.7905 - val_loss: 0.8366 - val_accuracy: 0.5745
# Epoch 269/350
# 9/9 [==============================] - 0s 25ms/step - loss: 0.4717 - accuracy: 0.7763 - val_loss: 0.7327 - val_accuracy: 0.5787
# Epoch 270/350
# 9/9 [==============================] - 0s 20ms/step - loss: 0.4507 - accuracy: 0.7900 - val_loss: 0.7463 - val_accuracy: 0.6170
# Epoch 271/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.4359 - accuracy: 0.8013 - val_loss: 0.8210 - val_accuracy: 0.6085
# Epoch 272/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.4350 - accuracy: 0.7952 - val_loss: 0.7992 - val_accuracy: 0.6128
# Epoch 273/350
# 9/9 [==============================] - 0s 20ms/step - loss: 0.4715 - accuracy: 0.7791 - val_loss: 0.7997 - val_accuracy: 0.6213
# Epoch 274/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.4517 - accuracy: 0.7909 - val_loss: 0.7937 - val_accuracy: 0.6298
# Epoch 275/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.4379 - accuracy: 0.7872 - val_loss: 0.8273 - val_accuracy: 0.5617
# Epoch 276/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.4406 - accuracy: 0.7957 - val_loss: 0.8090 - val_accuracy: 0.5872
# Epoch 277/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.4633 - accuracy: 0.7843 - val_loss: 0.8079 - val_accuracy: 0.5915
# Epoch 278/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.4351 - accuracy: 0.7999 - val_loss: 0.7764 - val_accuracy: 0.6043
# Epoch 279/350
# 9/9 [==============================] - 0s 23ms/step - loss: 0.4522 - accuracy: 0.7843 - val_loss: 0.8270 - val_accuracy: 0.6000
# Epoch 280/350
# 9/9 [==============================] - 0s 24ms/step - loss: 0.4418 - accuracy: 0.7947 - val_loss: 0.7914 - val_accuracy: 0.6000
# Epoch 281/350
# 9/9 [==============================] - 0s 19ms/step - loss: 0.4577 - accuracy: 0.7791 - val_loss: 0.8299 - val_accuracy: 0.6383
# Epoch 282/350
# 9/9 [==============================] - 0s 19ms/step - loss: 0.4322 - accuracy: 0.8008 - val_loss: 0.8244 - val_accuracy: 0.6128
# Epoch 283/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.4331 - accuracy: 0.7994 - val_loss: 0.8110 - val_accuracy: 0.5915
# Epoch 284/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.4384 - accuracy: 0.7928 - val_loss: 0.8177 - val_accuracy: 0.6043
# Epoch 285/350
# 9/9 [==============================] - 0s 20ms/step - loss: 0.4615 - accuracy: 0.7820 - val_loss: 0.7939 - val_accuracy: 0.6170
# Epoch 286/350
# 9/9 [==============================] - 0s 23ms/step - loss: 0.4333 - accuracy: 0.8023 - val_loss: 0.8037 - val_accuracy: 0.6128
# Epoch 287/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.4204 - accuracy: 0.8046 - val_loss: 0.8174 - val_accuracy: 0.5915
# Epoch 288/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.4190 - accuracy: 0.8032 - val_loss: 0.8023 - val_accuracy: 0.5915
# Epoch 289/350
# 9/9 [==============================] - 0s 19ms/step - loss: 0.4266 - accuracy: 0.8070 - val_loss: 0.7973 - val_accuracy: 0.5745
# Epoch 290/350
# ...
# Epoch 239/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.5007 - accuracy: 0.7551 - val_loss: 0.8853 - val_accuracy: 0.5745
# Epoch 240/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.4982 - accuracy: 0.7570 - val_loss: 0.8587 - val_accuracy: 0.6000
# Epoch 241/350
# 9/9 [==============================] - 0s 23ms/step - loss: 0.5160 - accuracy: 0.7461 - val_loss: 0.8534 - val_accuracy: 0.5404
# Epoch 242/350
# 9/9 [==============================] - 0s 26ms/step - loss: 0.4998 - accuracy: 0.7678 - val_loss: 0.7985 - val_accuracy: 0.5574
# Epoch 243/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.5092 - accuracy: 0.7414 - val_loss: 0.8929 - val_accuracy: 0.6000
# Epoch 244/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.4831 - accuracy: 0.7744 - val_loss: 0.8408 - val_accuracy: 0.5702
# Epoch 245/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.4732 - accuracy: 0.7763 - val_loss: 0.8702 - val_accuracy: 0.5830
# Epoch 246/350
# 9/9 [==============================] - 0s 25ms/step - loss: 0.4764 - accuracy: 0.7622 - val_loss: 0.8503 - val_accuracy: 0.5915
# Epoch 247/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.5133 - accuracy: 0.7489 - val_loss: 0.8892 - val_accuracy: 0.5787
# Epoch 248/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.4864 - accuracy: 0.7678 - val_loss: 0.8252 - val_accuracy: 0.6043
# Epoch 249/350
# 9/9 [==============================] - 0s 20ms/step - loss: 0.4883 - accuracy: 0.7636 - val_loss: 0.8225 - val_accuracy: 0.5915
# Epoch 250/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.4766 - accuracy: 0.7697 - val_loss: 0.9041 - val_accuracy: 0.5574
# Epoch 251/350
# 9/9 [==============================] - 0s 23ms/step - loss: 0.4949 - accuracy: 0.7584 - val_loss: 0.8117 - val_accuracy: 0.6000
# Epoch 252/350
# 9/9 [==============================] - 0s 18ms/step - loss: 0.4784 - accuracy: 0.7782 - val_loss: 0.8746 - val_accuracy: 0.6000
# Epoch 253/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.4952 - accuracy: 0.7527 - val_loss: 0.8352 - val_accuracy: 0.5745
# Epoch 254/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.4804 - accuracy: 0.7640 - val_loss: 0.8425 - val_accuracy: 0.5957
# Epoch 255/350
# 9/9 [==============================] - 0s 19ms/step - loss: 0.4931 - accuracy: 0.7645 - val_loss: 0.8519 - val_accuracy: 0.5787
# Epoch 256/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.4605 - accuracy: 0.7744 - val_loss: 0.8516 - val_accuracy: 0.6000
# Epoch 257/350
# 9/9 [==============================] - 0s 19ms/step - loss: 0.4765 - accuracy: 0.7697 - val_loss: 0.8107 - val_accuracy: 0.5830
# Epoch 258/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.4651 - accuracy: 0.7683 - val_loss: 0.9240 - val_accuracy: 0.5191
# Epoch 259/350
# 9/9 [==============================] - 0s 25ms/step - loss: 0.4771 - accuracy: 0.7810 - val_loss: 0.8363 - val_accuracy: 0.5872
# Epoch 260/350
# 9/9 [==============================] - 0s 23ms/step - loss: 0.4711 - accuracy: 0.7688 - val_loss: 0.9477 - val_accuracy: 0.5574
# Epoch 261/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.4741 - accuracy: 0.7791 - val_loss: 0.8374 - val_accuracy: 0.5787
# Epoch 262/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.4684 - accuracy: 0.7758 - val_loss: 0.8926 - val_accuracy: 0.5574
# Epoch 263/350
# 9/9 [==============================] - 0s 23ms/step - loss: 0.4611 - accuracy: 0.7867 - val_loss: 0.8743 - val_accuracy: 0.5574
# Epoch 264/350
# 9/9 [==============================] - 0s 25ms/step - loss: 0.4755 - accuracy: 0.7739 - val_loss: 0.8482 - val_accuracy: 0.5787
# Epoch 265/350
# 9/9 [==============================] - 0s 23ms/step - loss: 0.4595 - accuracy: 0.7843 - val_loss: 0.9857 - val_accuracy: 0.5660
# Epoch 266/350
# 9/9 [==============================] - 0s 23ms/step - loss: 0.4604 - accuracy: 0.7862 - val_loss: 0.9094 - val_accuracy: 0.5787
# Epoch 267/350
# 9/9 [==============================] - 0s 25ms/step - loss: 0.4667 - accuracy: 0.7782 - val_loss: 0.8917 - val_accuracy: 0.5617
# Epoch 268/350
# 9/9 [==============================] - 0s 25ms/step - loss: 0.4596 - accuracy: 0.7796 - val_loss: 0.8415 - val_accuracy: 0.6043
# Epoch 269/350
# 9/9 [==============================] - 0s 26ms/step - loss: 0.4743 - accuracy: 0.7725 - val_loss: 0.8614 - val_accuracy: 0.5957
# Epoch 270/350
# 9/9 [==============================] - 0s 23ms/step - loss: 0.4750 - accuracy: 0.7725 - val_loss: 0.8318 - val_accuracy: 0.6128
# Epoch 271/350
# 9/9 [==============================] - 0s 25ms/step - loss: 0.4662 - accuracy: 0.7730 - val_loss: 0.8549 - val_accuracy: 0.6043
# Epoch 272/350
# 9/9 [==============================] - 0s 27ms/step - loss: 0.4691 - accuracy: 0.7716 - val_loss: 0.8727 - val_accuracy: 0.5915
# Epoch 273/350
# 9/9 [==============================] - 0s 25ms/step - loss: 0.4514 - accuracy: 0.7900 - val_loss: 0.9226 - val_accuracy: 0.5617
# Epoch 274/350
# 9/9 [==============================] - 0s 25ms/step - loss: 0.4341 - accuracy: 0.7942 - val_loss: 1.0454 - val_accuracy: 0.5404
# Epoch 275/350
# 9/9 [==============================] - 0s 28ms/step - loss: 0.4680 - accuracy: 0.7749 - val_loss: 0.9584 - val_accuracy: 0.5745
# Epoch 276/350
# 9/9 [==============================] - 0s 30ms/step - loss: 0.4442 - accuracy: 0.7839 - val_loss: 0.8734 - val_accuracy: 0.5532
# Epoch 277/350
# 9/9 [==============================] - 0s 28ms/step - loss: 0.4595 - accuracy: 0.7867 - val_loss: 0.8579 - val_accuracy: 0.5787
# Epoch 278/350
# 9/9 [==============================] - 0s 27ms/step - loss: 0.4505 - accuracy: 0.7867 - val_loss: 0.9258 - val_accuracy: 0.5872
# Epoch 279/350
# 9/9 [==============================] - 0s 24ms/step - loss: 0.4555 - accuracy: 0.7876 - val_loss: 0.8653 - val_accuracy: 0.5787
# Epoch 280/350
# 9/9 [==============================] - 0s 25ms/step - loss: 0.4592 - accuracy: 0.7857 - val_loss: 0.9815 - val_accuracy: 0.6000
# Epoch 281/350
# 9/9 [==============================] - 0s 25ms/step - loss: 0.4710 - accuracy: 0.7829 - val_loss: 0.8847 - val_accuracy: 0.5617
# Epoch 282/350
# 9/9 [==============================] - 0s 27ms/step - loss: 0.4596 - accuracy: 0.7867 - val_loss: 0.8852 - val_accuracy: 0.5489
# Epoch 283/350
# 9/9 [==============================] - 0s 23ms/step - loss: 0.4510 - accuracy: 0.7876 - val_loss: 0.8783 - val_accuracy: 0.5787
# Epoch 284/350
# 9/9 [==============================] - 0s 29ms/step - loss: 0.4545 - accuracy: 0.7872 - val_loss: 0.9172 - val_accuracy: 0.5830
# Epoch 285/350
# 9/9 [==============================] - 0s 25ms/step - loss: 0.4492 - accuracy: 0.7848 - val_loss: 0.8942 - val_accuracy: 0.5617
# Epoch 286/350
# 9/9 [==============================] - 0s 28ms/step - loss: 0.4470 - accuracy: 0.7876 - val_loss: 0.8843 - val_accuracy: 0.5787
# Epoch 287/350
# 9/9 [==============================] - 0s 25ms/step - loss: 0.4348 - accuracy: 0.7919 - val_loss: 0.9020 - val_accuracy: 0.5915
# Epoch 288/350
# 9/9 [==============================] - 0s 29ms/step - loss: 0.4285 - accuracy: 0.8018 - val_loss: 0.9597 - val_accuracy: 0.5872
# Epoch 289/350
# 9/9 [==============================] - 0s 23ms/step - loss: 0.4481 - accuracy: 0.7820 - val_loss: 1.0718 - val_accuracy: 0.5149
# Epoch 290/350
# 9/9 [==============================] - 0s 24ms/step - loss: 0.4572 - accuracy: 0.7876 - val_loss: 0.8942 - val_accuracy: 0.5702
# Epoch 291/350
# 9/9 [==============================] - 0s 27ms/step - loss: 0.4238 - accuracy: 0.7961 - val_loss: 0.9715 - val_accuracy: 0.5745
# Epoch 292/350
# 9/9 [==============================] - 0s 26ms/step - loss: 0.4308 - accuracy: 0.8065 - val_loss: 1.0307 - val_accuracy: 0.5447
# Epoch 293/350
# 9/9 [==============================] - 0s 24ms/step - loss: 0.4497 - accuracy: 0.7848 - val_loss: 0.8964 - val_accuracy: 0.5362
# Epoch 294/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.4302 - accuracy: 0.8018 - val_loss: 1.0013 - val_accuracy: 0.5489
# Epoch 295/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.4332 - accuracy: 0.7966 - val_loss: 0.9791 - val_accuracy: 0.5617
# Epoch 296/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.4438 - accuracy: 0.8018 - val_loss: 0.8604 - val_accuracy: 0.5830
# Epoch 297/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.4388 - accuracy: 0.7971 - val_loss: 0.9362 - val_accuracy: 0.5489
# Epoch 298/350
# 9/9 [==============================] - 0s 23ms/step - loss: 0.4325 - accuracy: 0.8037 - val_loss: 1.1114 - val_accuracy: 0.5489
# Epoch 299/350
# 9/9 [==============================] - 0s 24ms/step - loss: 0.4302 - accuracy: 0.7924 - val_loss: 1.0425 - val_accuracy: 0.5234
# Epoch 300/350
# 9/9 [==============================] - 0s 23ms/step - loss: 0.4419 - accuracy: 0.7919 - val_loss: 0.9491 - val_accuracy: 0.5745
# Epoch 301/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.4412 - accuracy: 0.7990 - val_loss: 0.9849 - val_accuracy: 0.5702
# Epoch 302/350
# 9/9 [==============================] - 0s 24ms/step - loss: 0.4434 - accuracy: 0.8032 - val_loss: 0.9394 - val_accuracy: 0.5915
# Epoch 303/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.4243 - accuracy: 0.8042 - val_loss: 0.9812 - val_accuracy: 0.5532
# Epoch 304/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.4196 - accuracy: 0.8051 - val_loss: 1.0288 - val_accuracy: 0.5915
# Epoch 305/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.4435 - accuracy: 0.7843 - val_loss: 0.9140 - val_accuracy: 0.5830
# Epoch 306/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.4494 - accuracy: 0.7895 - val_loss: 0.9662 - val_accuracy: 0.5830
# Epoch 307/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.4163 - accuracy: 0.8070 - val_loss: 1.1148 - val_accuracy: 0.5277
# Epoch 308/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.4585 - accuracy: 0.7843 - val_loss: 0.9476 - val_accuracy: 0.5787
# Epoch 309/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.4294 - accuracy: 0.7876 - val_loss: 1.0342 - val_accuracy: 0.5447
# Epoch 310/350
# 9/9 [==============================] - 0s 23ms/step - loss: 0.4500 - accuracy: 0.7848 - val_loss: 1.0811 - val_accuracy: 0.5574
# Epoch 311/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.4265 - accuracy: 0.8018 - val_loss: 0.9642 - val_accuracy: 0.5404
# Epoch 312/350
# 9/9 [==============================] - 0s 23ms/step - loss: 0.4680 - accuracy: 0.7640 - val_loss: 0.9786 - val_accuracy: 0.6000
# Epoch 313/350
# 9/9 [==============================] - 0s 23ms/step - loss: 0.4200 - accuracy: 0.8042 - val_loss: 1.0088 - val_accuracy: 0.5319
# Epoch 314/350
# 9/9 [==============================] - 0s 19ms/step - loss: 0.4286 - accuracy: 0.7985 - val_loss: 1.0238 - val_accuracy: 0.5574
# Epoch 315/350
# 9/9 [==============================] - 0s 19ms/step - loss: 0.4061 - accuracy: 0.8108 - val_loss: 1.0089 - val_accuracy: 0.5872
# Epoch 316/350
# 9/9 [==============================] - 0s 26ms/step - loss: 0.4291 - accuracy: 0.8013 - val_loss: 1.0448 - val_accuracy: 0.5532
# Epoch 317/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.4182 - accuracy: 0.7980 - val_loss: 1.0292 - val_accuracy: 0.5787
# Epoch 318/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.4117 - accuracy: 0.8065 - val_loss: 1.0671 - val_accuracy: 0.5447
# Epoch 319/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.3965 - accuracy: 0.8207 - val_loss: 0.9590 - val_accuracy: 0.5617
# Epoch 320/350
# 9/9 [==============================] - 0s 19ms/step - loss: 0.4300 - accuracy: 0.8004 - val_loss: 1.0344 - val_accuracy: 0.5872
# Epoch 321/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.3949 - accuracy: 0.8216 - val_loss: 1.0726 - val_accuracy: 0.5489
# Epoch 322/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.4101 - accuracy: 0.8098 - val_loss: 1.1124 - val_accuracy: 0.5489
# Epoch 323/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.4238 - accuracy: 0.8032 - val_loss: 0.9937 - val_accuracy: 0.5787
# Epoch 324/350
# 9/9 [==============================] - 0s 23ms/step - loss: 0.3965 - accuracy: 0.8155 - val_loss: 1.1390 - val_accuracy: 0.6170
# Epoch 325/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.4084 - accuracy: 0.8098 - val_loss: 1.0692 - val_accuracy: 0.5532
# Epoch 326/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.4184 - accuracy: 0.7985 - val_loss: 0.9959 - val_accuracy: 0.5447
# Epoch 327/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.4212 - accuracy: 0.7975 - val_loss: 1.2160 - val_accuracy: 0.5149
# Epoch 328/350
# 9/9 [==============================] - 0s 23ms/step - loss: 0.4435 - accuracy: 0.8056 - val_loss: 1.1479 - val_accuracy: 0.5106
# Epoch 329/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.4136 - accuracy: 0.8112 - val_loss: 1.0092 - val_accuracy: 0.5745
# Epoch 330/350
# 9/9 [==============================] - 0s 24ms/step - loss: 0.3963 - accuracy: 0.8174 - val_loss: 1.0778 - val_accuracy: 0.5745
# Epoch 331/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.3940 - accuracy: 0.8131 - val_loss: 1.1092 - val_accuracy: 0.5617
# Epoch 332/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.4088 - accuracy: 0.8051 - val_loss: 1.1040 - val_accuracy: 0.5447
# Epoch 333/350
# 9/9 [==============================] - 0s 28ms/step - loss: 0.4156 - accuracy: 0.8079 - val_loss: 1.0907 - val_accuracy: 0.5489
# Epoch 334/350
# 9/9 [==============================] - 0s 23ms/step - loss: 0.3959 - accuracy: 0.8160 - val_loss: 1.0119 - val_accuracy: 0.5830
# Epoch 335/350
# 9/9 [==============================] - 0s 20ms/step - loss: 0.3909 - accuracy: 0.8126 - val_loss: 1.2174 - val_accuracy: 0.5532
# Epoch 336/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.4257 - accuracy: 0.7975 - val_loss: 1.0139 - val_accuracy: 0.5660
# Epoch 337/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.4119 - accuracy: 0.8075 - val_loss: 1.0366 - val_accuracy: 0.5660
# Epoch 338/350
# 9/9 [==============================] - 0s 22ms/step - loss: 0.4072 - accuracy: 0.8108 - val_loss: 1.0890 - val_accuracy: 0.5489
# Epoch 339/350
# 9/9 [==============================] - 0s 24ms/step - loss: 0.4218 - accuracy: 0.8032 - val_loss: 0.9598 - val_accuracy: 0.5404
# Epoch 340/350
# 9/9 [==============================] - 0s 23ms/step - loss: 0.4099 - accuracy: 0.8075 - val_loss: 1.0680 - val_accuracy: 0.5915
# Epoch 341/350
# 9/9 [==============================] - 0s 21ms/step - loss: 0.3811 - accuracy: 0.8259 - val_loss: 1.0775 - val_accuracy: 0.5532
# Epoch 342/350
# 9/9 [==============================] - 0s 30ms/step - loss: 0.4010 - accuracy: 0.8145 - val_loss: 0.9369 - val_accuracy: 0.5702
# Epoch 343/350
# 9/9 [==============================] - 0s 26ms/step - loss: 0.3975 - accuracy: 0.8131 - val_loss: 1.1050 - val_accuracy: 0.5574
# Epoch 344/350
# 9/9 [==============================] - 0s 26ms/step - loss: 0.3988 - accuracy: 0.8141 - val_loss: 1.1845 - val_accuracy: 0.5787
# Epoch 345/350
# 9/9 [==============================] - 0s 28ms/step - loss: 0.3977 - accuracy: 0.8183 - val_loss: 1.0700 - val_accuracy: 0.5957
# Epoch 346/350
# 9/9 [==============================] - 0s 25ms/step - loss: 0.3995 - accuracy: 0.8211 - val_loss: 1.0154 - val_accuracy: 0.5447
# Epoch 347/350
# 9/9 [==============================] - 0s 30ms/step - loss: 0.3731 - accuracy: 0.8277 - val_loss: 1.1675 - val_accuracy: 0.5149
# Epoch 348/350
# 9/9 [==============================] - 0s 25ms/step - loss: 0.4060 - accuracy: 0.8178 - val_loss: 1.1217 - val_accuracy: 0.5915
# Epoch 349/350
# 9/9 [==============================] - 0s 25ms/step - loss: 0.3822 - accuracy: 0.8155 - val_loss: 1.2944 - val_accuracy: 0.5021
# Epoch 350/350
# 9/9 [==============================] - 0s 26ms/step - loss: 0.3976 - accuracy: 0.8169 - val_loss: 1.1874 - val_accuracy: 0.5660

# %% [markdown]
# * Here, I have used the outermost loop as the cross-validation loop, ensuring that each ensemble model is trained on each fold.
# * Then each ensemble model is trained within the folds to ensure that the validation is done properly across all the data.
# * I have splitted data by using index-based slicing from the cross-validation fold splitting, which is more typical in scenarios where a separate feature and label arrays are present.
