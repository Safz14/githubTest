# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Assumes scale images are on your Drive under "Images"

# !ls /content/drive/MyDrive/Images/*csv
# Out:
# /content/drive/MyDrive/Images/labels.csv
# /content/drive/MyDrive/Images/SalmonFishScalesCoordinates-V2.csv

# %%
import os.path
import numpy as np
import math
from matplotlib.image import imread
import matplotlib.pyplot as plt
import skimage.draw as drw

SCALE_WIDTH = 1500
SCALE_HEIGHT = 2000
IMAGE_HEIGHT = 1920
TRANSECT_LENGTH = 750

PATH=os.sep + os.path.join("content", "drive", "MyDrive", "Images")

def rgb2gray(rgb):
    return np.dot(rgb[...,:3], [0.2989, 0.5870, 0.1140])

def fill_boarder(gray_img, thickness, fill_value=255):
  gray_img[:thickness,:] = fill_value
  gray_img[-thickness:,:] = fill_value
  gray_img[:,:thickness] = fill_value
  gray_img[:,-thickness:] = fill_value

def scale_edge_detector(x,index, window_size, frequency_factor, orientation):
  if not (orientation == 'LR' or orientation == 'RL'):
    raise Exception("Edge detection orientation must be 'LR' or 'RL'.")

  if window_size % 2 != 1:
    raise Exception("Window size must be an odd number.")

  l_sum = np.sum(x[index - int(window_size / 2): index])
  r_sum = np.sum(x[index + 1: index + int(window_size / 2)])

  if orientation == 'LR':
    if r_sum > l_sum * frequency_factor:
      return True
    else:
      return False
  else:
    if r_sum * frequency_factor > l_sum:
      return True
    else:
      return False

def mask1d(gray_img, kernel_size, threshold=20):
  if kernel_size % 2 != 1:
    raise Exception("Kernel size must be an odd number.")


  mask = np.zeros(gray_img.shape, dtype=np.uint8)
  filter = np.ones(kernel_size) / kernel_size

  for y in range(gray_img.shape[0]):
    delta = np.convolve(gray_img[y,:], filter, mode='same') - gray_img[y,:]
    mask[y, (np.abs(delta) > threshold)] = 255.

  return mask

def mask(gray_img, kernel_size, threshold=20):
  if kernel_size % 2 != 1:
    raise Exception("Kernel size must be an odd number.")

  xd = mask1d(gray_img, 9, 20)
  yd = mask1d(np.transpose(gray_img), 9, 20).transpose()
  mask = xd /2 + yd / 2

  return mask

def denoise(gray_img, kernel_size, percent_activated_threshold=0.4):
  if kernel_size % 2 != 1:
    raise Exception("Kernel size must be an odd number.")

  activation_cutoff = percent_activated_threshold * kernel_size * kernel_size * 255
  denoised_img = gray_img.copy()

  for j in range(int(kernel_size / 2), gray_img.shape[0] - int(kernel_size / 2)):
    for k in range(int(kernel_size / 2), gray_img.shape[1] - int(kernel_size / 2)):
      if gray_img[j, k] > 120:
        if np.sum(gray_img[j:j+kernel_size,k:k+kernel_size]) < activation_cutoff:
          denoised_img[j, k] = 0

  return denoised_img

def detect_scale_contour(gray_img, padding=25):
  contour = []

  for j in range(padding, gray_img.shape[0] - padding):
    k = padding
    k_min = padding

    # Burn in period to make sure we are not detecting a scale on the edge
    while k < gray_img.shape[1] - padding and np.sum(gray_img[j, k-10:k+25]) > 30 * 255:
      k = k + 1

    while k < gray_img.shape[1] - padding:
      if gray_img[j, k] > 0 and scale_edge_detector(gray_img[j,:], k, 25, 5, 'LR'):
        contour.append((j, k))
        k_min = k
        k = gray_img.shape[1] - padding
      k = k + 1

    # Burn in period to make sure we are not detecting a scale on the edge
    while k > k_min and np.sum(gray_img[j, k-25:k+10]) > 30 * 255:
      k = k - 1

    while k > k_min:
      if gray_img[j, k] > 0 and scale_edge_detector(gray_img[j,:], k, 25, 5, 'RL'):
        contour.append((j, k))
        k = 0
      k = k - 1

  return contour

def dilate_contour(contour, thickness):

  dialated_contour = set()
  for (j, k) in contour:
    for l in range(j - thickness, j + thickness):
      for m in range(k - thickness, k + thickness):
        dialated_contour.add((l, m))

  return list(dialated_contour)

def draw_box(gray_img, top_left_point, bottom_right_point, color=255):
  j1, k1 = top_left_point
  j2, k2 = bottom_right_point

  gray_img[j1,k1:k2+1] = color
  gray_img[j2,k1:k2+1] = color
  gray_img[j1:j2+1,k1] = color
  gray_img[j1:j2+1,k2] = color

def draw_line(gray_img, mid_point, end_point, color=255):

  rr, cc = drw.line(*mid_point, *end_point)
  gray_img[rr, cc] = color

def draw_contour(size, contour, color=255):

  img = np.zeros(size, dtype=np.uint8)
  for (j, k) in contour:
    img[j, k] = color

  return img

def load_img_to_gray(file):
  img = imread(file)
  gray = rgb2gray(img)

  return gray

def show_image_and_contour(gray):

  plt.imshow(gray, cmap=plt.get_cmap('gray'))
  plt.show()

  masked_image = mask(gray, 9, 20)
  denoised_mask = denoise(masked_image, 101, .025)

  contour = detect_scale_contour(denoised_mask, 100)
  dilated_contour = dilate_contour(contour, 5)
  drawn_contour = draw_contour(denoised_mask.shape, dilated_contour)

  plt.imshow(np.abs(drawn_contour - 255), cmap=plt.get_cmap('gray'))
  plt.show()

def frame_image_w_mean(gray, j_m, k_m):
  mean_pixel_value = np.mean(gray)

  if j_m - SCALE_HEIGHT // 2 > 0:
    gray[0:j_m - SCALE_HEIGHT // 2,:] = mean_pixel_value
    gray[j_m + SCALE_HEIGHT // 2:,:] = mean_pixel_value

  if k_m - SCALE_WIDTH // 2 > 0:
    gray[:, 0:k_m - SCALE_WIDTH // 2] = mean_pixel_value
    gray[:,k_m + SCALE_WIDTH // 2:] = mean_pixel_value

  #return gray

def calculate_transect_endpoint(mid_point, offset, length):
  """
  Given an offset from a line extending direclty down from the
  mid-point, determine the coordinates of the other endpoint of
  a line that starts at the mid-point and extends in the direction
  of the offset of specified length

  :param mid_point: the coordinates of the mid-point in row-major format
  :param offset: offset angle in radians from 6 o'clock applied counter-clockwise
  :param length: describe about parameter p3
  :return: the coordinates of the endpoint in row-major format
  """
  j, k = mid_point

  return (j + int(length * math.cos(offset)),
          k + int(length * math.sin(offset)))

def calculate_transect_angle(mid_point, end_point):
  """
  Given two points, calculated the angle between a line that
  extends down from the mid-point, opens counter-clockwise
  to the line that is defined by the mid_point and end_point

  :param mid_point: the coordinates of the mid-point in row-major format
  :param end_point: the coordinates of the end-point of the transect
     in row-major format
  :return: angle in radians
  """

  offset = 0

  # if the transect angle is at pi/2 or 3 pi/2, the atan will be undefined
  if abs(mid_point[0] - end_point[0]) < 1e-5:
    if mid_point[0] < end_point[0]:
      offset = math.pi / 2
    else:
      offset = 3 * math.pi / 2

  else:
    offset = math.atan((mid_point[1] - end_point[1]) /
                       (mid_point[0] - end_point[0]))

    # if end point is above mid point, add pi to offset as it would have
    #  been caculated relative to line extending above mid point.
    if(end_point[0] < mid_point[0]):
      offset = offset + math.pi

    # if offset is negative, add to 2pi
    if(end_point[1] < mid_point[1]):
      offset = 2 * math.pi + offset

  return offset

def calculate_coordinates_of_transects(mid_point, transect_angle, offset_step_size, transect_count):
  """
  Determine the coordintates of points along transect lines at specified offsets
  from an initial trasect.

  :param mid_point: the coordinates of the mid-point in row-major format
  :param offset: transect angle in radians from 6 o'clock applied counter-clockwise
  :param offset_step_size: Offset in radians between transects
  :param transect_count: The number of transects to generate in addition to
    main transect
  :return: a list of lists containing the coordinates of points on transects
    extending out from the mid_point.  Indexing of transects alternates out
    from main transect.
  """
  transects_coordinates = []
  calculate_transect_endpoint(mid_point, transect_angle, TRANSECT_LENGTH)
  transects_coordinates.append(drw.line(*mid_point,
                                        *calculate_transect_endpoint(mid_point, transect_angle, TRANSECT_LENGTH))
                               )

  for offset in [o for i in range(1, int(transect_count / 2) + 1) for o in (i * offset_step_size, -i * offset_step_size)]:
    transects_coordinates.append(drw.line(*mid_point,
                                          *calculate_transect_endpoint(mid_point, transect_angle + offset, TRANSECT_LENGTH))
                                 )

  return transects_coordinates

def draw_transects(gray_img, transects_coordinates, color = 250):
  """
  Draws transects on a copy of grayscale image.

  :param gray_img: 2d array of a grayscale image
  :param trasects_coordinates: a list of lists containing the coordinates of points on transects
    extending out from the mid_point.  Indexing of transects alternates out
    from main transect.
  :param color: pixel value for drawn transect
  :return: 2d array representing grayscale image with transects applied
  """
  img_w_transects = np.copy(gray_img)
  j_max = gray_img.shape[0]
  k_max = gray_img.shape[1]

  for i, transect in enumerate(transects_coordinates):
    rr, cc = transect
    rr[rr >= j_max] = j_max - 1
    cc[cc >= k_max] = k_max - 1

    img_w_transects[rr, cc] = color

  return img_w_transects

def extract_transects_signals(gray_img, transects_coordinates):

  transect_signals = []
  for i, transect in enumerate(transects_coordinates):
    signal = []
    rr, cc = transect
    for j, k in zip(rr, cc):
      signal.append(gray_img[j, k])
    transect_signals.append(signal)

  return transect_signals

def convolve_transects_signals(transects_signals, kernel_size):

  filter = np.ones(kernel_size) / kernel_size
  convolved_signals = []

  for signal in transects_signals:
    convolved_signals.append(convolve_transects_signal(signal, kernel_size))

  return convolved_signals

def convolve_transects_signal(transects_signal, kernel_size):

  filter = np.ones(kernel_size) / kernel_size
  signal_length = max(len(transects_signal), kernel_size) - min(len(transects_signal), kernel_size) + 1
  offset = int((len(transects_signal) - signal_length) / 2)
  return(np.convolve(transects_signal, filter, mode='valid') - transects_signal[offset:-offset])


def plot_transect_signals(transects_signals, figure_path, figure_filename):
  n = len(transects)

  fig, axes = plt.subplots(2 * n)
  for i, signal in enumerate(transects_signals):
    axes[i].plot(signal)

  convolved_signals = convolve_transects_signals(transects_signals, 5)
  for i, signal in enumerate(convolved_signals):
    axes[i + n].plot(signal)

  fig.savefig(os.path.join(figure_path, figure_filename +".png"), format="png",
              bbox_inches="tight")

def plot_transect_signals_for_image(filepath, mid_point, transect_angle,
                                    offset_step_size, transect_count,
                                    figure_path):
  gray = load_img_to_gray(filepath)
  filename = os.path.splitext(os.path.basename(filepath))[0]

  transects = calculate_coordinates_of_transects(mid_point, transect_angle,
                                                 offset_step_size, transect_count)
  transects_signals = extract_transects_signals(gray, transects)

  plot_transect_signals(transects_signals, figure_path, filename)

# %%
import pandas as pd
from ast import literal_eval

scale_data = pd.read_csv('/content/drive/MyDrive/Images/SalmonFishScalesCoordinates-V2.csv', sep=",",
                          names=['filename', 'lt_center', 'br_center', 'end_point'],
                          dtype={'filename': 'string'},
                          converters={'lt_center': literal_eval,
                                      'br_center': literal_eval,
                                      'end_point': literal_eval},
                          header=0)
scale_data['filepath'] = scale_data.apply(lambda row: os.path.join(PATH, row['filename']) +  ".tif", axis=1)

# Switch from column-major to row major
scale_data['lt_center'] = scale_data.apply(lambda row: (row['lt_center'][1], row['lt_center'][0]) , axis = 1)
scale_data['br_center'] = scale_data.apply(lambda row: (row['br_center'][1], row['br_center'][0]) , axis = 1)
scale_data['end_point'] = scale_data.apply(lambda row: (row['end_point'][1], row['end_point'][0]) , axis = 1)

scale_data['mid_center'] = scale_data.apply(lambda row: (int((row['lt_center'][0] + row['br_center'][0]) / 2),
                                                         int((row['lt_center'][1] + row['br_center'][1]) / 2)) , axis=1)
scale_data['transect_angle'] = scale_data.apply(lambda row: calculate_transect_angle(row['mid_center'], row['end_point']), axis=1)

scale_data['id'] = scale_data.apply(lambda row: int(row['filename'].split('_')[0]), axis=1)

# Bring in labels
label_data = pd.read_csv('/content/drive/MyDrive/Images/labels.csv', sep=",",
                          names=['id', 'age', 'type', 'fold'],
                          dtype={'filename': 'int64', 'age': 'int32', 'type': 'int32', 'fold': 'int32'},
                          header=0)

# Fold in labels with scale data
scale_data = scale_data.merge(label_data, on='id', how='left', validate='many_to_one')

# Drop any rows with NaNs, recast ints
scale_data = scale_data.dropna().astype({'fold': int, 'type': int})

# %%
# Get transect signals
transects_signals = []

for index, row in scale_data.iterrows():
  #print(index, row['id'], row['filename'], row['fold'])

  gray = load_img_to_gray(row['filepath'])
  transects = calculate_coordinates_of_transects(row['mid_center'],
                                                 row['transect_angle'],
                                                 .1, 11)

  transects_signals.append([row['id'],
                           extract_transects_signals(gray, transects)],
                           )

transects_signals_df = pd.DataFrame(transects_signals, columns=['id', 'signals'])

# Merge with labels and explode
transects_signals_df = transects_signals_df.merge(label_data, on='id',
                                                  how='left',
                                                  validate='many_to_one')\
                                                  .explode('signals', ignore_index=True)\
                                                  .rename(columns={"signals": "signal"})
transects_signals_df['signal'] = transects_signals_df['signal'].apply(lambda x: np.array(x))

# Add convolved signals
transects_signals_df['convolved_signal'] = transects_signals_df.apply(lambda row: convolve_transects_signal(row['signal'], 5), axis=1)

# %% [markdown]
# ## Ensemble Approach

# %%
# Create a copy of transects_signals_df so that it doesn't have to be generated
#  each time
from numpy.fft import fft, ifft

def rolling_window(a, window, step):
    shape = a.shape[:-1] + ((a.shape[-1] - window + 1)//step, window)
    strides = (a.strides[0] * step,) + (a.strides[-1],)
    return np.lib.stride_tricks.as_strided(a, shape=shape, strides=strides)

#print(rolling_window(s[2], 25, 1).shape)

# Define Transect Configurations
transect_configurations = [7, 9]  # Different numbers of transects for each model

ensemble_predictions = []  # List to store predictions from each model in the ensemble

# Iterate over each transect configuration
for num_transects in transect_configurations:

    # Modifing Data Preparation
    df = transects_signals_df.copy(deep=True)
    df['signal'] = df['signal'].apply(lambda x: np.pad(x, (0, int(1.4 * TRANSECT_LENGTH) - x.size), 'constant', constant_values=(0, 0)))
    df['signal'] = df['signal'].apply(lambda x: np.flip(x))
    df['convolved_signal'] = df['convolved_signal'].apply(lambda x: np.pad(x, (0, int(1.4 * TRANSECT_LENGTH) - x.size), 'constant', constant_values=(0, 0)))
    df['convolved_signal'] = df['convolved_signal'].apply(lambda x: np.flip(x))
    df['convolved_freq'] = df['signal'].apply(lambda x: np.abs(fft(x))[0:75])

    # Splitting Dataset
    train = df[df['fold'] < 9][['convolved_freq', 'type']].to_numpy(copy=True)
    val = df[df['fold'] >= 9][['convolved_freq', 'type']].to_numpy(copy=True)

    x_train = np.stack(train[:,0])
    x_max = np.max(x_train)
    x_train = x_train / x_max

    y_train = train[:,1].astype(int)

    x_val = np.stack(val[:,0]) / x_max
    y_val = val[:,1].astype(int)

    # Defining Ensemble Models
    models = []  # List to store instances of neural network models

    NUM_MODELS_IN_ENSEMBLE = 3

    import keras

    for _ in range(NUM_MODELS_IN_ENSEMBLE):
        # Define neural network model (same architecture as before)
        model = keras.Sequential([
            keras.layers.Dense(256, activation='relu'),
            keras.layers.Dropout(.5),
            keras.layers.Dense(256, activation='relu'),
            keras.layers.Dropout(.75),
            keras.layers.Dense(124, activation='relu'),
            keras.layers.Dropout(.75),
            keras.layers.Dense(2, activation='softmax')
        ])

        # Compiling model
        model.compile(optimizer='rmsprop', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

        models.append(model)  # Add model instance to ensemble

    # Training Ensemble Models
    for model in models:
        model.fit(x=x_train, y=y_train, batch_size=256, epochs=350, validation_data=(x_val, y_val), verbose=1)
# Out:
# Epoch 1/350
# 8/8 [==============================] - 2s 43ms/step - loss: 0.6995 - accuracy: 0.5170 - val_loss: 0.6850 - val_accuracy: 0.6000
# Epoch 2/350
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6959 - accuracy: 0.5216 - val_loss: 0.6839 - val_accuracy: 0.6000
# Epoch 3/350
# 8/8 [==============================] - 0s 13ms/step - loss: 0.6898 - accuracy: 0.5333 - val_loss: 0.6824 - val_accuracy: 0.6000
# Epoch 4/350
# 8/8 [==============================] - 0s 17ms/step - loss: 0.6933 - accuracy: 0.5394 - val_loss: 0.6837 - val_accuracy: 0.6000
# Epoch 5/350
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6901 - accuracy: 0.5510 - val_loss: 0.6818 - val_accuracy: 0.6000
# Epoch 6/350
# 8/8 [==============================] - 0s 13ms/step - loss: 0.6906 - accuracy: 0.5475 - val_loss: 0.6808 - val_accuracy: 0.6000
# Epoch 7/350
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6888 - accuracy: 0.5490 - val_loss: 0.6810 - val_accuracy: 0.6000
# Epoch 8/350
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6904 - accuracy: 0.5460 - val_loss: 0.6804 - val_accuracy: 0.6000
# Epoch 9/350
# 8/8 [==============================] - 0s 13ms/step - loss: 0.6885 - accuracy: 0.5500 - val_loss: 0.6798 - val_accuracy: 0.6000
# Epoch 10/350
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6884 - accuracy: 0.5531 - val_loss: 0.6791 - val_accuracy: 0.6000
# Epoch 11/350
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6876 - accuracy: 0.5521 - val_loss: 0.6791 - val_accuracy: 0.6000
# Epoch 12/350
# 8/8 [==============================] - 0s 13ms/step - loss: 0.6856 - accuracy: 0.5729 - val_loss: 0.6787 - val_accuracy: 0.6000
# Epoch 13/350
# 8/8 [==============================] - 0s 17ms/step - loss: 0.6878 - accuracy: 0.5536 - val_loss: 0.6777 - val_accuracy: 0.6000
# Epoch 14/350
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6888 - accuracy: 0.5505 - val_loss: 0.6772 - val_accuracy: 0.6000
# Epoch 15/350
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6860 - accuracy: 0.5602 - val_loss: 0.6765 - val_accuracy: 0.6000
# Epoch 16/350
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6904 - accuracy: 0.5500 - val_loss: 0.6762 - val_accuracy: 0.6000
# Epoch 17/350
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6887 - accuracy: 0.5627 - val_loss: 0.6763 - val_accuracy: 0.6000
# Epoch 18/350
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6877 - accuracy: 0.5602 - val_loss: 0.6770 - val_accuracy: 0.6000
# Epoch 19/350
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6879 - accuracy: 0.5612 - val_loss: 0.6767 - val_accuracy: 0.6000
# Epoch 20/350
# 8/8 [==============================] - 0s 13ms/step - loss: 0.6870 - accuracy: 0.5526 - val_loss: 0.6766 - val_accuracy: 0.6000
# Epoch 21/350
# 8/8 [==============================] - 0s 17ms/step - loss: 0.6859 - accuracy: 0.5576 - val_loss: 0.6754 - val_accuracy: 0.6000
# Epoch 22/350
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6848 - accuracy: 0.5678 - val_loss: 0.6745 - val_accuracy: 0.6000
# Epoch 23/350
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6879 - accuracy: 0.5546 - val_loss: 0.6747 - val_accuracy: 0.6000
# Epoch 24/350
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6877 - accuracy: 0.5597 - val_loss: 0.6743 - val_accuracy: 0.6000
# Epoch 25/350
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6848 - accuracy: 0.5607 - val_loss: 0.6738 - val_accuracy: 0.6000
# Epoch 26/350
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6836 - accuracy: 0.5688 - val_loss: 0.6719 - val_accuracy: 0.6000
# Epoch 27/350
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6841 - accuracy: 0.5693 - val_loss: 0.6706 - val_accuracy: 0.6000
# Epoch 28/350
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6829 - accuracy: 0.5617 - val_loss: 0.6689 - val_accuracy: 0.6000
# Epoch 29/350
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6877 - accuracy: 0.5653 - val_loss: 0.6693 - val_accuracy: 0.6000
# Epoch 30/350
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6860 - accuracy: 0.5607 - val_loss: 0.6685 - val_accuracy: 0.6000
# Epoch 31/350
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6852 - accuracy: 0.5648 - val_loss: 0.6686 - val_accuracy: 0.6000
# Epoch 32/350
# 8/8 [==============================] - 0s 13ms/step - loss: 0.6847 - accuracy: 0.5703 - val_loss: 0.6680 - val_accuracy: 0.6000
# Epoch 33/350
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6838 - accuracy: 0.5673 - val_loss: 0.6662 - val_accuracy: 0.6000
# Epoch 34/350
# 8/8 [==============================] - 0s 13ms/step - loss: 0.6828 - accuracy: 0.5719 - val_loss: 0.6645 - val_accuracy: 0.6000
# Epoch 35/350
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6804 - accuracy: 0.5739 - val_loss: 0.6617 - val_accuracy: 0.6000
# Epoch 36/350
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6835 - accuracy: 0.5719 - val_loss: 0.6601 - val_accuracy: 0.6026
# Epoch 37/350
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6832 - accuracy: 0.5734 - val_loss: 0.6577 - val_accuracy: 0.6000
# Epoch 38/350
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6825 - accuracy: 0.5668 - val_loss: 0.6554 - val_accuracy: 0.6000
# Epoch 39/350
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6810 - accuracy: 0.5775 - val_loss: 0.6533 - val_accuracy: 0.6000
# Epoch 40/350
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6790 - accuracy: 0.5846 - val_loss: 0.6480 - val_accuracy: 0.6078
# Epoch 41/350
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6760 - accuracy: 0.5947 - val_loss: 0.6397 - val_accuracy: 0.7481
# Epoch 42/350
# 8/8 [==============================] - 0s 17ms/step - loss: 0.6759 - accuracy: 0.5830 - val_loss: 0.6360 - val_accuracy: 0.7870
# Epoch 43/350
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6727 - accuracy: 0.5881 - val_loss: 0.6332 - val_accuracy: 0.6545
# Epoch 44/350
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6764 - accuracy: 0.5820 - val_loss: 0.6254 - val_accuracy: 0.7455
# Epoch 45/350
# 8/8 [==============================] - 0s 13ms/step - loss: 0.6732 - accuracy: 0.5973 - val_loss: 0.6208 - val_accuracy: 0.7584
# Epoch 46/350
# 8/8 [==============================] - 0s 13ms/step - loss: 0.6675 - accuracy: 0.6084 - val_loss: 0.6175 - val_accuracy: 0.7429
# Epoch 47/350
# 8/8 [==============================] - 0s 18ms/step - loss: 0.6685 - accuracy: 0.5973 - val_loss: 0.6049 - val_accuracy: 0.7948
# Epoch 48/350
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6647 - accuracy: 0.6181 - val_loss: 0.5975 - val_accuracy: 0.7974
# Epoch 49/350
# 8/8 [==============================] - 0s 17ms/step - loss: 0.6633 - accuracy: 0.6155 - val_loss: 0.5940 - val_accuracy: 0.7922
# Epoch 50/350
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6638 - accuracy: 0.6115 - val_loss: 0.5807 - val_accuracy: 0.8000
# Epoch 51/350
# 8/8 [==============================] - 0s 13ms/step - loss: 0.6609 - accuracy: 0.6110 - val_loss: 0.5821 - val_accuracy: 0.7948
# Epoch 52/350
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6576 - accuracy: 0.6247 - val_loss: 0.5651 - val_accuracy: 0.8000
# Epoch 53/350
# 8/8 [==============================] - 0s 13ms/step - loss: 0.6620 - accuracy: 0.6115 - val_loss: 0.5598 - val_accuracy: 0.8026
# Epoch 54/350
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6569 - accuracy: 0.6176 - val_loss: 0.5721 - val_accuracy: 0.8026
# Epoch 55/350
# 8/8 [==============================] - 0s 13ms/step - loss: 0.6536 - accuracy: 0.6221 - val_loss: 0.5574 - val_accuracy: 0.8026
# Epoch 56/350
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6591 - accuracy: 0.6155 - val_loss: 0.5434 - val_accuracy: 0.8156
# Epoch 57/350
# 8/8 [==============================] - 0s 13ms/step - loss: 0.6493 - accuracy: 0.6303 - val_loss: 0.5380 - val_accuracy: 0.8078
# Epoch 58/350
# 8/8 [==============================] - 0s 20ms/step - loss: 0.6539 - accuracy: 0.6145 - val_loss: 0.5506 - val_accuracy: 0.8000
# Epoch 59/350
# 8/8 [==============================] - 0s 21ms/step - loss: 0.6557 - accuracy: 0.6150 - val_loss: 0.5388 - val_accuracy: 0.7974
# Epoch 60/350
# 8/8 [==============================] - 0s 21ms/step - loss: 0.6463 - accuracy: 0.6359 - val_loss: 0.5346 - val_accuracy: 0.7844
# Epoch 61/350
# 8/8 [==============================] - 0s 20ms/step - loss: 0.6455 - accuracy: 0.6318 - val_loss: 0.5400 - val_accuracy: 0.8000
# Epoch 62/350
# 8/8 [==============================] - 0s 21ms/step - loss: 0.6515 - accuracy: 0.6262 - val_loss: 0.5328 - val_accuracy: 0.8026
# Epoch 63/350
# 8/8 [==============================] - 0s 22ms/step - loss: 0.6468 - accuracy: 0.6267 - val_loss: 0.5535 - val_accuracy: 0.8000
# Epoch 64/350
# 8/8 [==============================] - 0s 22ms/step - loss: 0.6493 - accuracy: 0.6287 - val_loss: 0.5274 - val_accuracy: 0.8052
# Epoch 65/350
# 8/8 [==============================] - 0s 18ms/step - loss: 0.6517 - accuracy: 0.6232 - val_loss: 0.5155 - val_accuracy: 0.8182
# Epoch 66/350
# 8/8 [==============================] - 0s 19ms/step - loss: 0.6475 - accuracy: 0.6267 - val_loss: 0.5284 - val_accuracy: 0.8026
# Epoch 67/350
# 8/8 [==============================] - 0s 20ms/step - loss: 0.6440 - accuracy: 0.6313 - val_loss: 0.5349 - val_accuracy: 0.8000
# Epoch 68/350
# 8/8 [==============================] - 0s 21ms/step - loss: 0.6482 - accuracy: 0.6303 - val_loss: 0.5348 - val_accuracy: 0.8000
# Epoch 69/350
# 8/8 [==============================] - 0s 22ms/step - loss: 0.6446 - accuracy: 0.6287 - val_loss: 0.5237 - val_accuracy: 0.8052
# Epoch 70/350
# 8/8 [==============================] - 0s 20ms/step - loss: 0.6413 - accuracy: 0.6257 - val_loss: 0.5222 - val_accuracy: 0.8052
# Epoch 71/350
# 8/8 [==============================] - 0s 20ms/step - loss: 0.6408 - accuracy: 0.6343 - val_loss: 0.5265 - val_accuracy: 0.8000
# Epoch 72/350
# 8/8 [==============================] - 0s 19ms/step - loss: 0.6401 - accuracy: 0.6333 - val_loss: 0.5227 - val_accuracy: 0.8026
# Epoch 73/350
# 8/8 [==============================] - 0s 21ms/step - loss: 0.6441 - accuracy: 0.6313 - val_loss: 0.5129 - val_accuracy: 0.8052
# Epoch 74/350
# 8/8 [==============================] - 0s 21ms/step - loss: 0.6416 - accuracy: 0.6409 - val_loss: 0.4924 - val_accuracy: 0.8234
# Epoch 75/350
# 8/8 [==============================] - 0s 23ms/step - loss: 0.6415 - accuracy: 0.6277 - val_loss: 0.4922 - val_accuracy: 0.8260
# Epoch 76/350
# 8/8 [==============================] - 0s 20ms/step - loss: 0.6424 - accuracy: 0.6399 - val_loss: 0.4941 - val_accuracy: 0.8234
# Epoch 77/350
# 8/8 [==============================] - 0s 22ms/step - loss: 0.6379 - accuracy: 0.6460 - val_loss: 0.5268 - val_accuracy: 0.8078
# Epoch 78/350
# 8/8 [==============================] - 0s 22ms/step - loss: 0.6343 - accuracy: 0.6409 - val_loss: 0.4954 - val_accuracy: 0.8182
# Epoch 79/350
# 8/8 [==============================] - 0s 22ms/step - loss: 0.6392 - accuracy: 0.6414 - val_loss: 0.4973 - val_accuracy: 0.8182
# Epoch 80/350
# 8/8 [==============================] - 0s 21ms/step - loss: 0.6358 - accuracy: 0.6404 - val_loss: 0.4997 - val_accuracy: 0.8156
# Epoch 81/350
# 8/8 [==============================] - 0s 24ms/step - loss: 0.6390 - accuracy: 0.6394 - val_loss: 0.5000 - val_accuracy: 0.8182
# Epoch 82/350
# 8/8 [==============================] - 0s 23ms/step - loss: 0.6384 - accuracy: 0.6318 - val_loss: 0.5144 - val_accuracy: 0.8078
# Epoch 83/350
# 8/8 [==============================] - 0s 22ms/step - loss: 0.6314 - accuracy: 0.6399 - val_loss: 0.5054 - val_accuracy: 0.8026
# Epoch 84/350
# 8/8 [==============================] - 0s 22ms/step - loss: 0.6409 - accuracy: 0.6313 - val_loss: 0.5033 - val_accuracy: 0.8078
# Epoch 85/350
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6353 - accuracy: 0.6404 - val_loss: 0.5338 - val_accuracy: 0.7896
# Epoch 86/350
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6326 - accuracy: 0.6465 - val_loss: 0.5002 - val_accuracy: 0.8104
# Epoch 87/350
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6365 - accuracy: 0.6445 - val_loss: 0.4845 - val_accuracy: 0.8208
# Epoch 88/350
# 8/8 [==============================] - 0s 17ms/step - loss: 0.6348 - accuracy: 0.6374 - val_loss: 0.4877 - val_accuracy: 0.8156
# Epoch 89/350
# 8/8 [==============================] - 0s 13ms/step - loss: 0.6401 - accuracy: 0.6359 - val_loss: 0.4837 - val_accuracy: 0.8234
# Epoch 90/350
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6377 - accuracy: 0.6374 - val_loss: 0.4869 - val_accuracy: 0.8208
# Epoch 91/350
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6379 - accuracy: 0.6364 - val_loss: 0.4923 - val_accuracy: 0.8182
# Epoch 92/350
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6406 - accuracy: 0.6359 - val_loss: 0.4927 - val_accuracy: 0.8182
# Epoch 93/350
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6340 - accuracy: 0.6364 - val_loss: 0.5013 - val_accuracy: 0.8104
# Epoch 94/350
# 8/8 [==============================] - 0s 13ms/step - loss: 0.6320 - accuracy: 0.6435 - val_loss: 0.4899 - val_accuracy: 0.8182
# Epoch 95/350
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6346 - accuracy: 0.6379 - val_loss: 0.4789 - val_accuracy: 0.8364
# Epoch 96/350
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6317 - accuracy: 0.6389 - val_loss: 0.5051 - val_accuracy: 0.8156
# Epoch 97/350
# 8/8 [==============================] - 0s 19ms/step - loss: 0.6337 - accuracy: 0.6338 - val_loss: 0.4910 - val_accuracy: 0.8156
# Epoch 98/350
# 8/8 [==============================] - 0s 13ms/step - loss: 0.6321 - accuracy: 0.6414 - val_loss: 0.4802 - val_accuracy: 0.8182
# Epoch 99/350
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6347 - accuracy: 0.6455 - val_loss: 0.4914 - val_accuracy: 0.8078
# Epoch 100/350
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6283 - accuracy: 0.6420 - val_loss: 0.4789 - val_accuracy: 0.8182
# Epoch 101/350
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6274 - accuracy: 0.6475 - val_loss: 0.4834 - val_accuracy: 0.8156
# Epoch 102/350
# 8/8 [==============================] - 0s 12ms/step - loss: 0.6291 - accuracy: 0.6430 - val_loss: 0.4724 - val_accuracy: 0.8312
# Epoch 103/350
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6325 - accuracy: 0.6470 - val_loss: 0.4877 - val_accuracy: 0.8156
# Epoch 104/350
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6327 - accuracy: 0.6404 - val_loss: 0.4871 - val_accuracy: 0.8182
# Epoch 105/350
# 8/8 [==============================] - 0s 17ms/step - loss: 0.6302 - accuracy: 0.6399 - val_loss: 0.4689 - val_accuracy: 0.8364
# Epoch 106/350
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6341 - accuracy: 0.6328 - val_loss: 0.5013 - val_accuracy: 0.8104
# Epoch 107/350
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6364 - accuracy: 0.6379 - val_loss: 0.4680 - val_accuracy: 0.8338
# Epoch 108/350
# 8/8 [==============================] - 0s 13ms/step - loss: 0.6320 - accuracy: 0.6384 - val_loss: 0.4937 - val_accuracy: 0.8182
# Epoch 109/350
# 8/8 [==============================] - 0s 13ms/step - loss: 0.6330 - accuracy: 0.6460 - val_loss: 0.4701 - val_accuracy: 0.8390
# Epoch 110/350
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6287 - accuracy: 0.6430 - val_loss: 0.4797 - val_accuracy: 0.8182
# Epoch 111/350
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6321 - accuracy: 0.6404 - val_loss: 0.4835 - val_accuracy: 0.8156
# Epoch 112/350
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6338 - accuracy: 0.6394 - val_loss: 0.5006 - val_accuracy: 0.8104
# Epoch 113/350
# 8/8 [==============================] - 0s 13ms/step - loss: 0.6256 - accuracy: 0.6425 - val_loss: 0.4875 - val_accuracy: 0.8156
# Epoch 114/350
# 8/8 [==============================] - 0s 18ms/step - loss: 0.6323 - accuracy: 0.6399 - val_loss: 0.4977 - val_accuracy: 0.8078
# Epoch 115/350
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6302 - accuracy: 0.6440 - val_loss: 0.4756 - val_accuracy: 0.8234
# Epoch 116/350
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6262 - accuracy: 0.6430 - val_loss: 0.4768 - val_accuracy: 0.8182
# Epoch 117/350
# 8/8 [==============================] - 0s 13ms/step - loss: 0.6320 - accuracy: 0.6369 - val_loss: 0.4989 - val_accuracy: 0.8078
# Epoch 118/350
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6267 - accuracy: 0.6465 - val_loss: 0.4852 - val_accuracy: 0.8182
# Epoch 119/350
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6296 - accuracy: 0.6475 - val_loss: 0.4767 - val_accuracy: 0.8182
# Epoch 120/350
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6278 - accuracy: 0.6425 - val_loss: 0.4760 - val_accuracy: 0.8208
# Epoch 121/350
# 8/8 [==============================] - 0s 13ms/step - loss: 0.6328 - accuracy: 0.6450 - val_loss: 0.4667 - val_accuracy: 0.8312
# Epoch 122/350
# 8/8 [==============================] - 0s 17ms/step - loss: 0.6371 - accuracy: 0.6420 - val_loss: 0.4705 - val_accuracy: 0.8364
# Epoch 123/350
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6309 - accuracy: 0.6465 - val_loss: 0.4775 - val_accuracy: 0.8234
# Epoch 124/350
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6331 - accuracy: 0.6420 - val_loss: 0.5384 - val_accuracy: 0.7766
# Epoch 125/350
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6329 - accuracy: 0.6460 - val_loss: 0.4769 - val_accuracy: 0.8286
# Epoch 126/350
# 8/8 [==============================] - 0s 13ms/step - loss: 0.6294 - accuracy: 0.6420 - val_loss: 0.4808 - val_accuracy: 0.8182
# Epoch 127/350
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6276 - accuracy: 0.6475 - val_loss: 0.4707 - val_accuracy: 0.8312
# Epoch 128/350
# 8/8 [==============================] - 0s 13ms/step - loss: 0.6255 - accuracy: 0.6480 - val_loss: 0.4840 - val_accuracy: 0.8182
# Epoch 129/350
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6280 - accuracy: 0.6480 - val_loss: 0.4747 - val_accuracy: 0.8286
# Epoch 130/350
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6256 - accuracy: 0.6470 - val_loss: 0.5037 - val_accuracy: 0.8000
# Epoch 131/350
# 8/8 [==============================] - 0s 17ms/step - loss: 0.6273 - accuracy: 0.6455 - val_loss: 0.4910 - val_accuracy: 0.8156
# Epoch 132/350
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6256 - accuracy: 0.6475 - val_loss: 0.5015 - val_accuracy: 0.8078
# Epoch 133/350
# 8/8 [==============================] - 0s 13ms/step - loss: 0.6290 - accuracy: 0.6475 - val_loss: 0.5253 - val_accuracy: 0.7896
# Epoch 134/350
# 8/8 [==============================] - 0s 13ms/step - loss: 0.6273 - accuracy: 0.6445 - val_loss: 0.4822 - val_accuracy: 0.8234
# Epoch 135/350
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6238 - accuracy: 0.6455 - val_loss: 0.4752 - val_accuracy: 0.8260
# Epoch 136/350
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6234 - accuracy: 0.6475 - val_loss: 0.5088 - val_accuracy: 0.7974
# Epoch 137/350
# 8/8 [==============================] - 0s 13ms/step - loss: 0.6263 - accuracy: 0.6465 - val_loss: 0.4780 - val_accuracy: 0.8182
# Epoch 138/350
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6242 - accuracy: 0.6480 - val_loss: 0.5220 - val_accuracy: 0.7896
# Epoch 139/350
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6276 - accuracy: 0.6440 - val_loss: 0.4883 - val_accuracy: 0.8156
# Epoch 140/350
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6355 - accuracy: 0.6389 - val_loss: 0.5130 - val_accuracy: 0.7922
# Epoch 141/350
# 8/8 [==============================] - 0s 13ms/step - loss: 0.6234 - accuracy: 0.6486 - val_loss: 0.4796 - val_accuracy: 0.8234
# Epoch 142/350
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6277 - accuracy: 0.6470 - val_loss: 0.4651 - val_accuracy: 0.8364
# Epoch 143/350
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6329 - accuracy: 0.6470 - val_loss: 0.4591 - val_accuracy: 0.8442
# Epoch 144/350
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6310 - accuracy: 0.6440 - val_loss: 0.5010 - val_accuracy: 0.8078
# Epoch 145/350
# 8/8 [==============================] - 0s 13ms/step - loss: 0.6220 - accuracy: 0.6506 - val_loss: 0.4873 - val_accuracy: 0.8182
# Epoch 146/350
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6297 - accuracy: 0.6445 - val_loss: 0.4914 - val_accuracy: 0.8156
# Epoch 147/350
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6256 - accuracy: 0.6455 - val_loss: 0.4638 - val_accuracy: 0.8364
# Epoch 148/350
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6228 - accuracy: 0.6445 - val_loss: 0.4580 - val_accuracy: 0.8390
# Epoch 149/350
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6193 - accuracy: 0.6480 - val_loss: 0.4722 - val_accuracy: 0.8286
# Epoch 150/350
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6244 - accuracy: 0.6511 - val_loss: 0.4692 - val_accuracy: 0.8312
# Epoch 151/350
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6222 - accuracy: 0.6465 - val_loss: 0.4840 - val_accuracy: 0.8130
# Epoch 152/350
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6272 - accuracy: 0.6480 - val_loss: 0.4849 - val_accuracy: 0.8130
# Epoch 153/350
# 8/8 [==============================] - 0s 13ms/step - loss: 0.6212 - accuracy: 0.6511 - val_loss: 0.4754 - val_accuracy: 0.8260
# Epoch 154/350
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6268 - accuracy: 0.6399 - val_loss: 0.4779 - val_accuracy: 0.8208
# Epoch 155/350
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6182 - accuracy: 0.6506 - val_loss: 0.4563 - val_accuracy: 0.8364
# Epoch 156/350
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6370 - accuracy: 0.6455 - val_loss: 0.4639 - val_accuracy: 0.8338
# Epoch 157/350
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6207 - accuracy: 0.6486 - val_loss: 0.4859 - val_accuracy: 0.8104
# Epoch 158/350
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6221 - accuracy: 0.6455 - val_loss: 0.4669 - val_accuracy: 0.8260
# Epoch 159/350
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6239 - accuracy: 0.6491 - val_loss: 0.4654 - val_accuracy: 0.8312
# Epoch 160/350
# 8/8 [==============================] - 0s 13ms/step - loss: 0.6369 - accuracy: 0.6414 - val_loss: 0.5022 - val_accuracy: 0.8026
# Epoch 161/350
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6242 - accuracy: 0.6491 - val_loss: 0.4823 - val_accuracy: 0.8182
# Epoch 162/350
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6256 - accuracy: 0.6475 - val_loss: 0.4646 - val_accuracy: 0.8364
# Epoch 163/350
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6238 - accuracy: 0.6531 - val_loss: 0.4621 - val_accuracy: 0.8364
# Epoch 164/350
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6248 - accuracy: 0.6480 - val_loss: 0.4587 - val_accuracy: 0.8338
# Epoch 165/350
# 8/8 [==============================] - 0s 25ms/step - loss: 0.6244 - accuracy: 0.6496 - val_loss: 0.4564 - val_accuracy: 0.8390
# Epoch 166/350
# 8/8 [==============================] - 0s 27ms/step - loss: 0.6246 - accuracy: 0.6506 - val_loss: 0.4692 - val_accuracy: 0.8312
# Epoch 167/350
# 8/8 [==============================] - 0s 29ms/step - loss: 0.6208 - accuracy: 0.6511 - val_loss: 0.4534 - val_accuracy: 0.8442
# Epoch 168/350
# 8/8 [==============================] - 0s 21ms/step - loss: 0.6247 - accuracy: 0.6526 - val_loss: 0.4839 - val_accuracy: 0.8182
# Epoch 169/350
# 8/8 [==============================] - 0s 28ms/step - loss: 0.6265 - accuracy: 0.6470 - val_loss: 0.4646 - val_accuracy: 0.8338
# Epoch 170/350
# 8/8 [==============================] - 0s 30ms/step - loss: 0.6243 - accuracy: 0.6511 - val_loss: 0.4588 - val_accuracy: 0.8416
# Epoch 171/350
# 8/8 [==============================] - 0s 25ms/step - loss: 0.6272 - accuracy: 0.6440 - val_loss: 0.4796 - val_accuracy: 0.8234
# Epoch 172/350
# 8/8 [==============================] - 0s 25ms/step - loss: 0.6164 - accuracy: 0.6516 - val_loss: 0.4526 - val_accuracy: 0.8442
# Epoch 173/350
# 8/8 [==============================] - 0s 28ms/step - loss: 0.6281 - accuracy: 0.6475 - val_loss: 0.4842 - val_accuracy: 0.8156
# Epoch 174/350
# 8/8 [==============================] - 0s 28ms/step - loss: 0.6219 - accuracy: 0.6506 - val_loss: 0.4723 - val_accuracy: 0.8286
# Epoch 175/350
# 8/8 [==============================] - 0s 28ms/step - loss: 0.6167 - accuracy: 0.6546 - val_loss: 0.4472 - val_accuracy: 0.8442
# Epoch 176/350
# 8/8 [==============================] - 0s 29ms/step - loss: 0.6291 - accuracy: 0.6440 - val_loss: 0.5059 - val_accuracy: 0.7974
# Epoch 177/350
# 8/8 [==============================] - 0s 23ms/step - loss: 0.6218 - accuracy: 0.6526 - val_loss: 0.5179 - val_accuracy: 0.7870
# Epoch 178/350
# 8/8 [==============================] - 0s 27ms/step - loss: 0.6268 - accuracy: 0.6475 - val_loss: 0.4717 - val_accuracy: 0.8286
# Epoch 179/350
# 8/8 [==============================] - 0s 27ms/step - loss: 0.6214 - accuracy: 0.6501 - val_loss: 0.4830 - val_accuracy: 0.8234
# Epoch 180/350
# 8/8 [==============================] - 0s 25ms/step - loss: 0.6199 - accuracy: 0.6491 - val_loss: 0.4966 - val_accuracy: 0.8026
# Epoch 181/350
# 8/8 [==============================] - 0s 26ms/step - loss: 0.6178 - accuracy: 0.6470 - val_loss: 0.4617 - val_accuracy: 0.8390
# Epoch 182/350
# 8/8 [==============================] - 0s 33ms/step - loss: 0.6231 - accuracy: 0.6455 - val_loss: 0.5007 - val_accuracy: 0.8000
# Epoch 183/350
# 8/8 [==============================] - 0s 28ms/step - loss: 0.6186 - accuracy: 0.6521 - val_loss: 0.4681 - val_accuracy: 0.8338
# Epoch 184/350
# 8/8 [==============================] - 0s 32ms/step - loss: 0.6228 - accuracy: 0.6460 - val_loss: 0.5100 - val_accuracy: 0.7974
# Epoch 185/350
# 8/8 [==============================] - 0s 26ms/step - loss: 0.6173 - accuracy: 0.6506 - val_loss: 0.4824 - val_accuracy: 0.8130
# Epoch 186/350
# 8/8 [==============================] - 0s 27ms/step - loss: 0.6305 - accuracy: 0.6465 - val_loss: 0.4789 - val_accuracy: 0.8234
# Epoch 187/350
# 8/8 [==============================] - 0s 23ms/step - loss: 0.6204 - accuracy: 0.6531 - val_loss: 0.5253 - val_accuracy: 0.7792
# Epoch 188/350
# 8/8 [==============================] - 0s 30ms/step - loss: 0.6259 - accuracy: 0.6445 - val_loss: 0.4634 - val_accuracy: 0.8390
# Epoch 189/350
# 8/8 [==============================] - 0s 25ms/step - loss: 0.6236 - accuracy: 0.6552 - val_loss: 0.4751 - val_accuracy: 0.8208
# Epoch 190/350
# 8/8 [==============================] - 0s 31ms/step - loss: 0.6180 - accuracy: 0.6486 - val_loss: 0.4632 - val_accuracy: 0.8390
# Epoch 191/350
# 8/8 [==============================] - 0s 28ms/step - loss: 0.6182 - accuracy: 0.6470 - val_loss: 0.4743 - val_accuracy: 0.8260
# Epoch 192/350
# 8/8 [==============================] - 0s 24ms/step - loss: 0.6243 - accuracy: 0.6430 - val_loss: 0.4961 - val_accuracy: 0.8026
# Epoch 193/350
# 8/8 [==============================] - 0s 29ms/step - loss: 0.6201 - accuracy: 0.6450 - val_loss: 0.4610 - val_accuracy: 0.8390
# Epoch 194/350
# 8/8 [==============================] - 0s 26ms/step - loss: 0.6233 - accuracy: 0.6496 - val_loss: 0.4609 - val_accuracy: 0.8338
# Epoch 195/350
# 8/8 [==============================] - 0s 26ms/step - loss: 0.6205 - accuracy: 0.6506 - val_loss: 0.4660 - val_accuracy: 0.8364
# Epoch 196/350
# 8/8 [==============================] - 0s 28ms/step - loss: 0.6159 - accuracy: 0.6552 - val_loss: 0.4631 - val_accuracy: 0.8416
# Epoch 197/350
# 8/8 [==============================] - 0s 25ms/step - loss: 0.6264 - accuracy: 0.6420 - val_loss: 0.4602 - val_accuracy: 0.8364
# Epoch 198/350
# 8/8 [==============================] - 0s 30ms/step - loss: 0.6198 - accuracy: 0.6491 - val_loss: 0.4901 - val_accuracy: 0.8026
# Epoch 199/350
# 8/8 [==============================] - 0s 28ms/step - loss: 0.6219 - accuracy: 0.6506 - val_loss: 0.4519 - val_accuracy: 0.8468
# Epoch 200/350
# 8/8 [==============================] - 0s 21ms/step - loss: 0.6263 - accuracy: 0.6460 - val_loss: 0.4881 - val_accuracy: 0.8104
# Epoch 201/350
# 8/8 [==============================] - 0s 23ms/step - loss: 0.6196 - accuracy: 0.6516 - val_loss: 0.4587 - val_accuracy: 0.8416
# Epoch 202/350
# 8/8 [==============================] - 0s 20ms/step - loss: 0.6188 - accuracy: 0.6506 - val_loss: 0.4771 - val_accuracy: 0.8286
# Epoch 203/350
# 8/8 [==============================] - 0s 19ms/step - loss: 0.6188 - accuracy: 0.6521 - val_loss: 0.4701 - val_accuracy: 0.8364
# Epoch 204/350
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6135 - accuracy: 0.6531 - val_loss: 0.4998 - val_accuracy: 0.8026
# Epoch 205/350
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6154 - accuracy: 0.6531 - val_loss: 0.4550 - val_accuracy: 0.8442
# Epoch 206/350
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6213 - accuracy: 0.6470 - val_loss: 0.4893 - val_accuracy: 0.8052
# Epoch 207/350
# 8/8 [==============================] - 0s 17ms/step - loss: 0.6176 - accuracy: 0.6496 - val_loss: 0.4905 - val_accuracy: 0.8000
# Epoch 208/350
# 8/8 [==============================] - 0s 13ms/step - loss: 0.6218 - accuracy: 0.6435 - val_loss: 0.4664 - val_accuracy: 0.8312
# Epoch 209/350
# 8/8 [==============================] - 0s 17ms/step - loss: 0.6198 - accuracy: 0.6480 - val_loss: 0.4504 - val_accuracy: 0.8442
# Epoch 210/350
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6197 - accuracy: 0.6531 - val_loss: 0.4561 - val_accuracy: 0.8390
# Epoch 211/350
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6236 - accuracy: 0.6496 - val_loss: 0.4815 - val_accuracy: 0.8104
# Epoch 212/350
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6237 - accuracy: 0.6486 - val_loss: 0.5005 - val_accuracy: 0.8026
# Epoch 213/350
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6269 - accuracy: 0.6440 - val_loss: 0.4792 - val_accuracy: 0.8234
# Epoch 214/350
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6213 - accuracy: 0.6450 - val_loss: 0.4639 - val_accuracy: 0.8338
# Epoch 215/350
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6151 - accuracy: 0.6511 - val_loss: 0.4695 - val_accuracy: 0.8286
# Epoch 216/350
# 8/8 [==============================] - 0s 17ms/step - loss: 0.6209 - accuracy: 0.6475 - val_loss: 0.4617 - val_accuracy: 0.8286
# Epoch 217/350
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6189 - accuracy: 0.6465 - val_loss: 0.4545 - val_accuracy: 0.8494
# Epoch 218/350
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6276 - accuracy: 0.6460 - val_loss: 0.4727 - val_accuracy: 0.8286
# Epoch 219/350
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6191 - accuracy: 0.6526 - val_loss: 0.4583 - val_accuracy: 0.8390
# Epoch 220/350
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6114 - accuracy: 0.6506 - val_loss: 0.4715 - val_accuracy: 0.8260
# Epoch 221/350
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6219 - accuracy: 0.6526 - val_loss: 0.4505 - val_accuracy: 0.8468
# Epoch 222/350
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6182 - accuracy: 0.6526 - val_loss: 0.4673 - val_accuracy: 0.8390
# Epoch 223/350
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6139 - accuracy: 0.6511 - val_loss: 0.4759 - val_accuracy: 0.8364
# Epoch 224/350
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6154 - accuracy: 0.6506 - val_loss: 0.4483 - val_accuracy: 0.8494
# Epoch 225/350
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6212 - accuracy: 0.6496 - val_loss: 0.4544 - val_accuracy: 0.8468
# Epoch 226/350
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6213 - accuracy: 0.6465 - val_loss: 0.4574 - val_accuracy: 0.8416
# Epoch 227/350
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6174 - accuracy: 0.6450 - val_loss: 0.4573 - val_accuracy: 0.8364
# Epoch 228/350
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6155 - accuracy: 0.6531 - val_loss: 0.4698 - val_accuracy: 0.8286
# Epoch 229/350
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6164 - accuracy: 0.6511 - val_loss: 0.4661 - val_accuracy: 0.8312
# Epoch 230/350
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6152 - accuracy: 0.6541 - val_loss: 0.4639 - val_accuracy: 0.8286
# Epoch 231/350
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6161 - accuracy: 0.6511 - val_loss: 0.4553 - val_accuracy: 0.8364
# Epoch 232/350
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6129 - accuracy: 0.6531 - val_loss: 0.4541 - val_accuracy: 0.8468
# Epoch 233/350
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6170 - accuracy: 0.6460 - val_loss: 0.4922 - val_accuracy: 0.8052
# Epoch 234/350
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6169 - accuracy: 0.6526 - val_loss: 0.4513 - val_accuracy: 0.8468
# Epoch 235/350
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6190 - accuracy: 0.6486 - val_loss: 0.4677 - val_accuracy: 0.8338
# Epoch 236/350
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6156 - accuracy: 0.6496 - val_loss: 0.4576 - val_accuracy: 0.8416
# Epoch 237/350
# 8/8 [==============================] - 0s 13ms/step - loss: 0.6146 - accuracy: 0.6516 - val_loss: 0.4600 - val_accuracy: 0.8364
# Epoch 238/350
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6137 - accuracy: 0.6536 - val_loss: 0.4483 - val_accuracy: 0.8312
# Epoch 239/350
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6219 - accuracy: 0.6521 - val_loss: 0.4491 - val_accuracy: 0.8468
# Epoch 240/350
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6193 - accuracy: 0.6501 - val_loss: 0.4498 - val_accuracy: 0.8468
# Epoch 241/350
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6177 - accuracy: 0.6531 - val_loss: 0.4579 - val_accuracy: 0.8338
# Epoch 242/350
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6107 - accuracy: 0.6541 - val_loss: 0.5047 - val_accuracy: 0.7896
# Epoch 243/350
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6126 - accuracy: 0.6531 - val_loss: 0.4454 - val_accuracy: 0.8468
# Epoch 244/350
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6124 - accuracy: 0.6511 - val_loss: 0.4455 - val_accuracy: 0.8416
# Epoch 245/350
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6138 - accuracy: 0.6506 - val_loss: 0.4451 - val_accuracy: 0.8442
# Epoch 246/350
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6177 - accuracy: 0.6491 - val_loss: 0.4804 - val_accuracy: 0.8078
# Epoch 247/350
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6138 - accuracy: 0.6531 - val_loss: 0.4888 - val_accuracy: 0.8078
# Epoch 248/350
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6170 - accuracy: 0.6511 - val_loss: 0.4724 - val_accuracy: 0.8156
# Epoch 249/350
# 8/8 [==============================] - 0s 17ms/step - loss: 0.6165 - accuracy: 0.6491 - val_loss: 0.4983 - val_accuracy: 0.8000
# Epoch 250/350
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6163 - accuracy: 0.6526 - val_loss: 0.4452 - val_accuracy: 0.8468
# Epoch 251/350
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6103 - accuracy: 0.6506 - val_loss: 0.4837 - val_accuracy: 0.8130
# Epoch 252/350
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6169 - accuracy: 0.6491 - val_loss: 0.4568 - val_accuracy: 0.8390
# Epoch 253/350
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6145 - accuracy: 0.6567 - val_loss: 0.4622 - val_accuracy: 0.8338
# Epoch 254/350
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6069 - accuracy: 0.6562 - val_loss: 0.4724 - val_accuracy: 0.8130
# Epoch 255/350
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6162 - accuracy: 0.6536 - val_loss: 0.4639 - val_accuracy: 0.8312
# Epoch 256/350
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6248 - accuracy: 0.6455 - val_loss: 0.4664 - val_accuracy: 0.8364
# Epoch 257/350
# 8/8 [==============================] - 0s 18ms/step - loss: 0.6117 - accuracy: 0.6531 - val_loss: 0.4821 - val_accuracy: 0.8182
# Epoch 258/350
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6138 - accuracy: 0.6531 - val_loss: 0.4579 - val_accuracy: 0.8338
# Epoch 259/350
# 8/8 [==============================] - 0s 13ms/step - loss: 0.6154 - accuracy: 0.6562 - val_loss: 0.4691 - val_accuracy: 0.8286
# Epoch 260/350
# 8/8 [==============================] - 0s 13ms/step - loss: 0.6146 - accuracy: 0.6546 - val_loss: 0.4707 - val_accuracy: 0.8260
# Epoch 261/350
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6213 - accuracy: 0.6506 - val_loss: 0.4848 - val_accuracy: 0.8104
# Epoch 262/350
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6140 - accuracy: 0.6557 - val_loss: 0.4559 - val_accuracy: 0.8338
# Epoch 263/350
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6085 - accuracy: 0.6562 - val_loss: 0.4537 - val_accuracy: 0.8416
# Epoch 264/350
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6113 - accuracy: 0.6506 - val_loss: 0.4796 - val_accuracy: 0.8182
# Epoch 265/350
# 8/8 [==============================] - 0s 18ms/step - loss: 0.6144 - accuracy: 0.6536 - val_loss: 0.4534 - val_accuracy: 0.8416
# Epoch 266/350
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6079 - accuracy: 0.6536 - val_loss: 0.4651 - val_accuracy: 0.8208
# Epoch 267/350
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6085 - accuracy: 0.6592 - val_loss: 0.4590 - val_accuracy: 0.8130
# Epoch 268/350
# 8/8 [==============================] - 0s 13ms/step - loss: 0.6144 - accuracy: 0.6496 - val_loss: 0.4853 - val_accuracy: 0.8104
# Epoch 269/350
# 8/8 [==============================] - 0s 13ms/step - loss: 0.6125 - accuracy: 0.6552 - val_loss: 0.4434 - val_accuracy: 0.8442
# Epoch 270/350
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6087 - accuracy: 0.6587 - val_loss: 0.4688 - val_accuracy: 0.8208
# Epoch 271/350
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6136 - accuracy: 0.6541 - val_loss: 0.4727 - val_accuracy: 0.8234
# Epoch 272/350
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6206 - accuracy: 0.6480 - val_loss: 0.4452 - val_accuracy: 0.8442
# Epoch 273/350
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6136 - accuracy: 0.6572 - val_loss: 0.4778 - val_accuracy: 0.8208
# Epoch 274/350
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6108 - accuracy: 0.6531 - val_loss: 0.4731 - val_accuracy: 0.8234
# Epoch 275/350
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6121 - accuracy: 0.6557 - val_loss: 0.4615 - val_accuracy: 0.8416
# Epoch 276/350
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6129 - accuracy: 0.6572 - val_loss: 0.4436 - val_accuracy: 0.8519
# Epoch 277/350
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6152 - accuracy: 0.6506 - val_loss: 0.4769 - val_accuracy: 0.8208
# Epoch 278/350
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6079 - accuracy: 0.6526 - val_loss: 0.4551 - val_accuracy: 0.8442
# Epoch 279/350
# 8/8 [==============================] - 0s 17ms/step - loss: 0.6108 - accuracy: 0.6541 - val_loss: 0.5018 - val_accuracy: 0.7948
# Epoch 280/350
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6076 - accuracy: 0.6582 - val_loss: 0.4467 - val_accuracy: 0.8390
# Epoch 281/350
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6091 - accuracy: 0.6552 - val_loss: 0.4765 - val_accuracy: 0.8208
# Epoch 282/350
# 8/8 [==============================] - 0s 17ms/step - loss: 0.6111 - accuracy: 0.6557 - val_loss: 0.4663 - val_accuracy: 0.8260
# Epoch 283/350
# 8/8 [==============================] - 0s 19ms/step - loss: 0.6078 - accuracy: 0.6572 - val_loss: 0.4515 - val_accuracy: 0.8390
# Epoch 284/350
# 8/8 [==============================] - 0s 24ms/step - loss: 0.6081 - accuracy: 0.6541 - val_loss: 0.4531 - val_accuracy: 0.8364
# Epoch 285/350
# 8/8 [==============================] - 0s 20ms/step - loss: 0.6095 - accuracy: 0.6526 - val_loss: 0.5154 - val_accuracy: 0.7792
# Epoch 286/350
# 8/8 [==============================] - 0s 21ms/step - loss: 0.6099 - accuracy: 0.6577 - val_loss: 0.4615 - val_accuracy: 0.8312
# Epoch 287/350
# 8/8 [==============================] - 0s 19ms/step - loss: 0.6099 - accuracy: 0.6557 - val_loss: 0.4639 - val_accuracy: 0.8286
# Epoch 288/350
# 8/8 [==============================] - 0s 21ms/step - loss: 0.6148 - accuracy: 0.6506 - val_loss: 0.4665 - val_accuracy: 0.8260
# Epoch 289/350
# 8/8 [==============================] - 0s 24ms/step - loss: 0.6117 - accuracy: 0.6546 - val_loss: 0.4550 - val_accuracy: 0.8312
# Epoch 290/350
# 8/8 [==============================] - 0s 21ms/step - loss: 0.6127 - accuracy: 0.6582 - val_loss: 0.4715 - val_accuracy: 0.8208
# Epoch 291/350
# 8/8 [==============================] - 0s 20ms/step - loss: 0.6145 - accuracy: 0.6531 - val_loss: 0.4716 - val_accuracy: 0.8286
# Epoch 292/350
# 8/8 [==============================] - 0s 18ms/step - loss: 0.6084 - accuracy: 0.6582 - val_loss: 0.4520 - val_accuracy: 0.8312
# Epoch 293/350
# 8/8 [==============================] - 0s 20ms/step - loss: 0.6101 - accuracy: 0.6567 - val_loss: 0.4842 - val_accuracy: 0.8182
# Epoch 294/350
# 8/8 [==============================] - 0s 20ms/step - loss: 0.6124 - accuracy: 0.6536 - val_loss: 0.4643 - val_accuracy: 0.8208
# Epoch 295/350
# 8/8 [==============================] - 0s 23ms/step - loss: 0.6127 - accuracy: 0.6562 - val_loss: 0.4584 - val_accuracy: 0.8312
# Epoch 296/350
# 8/8 [==============================] - 0s 18ms/step - loss: 0.6125 - accuracy: 0.6546 - val_loss: 0.4487 - val_accuracy: 0.8442
# Epoch 297/350
# 8/8 [==============================] - 0s 19ms/step - loss: 0.6126 - accuracy: 0.6546 - val_loss: 0.4628 - val_accuracy: 0.8338
# Epoch 298/350
# 8/8 [==============================] - 0s 20ms/step - loss: 0.6134 - accuracy: 0.6557 - val_loss: 0.5258 - val_accuracy: 0.7584
# Epoch 299/350
# 8/8 [==============================] - 0s 21ms/step - loss: 0.6116 - accuracy: 0.6470 - val_loss: 0.4654 - val_accuracy: 0.8286
# Epoch 300/350
# 8/8 [==============================] - 0s 21ms/step - loss: 0.6117 - accuracy: 0.6526 - val_loss: 0.4643 - val_accuracy: 0.8234
# Epoch 301/350
# 8/8 [==============================] - 0s 24ms/step - loss: 0.6060 - accuracy: 0.6587 - val_loss: 0.4599 - val_accuracy: 0.8234
# Epoch 302/350
# 8/8 [==============================] - 0s 23ms/step - loss: 0.6118 - accuracy: 0.6536 - val_loss: 0.4647 - val_accuracy: 0.8208
# Epoch 303/350
# 8/8 [==============================] - 0s 23ms/step - loss: 0.6052 - accuracy: 0.6592 - val_loss: 0.4546 - val_accuracy: 0.8338
# Epoch 304/350
# 8/8 [==============================] - 0s 22ms/step - loss: 0.6046 - accuracy: 0.6633 - val_loss: 0.4494 - val_accuracy: 0.8364
# Epoch 305/350
# 8/8 [==============================] - 0s 21ms/step - loss: 0.6125 - accuracy: 0.6572 - val_loss: 0.4594 - val_accuracy: 0.8234
# Epoch 306/350
# 8/8 [==============================] - 0s 23ms/step - loss: 0.6133 - accuracy: 0.6557 - val_loss: 0.4682 - val_accuracy: 0.8182
# Epoch 307/350
# 8/8 [==============================] - 0s 25ms/step - loss: 0.6094 - accuracy: 0.6602 - val_loss: 0.4468 - val_accuracy: 0.8338
# Epoch 308/350
# 8/8 [==============================] - 0s 23ms/step - loss: 0.6048 - accuracy: 0.6602 - val_loss: 0.4726 - val_accuracy: 0.8104
# Epoch 309/350
# 8/8 [==============================] - 0s 21ms/step - loss: 0.6139 - accuracy: 0.6526 - val_loss: 0.4580 - val_accuracy: 0.8234
# Epoch 310/350
# 8/8 [==============================] - 0s 23ms/step - loss: 0.5986 - accuracy: 0.6704 - val_loss: 0.4780 - val_accuracy: 0.7948
# Epoch 311/350
# 8/8 [==============================] - 0s 22ms/step - loss: 0.6096 - accuracy: 0.6541 - val_loss: 0.4700 - val_accuracy: 0.8182
# Epoch 312/350
# 8/8 [==============================] - 0s 26ms/step - loss: 0.6103 - accuracy: 0.6531 - val_loss: 0.4589 - val_accuracy: 0.8104
# Epoch 313/350
# 8/8 [==============================] - 0s 20ms/step - loss: 0.6099 - accuracy: 0.6587 - val_loss: 0.4717 - val_accuracy: 0.8156
# Epoch 314/350
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6060 - accuracy: 0.6668 - val_loss: 0.4700 - val_accuracy: 0.8156
# Epoch 315/350
# 8/8 [==============================] - 0s 17ms/step - loss: 0.6074 - accuracy: 0.6597 - val_loss: 0.4662 - val_accuracy: 0.8234
# Epoch 316/350
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6129 - accuracy: 0.6577 - val_loss: 0.4817 - val_accuracy: 0.8156
# Epoch 317/350
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6068 - accuracy: 0.6623 - val_loss: 0.5232 - val_accuracy: 0.7662
# Epoch 318/350
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6084 - accuracy: 0.6572 - val_loss: 0.4577 - val_accuracy: 0.8234
# Epoch 319/350
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6042 - accuracy: 0.6643 - val_loss: 0.4742 - val_accuracy: 0.8026
# Epoch 320/350
# 8/8 [==============================] - 0s 17ms/step - loss: 0.6036 - accuracy: 0.6618 - val_loss: 0.4436 - val_accuracy: 0.8338
# Epoch 321/350
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6139 - accuracy: 0.6511 - val_loss: 0.4629 - val_accuracy: 0.8234
# Epoch 322/350
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6099 - accuracy: 0.6597 - val_loss: 0.4400 - val_accuracy: 0.8364
# Epoch 323/350
# 8/8 [==============================] - 0s 17ms/step - loss: 0.6100 - accuracy: 0.6592 - val_loss: 0.4646 - val_accuracy: 0.8182
# Epoch 324/350
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6042 - accuracy: 0.6577 - val_loss: 0.4834 - val_accuracy: 0.8078
# Epoch 325/350
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6107 - accuracy: 0.6546 - val_loss: 0.4711 - val_accuracy: 0.8182
# Epoch 326/350
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6150 - accuracy: 0.6486 - val_loss: 0.4772 - val_accuracy: 0.8182
# Epoch 327/350
# 8/8 [==============================] - 0s 17ms/step - loss: 0.6025 - accuracy: 0.6618 - val_loss: 0.4510 - val_accuracy: 0.8338
# Epoch 328/350
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6045 - accuracy: 0.6582 - val_loss: 0.4834 - val_accuracy: 0.8026
# Epoch 329/350
# 8/8 [==============================] - 0s 18ms/step - loss: 0.6057 - accuracy: 0.6536 - val_loss: 0.4548 - val_accuracy: 0.8260
# Epoch 330/350
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6074 - accuracy: 0.6648 - val_loss: 0.4700 - val_accuracy: 0.8156
# Epoch 331/350
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6093 - accuracy: 0.6516 - val_loss: 0.4524 - val_accuracy: 0.8338
# Epoch 332/350
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6066 - accuracy: 0.6577 - val_loss: 0.4739 - val_accuracy: 0.8182
# Epoch 333/350
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6079 - accuracy: 0.6582 - val_loss: 0.4798 - val_accuracy: 0.8130
# Epoch 334/350
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5993 - accuracy: 0.6638 - val_loss: 0.4711 - val_accuracy: 0.8052
# Epoch 335/350
# 8/8 [==============================] - 0s 17ms/step - loss: 0.6040 - accuracy: 0.6643 - val_loss: 0.4720 - val_accuracy: 0.8130
# Epoch 336/350
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6017 - accuracy: 0.6607 - val_loss: 0.4716 - val_accuracy: 0.8156
# Epoch 337/350
# 8/8 [==============================] - 0s 17ms/step - loss: 0.6064 - accuracy: 0.6612 - val_loss: 0.4607 - val_accuracy: 0.8234
# Epoch 338/350
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6154 - accuracy: 0.6526 - val_loss: 0.4914 - val_accuracy: 0.8078
# Epoch 339/350
# ...
# Epoch 239/350
# 8/8 [==============================] - 0s 28ms/step - loss: 0.6113 - accuracy: 0.6541 - val_loss: 0.4816 - val_accuracy: 0.8130
# Epoch 240/350
# 8/8 [==============================] - 0s 28ms/step - loss: 0.6139 - accuracy: 0.6536 - val_loss: 0.4923 - val_accuracy: 0.8000
# Epoch 241/350
# 8/8 [==============================] - 0s 28ms/step - loss: 0.6176 - accuracy: 0.6496 - val_loss: 0.4869 - val_accuracy: 0.8130
# Epoch 242/350
# 8/8 [==============================] - 0s 29ms/step - loss: 0.6136 - accuracy: 0.6607 - val_loss: 0.4468 - val_accuracy: 0.8442
# Epoch 243/350
# 8/8 [==============================] - 0s 21ms/step - loss: 0.6161 - accuracy: 0.6511 - val_loss: 0.4559 - val_accuracy: 0.8338
# Epoch 244/350
# 8/8 [==============================] - 0s 21ms/step - loss: 0.6085 - accuracy: 0.6597 - val_loss: 0.4661 - val_accuracy: 0.8312
# Epoch 245/350
# 8/8 [==============================] - 0s 21ms/step - loss: 0.6208 - accuracy: 0.6496 - val_loss: 0.4696 - val_accuracy: 0.8312
# Epoch 246/350
# 8/8 [==============================] - 0s 21ms/step - loss: 0.6075 - accuracy: 0.6577 - val_loss: 0.4597 - val_accuracy: 0.8312
# Epoch 247/350
# 8/8 [==============================] - 0s 20ms/step - loss: 0.6125 - accuracy: 0.6557 - val_loss: 0.4620 - val_accuracy: 0.8338
# Epoch 248/350
# 8/8 [==============================] - 0s 20ms/step - loss: 0.6154 - accuracy: 0.6536 - val_loss: 0.4600 - val_accuracy: 0.8312
# Epoch 249/350
# 8/8 [==============================] - 0s 21ms/step - loss: 0.6169 - accuracy: 0.6567 - val_loss: 0.4631 - val_accuracy: 0.8338
# Epoch 250/350
# 8/8 [==============================] - 0s 22ms/step - loss: 0.6136 - accuracy: 0.6531 - val_loss: 0.4535 - val_accuracy: 0.8390
# Epoch 251/350
# 8/8 [==============================] - 0s 22ms/step - loss: 0.6115 - accuracy: 0.6516 - val_loss: 0.4516 - val_accuracy: 0.8416
# Epoch 252/350
# 8/8 [==============================] - 0s 23ms/step - loss: 0.6176 - accuracy: 0.6480 - val_loss: 0.4604 - val_accuracy: 0.8390
# Epoch 253/350
# 8/8 [==============================] - 0s 20ms/step - loss: 0.6212 - accuracy: 0.6430 - val_loss: 0.4817 - val_accuracy: 0.8156
# Epoch 254/350
# 8/8 [==============================] - 0s 21ms/step - loss: 0.6186 - accuracy: 0.6470 - val_loss: 0.4483 - val_accuracy: 0.8442
# Epoch 255/350
# 8/8 [==============================] - 0s 22ms/step - loss: 0.6201 - accuracy: 0.6496 - val_loss: 0.4968 - val_accuracy: 0.8052
# Epoch 256/350
# 8/8 [==============================] - 0s 21ms/step - loss: 0.6176 - accuracy: 0.6552 - val_loss: 0.5120 - val_accuracy: 0.7870
# Epoch 257/350
# 8/8 [==============================] - 0s 22ms/step - loss: 0.6252 - accuracy: 0.6486 - val_loss: 0.4819 - val_accuracy: 0.8156
# Epoch 258/350
# 8/8 [==============================] - 0s 21ms/step - loss: 0.6142 - accuracy: 0.6506 - val_loss: 0.4541 - val_accuracy: 0.8416
# Epoch 259/350
# 8/8 [==============================] - 0s 21ms/step - loss: 0.6144 - accuracy: 0.6521 - val_loss: 0.4853 - val_accuracy: 0.8104
# Epoch 260/350
# 8/8 [==============================] - 0s 21ms/step - loss: 0.6137 - accuracy: 0.6511 - val_loss: 0.4489 - val_accuracy: 0.8468
# Epoch 261/350
# 8/8 [==============================] - 0s 23ms/step - loss: 0.6139 - accuracy: 0.6531 - val_loss: 0.4710 - val_accuracy: 0.8286
# Epoch 262/350
# 8/8 [==============================] - 0s 22ms/step - loss: 0.6144 - accuracy: 0.6541 - val_loss: 0.4490 - val_accuracy: 0.8416
# Epoch 263/350
# 8/8 [==============================] - 0s 22ms/step - loss: 0.6086 - accuracy: 0.6592 - val_loss: 0.4773 - val_accuracy: 0.8156
# Epoch 264/350
# 8/8 [==============================] - 0s 21ms/step - loss: 0.6167 - accuracy: 0.6531 - val_loss: 0.4715 - val_accuracy: 0.8208
# Epoch 265/350
# 8/8 [==============================] - 0s 22ms/step - loss: 0.6172 - accuracy: 0.6531 - val_loss: 0.4599 - val_accuracy: 0.8390
# Epoch 266/350
# 8/8 [==============================] - 0s 21ms/step - loss: 0.6108 - accuracy: 0.6562 - val_loss: 0.4773 - val_accuracy: 0.8130
# Epoch 267/350
# 8/8 [==============================] - 0s 21ms/step - loss: 0.6073 - accuracy: 0.6557 - val_loss: 0.4917 - val_accuracy: 0.8026
# Epoch 268/350
# 8/8 [==============================] - 0s 22ms/step - loss: 0.6086 - accuracy: 0.6546 - val_loss: 0.4941 - val_accuracy: 0.7974
# Epoch 269/350
# 8/8 [==============================] - 0s 24ms/step - loss: 0.6145 - accuracy: 0.6516 - val_loss: 0.4530 - val_accuracy: 0.8312
# Epoch 270/350
# 8/8 [==============================] - 0s 22ms/step - loss: 0.6148 - accuracy: 0.6577 - val_loss: 0.5273 - val_accuracy: 0.7636
# Epoch 271/350
# 8/8 [==============================] - 0s 20ms/step - loss: 0.6213 - accuracy: 0.6501 - val_loss: 0.4686 - val_accuracy: 0.8312
# Epoch 272/350
# 8/8 [==============================] - 0s 21ms/step - loss: 0.6100 - accuracy: 0.6546 - val_loss: 0.4623 - val_accuracy: 0.8312
# Epoch 273/350
# 8/8 [==============================] - 0s 20ms/step - loss: 0.6060 - accuracy: 0.6602 - val_loss: 0.4445 - val_accuracy: 0.8494
# Epoch 274/350
# 8/8 [==============================] - 0s 21ms/step - loss: 0.6195 - accuracy: 0.6546 - val_loss: 0.5090 - val_accuracy: 0.7896
# Epoch 275/350
# 8/8 [==============================] - 0s 23ms/step - loss: 0.6115 - accuracy: 0.6562 - val_loss: 0.4774 - val_accuracy: 0.8156
# Epoch 276/350
# 8/8 [==============================] - 0s 20ms/step - loss: 0.6135 - accuracy: 0.6546 - val_loss: 0.4572 - val_accuracy: 0.8390
# Epoch 277/350
# 8/8 [==============================] - 0s 20ms/step - loss: 0.6148 - accuracy: 0.6486 - val_loss: 0.4742 - val_accuracy: 0.8260
# Epoch 278/350
# 8/8 [==============================] - 0s 18ms/step - loss: 0.6128 - accuracy: 0.6506 - val_loss: 0.4709 - val_accuracy: 0.8234
# Epoch 279/350
# 8/8 [==============================] - 0s 20ms/step - loss: 0.6133 - accuracy: 0.6546 - val_loss: 0.4419 - val_accuracy: 0.8494
# Epoch 280/350
# 8/8 [==============================] - 0s 22ms/step - loss: 0.6118 - accuracy: 0.6531 - val_loss: 0.4591 - val_accuracy: 0.8338
# Epoch 281/350
# 8/8 [==============================] - 0s 21ms/step - loss: 0.6086 - accuracy: 0.6562 - val_loss: 0.4996 - val_accuracy: 0.7974
# Epoch 282/350
# 8/8 [==============================] - 0s 24ms/step - loss: 0.6128 - accuracy: 0.6552 - val_loss: 0.4646 - val_accuracy: 0.8286
# Epoch 283/350
# 8/8 [==============================] - 0s 21ms/step - loss: 0.6072 - accuracy: 0.6587 - val_loss: 0.4653 - val_accuracy: 0.8286
# Epoch 284/350
# 8/8 [==============================] - 0s 23ms/step - loss: 0.6148 - accuracy: 0.6516 - val_loss: 0.4667 - val_accuracy: 0.8234
# Epoch 285/350
# 8/8 [==============================] - 0s 21ms/step - loss: 0.6121 - accuracy: 0.6536 - val_loss: 0.4810 - val_accuracy: 0.8156
# Epoch 286/350
# 8/8 [==============================] - 0s 22ms/step - loss: 0.6073 - accuracy: 0.6582 - val_loss: 0.4965 - val_accuracy: 0.8052
# Epoch 287/350
# 8/8 [==============================] - 0s 19ms/step - loss: 0.6115 - accuracy: 0.6577 - val_loss: 0.4772 - val_accuracy: 0.8156
# Epoch 288/350
# 8/8 [==============================] - 0s 23ms/step - loss: 0.6107 - accuracy: 0.6557 - val_loss: 0.4895 - val_accuracy: 0.8000
# Epoch 289/350
# 8/8 [==============================] - 0s 25ms/step - loss: 0.6168 - accuracy: 0.6506 - val_loss: 0.4836 - val_accuracy: 0.8182
# Epoch 290/350
# 8/8 [==============================] - 0s 20ms/step - loss: 0.6114 - accuracy: 0.6546 - val_loss: 0.4473 - val_accuracy: 0.8468
# Epoch 291/350
# 8/8 [==============================] - 0s 21ms/step - loss: 0.6114 - accuracy: 0.6562 - val_loss: 0.4645 - val_accuracy: 0.8234
# Epoch 292/350
# 8/8 [==============================] - 0s 21ms/step - loss: 0.6155 - accuracy: 0.6557 - val_loss: 0.4919 - val_accuracy: 0.8078
# Epoch 293/350
# 8/8 [==============================] - 0s 19ms/step - loss: 0.6118 - accuracy: 0.6531 - val_loss: 0.4686 - val_accuracy: 0.8286
# Epoch 294/350
# 8/8 [==============================] - 0s 22ms/step - loss: 0.6091 - accuracy: 0.6541 - val_loss: 0.4741 - val_accuracy: 0.8182
# Epoch 295/350
# 8/8 [==============================] - 0s 21ms/step - loss: 0.6128 - accuracy: 0.6552 - val_loss: 0.4568 - val_accuracy: 0.8364
# Epoch 296/350
# 8/8 [==============================] - 0s 21ms/step - loss: 0.6106 - accuracy: 0.6582 - val_loss: 0.4529 - val_accuracy: 0.8416
# Epoch 297/350
# 8/8 [==============================] - 0s 21ms/step - loss: 0.6096 - accuracy: 0.6557 - val_loss: 0.4424 - val_accuracy: 0.8468
# Epoch 298/350
# 8/8 [==============================] - 0s 23ms/step - loss: 0.6089 - accuracy: 0.6546 - val_loss: 0.4870 - val_accuracy: 0.8130
# Epoch 299/350
# 8/8 [==============================] - 0s 21ms/step - loss: 0.6123 - accuracy: 0.6587 - val_loss: 0.4601 - val_accuracy: 0.8286
# Epoch 300/350
# 8/8 [==============================] - 0s 24ms/step - loss: 0.6097 - accuracy: 0.6536 - val_loss: 0.4489 - val_accuracy: 0.8390
# Epoch 301/350
# 8/8 [==============================] - 0s 29ms/step - loss: 0.6046 - accuracy: 0.6607 - val_loss: 0.4443 - val_accuracy: 0.8519
# Epoch 302/350
# 8/8 [==============================] - 0s 25ms/step - loss: 0.6113 - accuracy: 0.6536 - val_loss: 0.4915 - val_accuracy: 0.8026
# Epoch 303/350
# 8/8 [==============================] - 0s 31ms/step - loss: 0.6064 - accuracy: 0.6572 - val_loss: 0.4488 - val_accuracy: 0.8390
# Epoch 304/350
# 8/8 [==============================] - 0s 27ms/step - loss: 0.6120 - accuracy: 0.6623 - val_loss: 0.4436 - val_accuracy: 0.8468
# Epoch 305/350
# 8/8 [==============================] - 0s 29ms/step - loss: 0.6116 - accuracy: 0.6541 - val_loss: 0.4597 - val_accuracy: 0.8286
# Epoch 306/350
# 8/8 [==============================] - 0s 28ms/step - loss: 0.6039 - accuracy: 0.6592 - val_loss: 0.4492 - val_accuracy: 0.8312
# Epoch 307/350
# 8/8 [==============================] - 0s 28ms/step - loss: 0.6309 - accuracy: 0.6409 - val_loss: 0.4610 - val_accuracy: 0.8338
# Epoch 308/350
# 8/8 [==============================] - 0s 28ms/step - loss: 0.6089 - accuracy: 0.6567 - val_loss: 0.4648 - val_accuracy: 0.8234
# Epoch 309/350
# 8/8 [==============================] - 0s 29ms/step - loss: 0.6021 - accuracy: 0.6546 - val_loss: 0.4889 - val_accuracy: 0.8052
# Epoch 310/350
# 8/8 [==============================] - 0s 25ms/step - loss: 0.6089 - accuracy: 0.6572 - val_loss: 0.4491 - val_accuracy: 0.8416
# Epoch 311/350
# 8/8 [==============================] - 0s 21ms/step - loss: 0.6088 - accuracy: 0.6587 - val_loss: 0.5067 - val_accuracy: 0.7896
# Epoch 312/350
# 8/8 [==============================] - 0s 28ms/step - loss: 0.6075 - accuracy: 0.6648 - val_loss: 0.4625 - val_accuracy: 0.8312
# Epoch 313/350
# 8/8 [==============================] - 0s 23ms/step - loss: 0.6081 - accuracy: 0.6531 - val_loss: 0.4564 - val_accuracy: 0.8338
# Epoch 314/350
# 8/8 [==============================] - 0s 31ms/step - loss: 0.6117 - accuracy: 0.6536 - val_loss: 0.4657 - val_accuracy: 0.8260
# Epoch 315/350
# 8/8 [==============================] - 0s 26ms/step - loss: 0.6032 - accuracy: 0.6577 - val_loss: 0.4622 - val_accuracy: 0.8312
# Epoch 316/350
# 8/8 [==============================] - 0s 28ms/step - loss: 0.6068 - accuracy: 0.6582 - val_loss: 0.4493 - val_accuracy: 0.8286
# Epoch 317/350
# 8/8 [==============================] - 0s 24ms/step - loss: 0.6097 - accuracy: 0.6577 - val_loss: 0.4526 - val_accuracy: 0.8338
# Epoch 318/350
# 8/8 [==============================] - 0s 27ms/step - loss: 0.6130 - accuracy: 0.6546 - val_loss: 0.4785 - val_accuracy: 0.8130
# Epoch 319/350
# 8/8 [==============================] - 0s 28ms/step - loss: 0.6107 - accuracy: 0.6597 - val_loss: 0.4587 - val_accuracy: 0.8286
# Epoch 320/350
# 8/8 [==============================] - 0s 27ms/step - loss: 0.6104 - accuracy: 0.6587 - val_loss: 0.5357 - val_accuracy: 0.7558
# Epoch 321/350
# 8/8 [==============================] - 0s 26ms/step - loss: 0.6157 - accuracy: 0.6521 - val_loss: 0.4552 - val_accuracy: 0.8364
# Epoch 322/350
# 8/8 [==============================] - 0s 27ms/step - loss: 0.6060 - accuracy: 0.6602 - val_loss: 0.4457 - val_accuracy: 0.8416
# Epoch 323/350
# 8/8 [==============================] - 0s 28ms/step - loss: 0.6188 - accuracy: 0.6460 - val_loss: 0.4555 - val_accuracy: 0.8416
# Epoch 324/350
# 8/8 [==============================] - 0s 27ms/step - loss: 0.6076 - accuracy: 0.6587 - val_loss: 0.4796 - val_accuracy: 0.8208
# Epoch 325/350
# 8/8 [==============================] - 0s 26ms/step - loss: 0.6089 - accuracy: 0.6587 - val_loss: 0.4727 - val_accuracy: 0.8156
# Epoch 326/350
# 8/8 [==============================] - 0s 26ms/step - loss: 0.6072 - accuracy: 0.6557 - val_loss: 0.4558 - val_accuracy: 0.8286
# Epoch 327/350
# 8/8 [==============================] - 0s 30ms/step - loss: 0.6094 - accuracy: 0.6597 - val_loss: 0.4625 - val_accuracy: 0.8312
# Epoch 328/350
# 8/8 [==============================] - 0s 24ms/step - loss: 0.6067 - accuracy: 0.6607 - val_loss: 0.4659 - val_accuracy: 0.8156
# Epoch 329/350
# 8/8 [==============================] - 0s 27ms/step - loss: 0.6076 - accuracy: 0.6582 - val_loss: 0.4529 - val_accuracy: 0.8338
# Epoch 330/350
# 8/8 [==============================] - 0s 25ms/step - loss: 0.6074 - accuracy: 0.6557 - val_loss: 0.4650 - val_accuracy: 0.8208
# Epoch 331/350
# 8/8 [==============================] - 0s 27ms/step - loss: 0.6079 - accuracy: 0.6567 - val_loss: 0.4547 - val_accuracy: 0.8338
# Epoch 332/350
# 8/8 [==============================] - 0s 26ms/step - loss: 0.6045 - accuracy: 0.6602 - val_loss: 0.4692 - val_accuracy: 0.8182
# Epoch 333/350
# 8/8 [==============================] - 0s 29ms/step - loss: 0.6051 - accuracy: 0.6633 - val_loss: 0.4387 - val_accuracy: 0.8468
# Epoch 334/350
# 8/8 [==============================] - 0s 27ms/step - loss: 0.6096 - accuracy: 0.6577 - val_loss: 0.4580 - val_accuracy: 0.8208
# Epoch 335/350
# 8/8 [==============================] - 0s 26ms/step - loss: 0.6019 - accuracy: 0.6602 - val_loss: 0.4507 - val_accuracy: 0.8390
# Epoch 336/350
# 8/8 [==============================] - 0s 20ms/step - loss: 0.6098 - accuracy: 0.6557 - val_loss: 0.4500 - val_accuracy: 0.8338
# Epoch 337/350
# 8/8 [==============================] - 0s 21ms/step - loss: 0.6113 - accuracy: 0.6531 - val_loss: 0.4524 - val_accuracy: 0.8312
# Epoch 338/350
# 8/8 [==============================] - 0s 21ms/step - loss: 0.6104 - accuracy: 0.6541 - val_loss: 0.4517 - val_accuracy: 0.8312
# Epoch 339/350
# 8/8 [==============================] - 0s 22ms/step - loss: 0.6014 - accuracy: 0.6673 - val_loss: 0.4592 - val_accuracy: 0.8364
# Epoch 340/350
# 8/8 [==============================] - 0s 22ms/step - loss: 0.6113 - accuracy: 0.6480 - val_loss: 0.4497 - val_accuracy: 0.8390
# Epoch 341/350
# 8/8 [==============================] - 0s 23ms/step - loss: 0.6061 - accuracy: 0.6536 - val_loss: 0.4929 - val_accuracy: 0.8000
# Epoch 342/350
# 8/8 [==============================] - 0s 22ms/step - loss: 0.6090 - accuracy: 0.6612 - val_loss: 0.4572 - val_accuracy: 0.8234
# Epoch 343/350
# 8/8 [==============================] - 0s 21ms/step - loss: 0.6012 - accuracy: 0.6607 - val_loss: 0.4690 - val_accuracy: 0.8182
# Epoch 344/350
# 8/8 [==============================] - 0s 21ms/step - loss: 0.6075 - accuracy: 0.6602 - val_loss: 0.4651 - val_accuracy: 0.8286
# Epoch 345/350
# 8/8 [==============================] - 0s 20ms/step - loss: 0.6080 - accuracy: 0.6557 - val_loss: 0.4517 - val_accuracy: 0.8338
# Epoch 346/350
# 8/8 [==============================] - 0s 21ms/step - loss: 0.6071 - accuracy: 0.6597 - val_loss: 0.4553 - val_accuracy: 0.8286
# Epoch 347/350
# 8/8 [==============================] - 0s 24ms/step - loss: 0.5980 - accuracy: 0.6628 - val_loss: 0.4546 - val_accuracy: 0.8364
# Epoch 348/350
# 8/8 [==============================] - 0s 23ms/step - loss: 0.6079 - accuracy: 0.6577 - val_loss: 0.5146 - val_accuracy: 0.7766
# Epoch 349/350
# 8/8 [==============================] - 0s 21ms/step - loss: 0.6085 - accuracy: 0.6587 - val_loss: 0.4630 - val_accuracy: 0.8234
# Epoch 350/350
# 8/8 [==============================] - 0s 21ms/step - loss: 0.6022 - accuracy: 0.6648 - val_loss: 0.5065 - val_accuracy: 0.7766

# %% [markdown]
# ## Result of the Ensemble Approach: Peak accuracy reached at 85.71%

# %% [markdown]
# ## Ignore Cells Below

# %%
import numpy as np

# Assuming you have a list of models and validation data x_val
ensemble_predictions = []

# Aggregating Predictions
for model in models:
    predictions = model.predict(x_val)  # each model's predict might return a shape like (num_samples, num_classes)
    ensemble_predictions.append(predictions)

# Combining predictions using averaging
ensemble_predictions_array = np.array(ensemble_predictions)  # shape should be (num_models, num_samples, num_classes)

# Calculating average predictions across models
avg_predictions = np.mean(ensemble_predictions_array, axis=0)

# Converting average predictions to class labels
avg_predicted_labels = np.argmax(avg_predictions, axis=1)  # shape should be (num_samples,)

# Assuming y_val is simply a vector of shape (num_samples,) with class labels
correct_predictions = np.sum(avg_predicted_labels == y_val)
total_predictions = len(y_val)
accuracy = correct_predictions / total_predictions

print("Ensemble Accuracy (Averaging): {:.2%}".format(accuracy))
# Out:
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 3ms/step
# Ensemble Accuracy (Averaging): 81.56%

# %%
# transects_signals_df contains the intensities of transects, type, age, and fold
# you should be able to use these to train models

# Create a copy of transects_signals_df so that it doesn't have to be generated
#  each time

def rolling_window(a, window, step):
    shape = a.shape[:-1] + ((a.shape[-1] - window + 1)//step, window)
    strides = (a.strides[0] * step,) + (a.strides[-1],)
    return np.lib.stride_tricks.as_strided(a, shape=shape, strides=strides)

#print(rolling_window(s[2], 25, 1).shape)

df = transects_signals_df.copy(deep=True)
df['signal'] = df['signal'].apply(lambda x: np.pad(x, (0, int(1.4 * TRANSECT_LENGTH) - x.size), 'constant', constant_values=(0, 0)))
df['signal'] = df['signal'].apply(lambda x: np.flip(x))
df['convolved_signal'] = df['convolved_signal'].apply(lambda x: np.pad(x, (0, int(1.4 * TRANSECT_LENGTH) - x.size), 'constant', constant_values=(0, 0)))
df['convolved_signal'] = df['convolved_signal'].apply(lambda x: np.flip(x))

import keras

# Untuned example from
# https://keras.io/examples/timeseries/timeseries_classification_from_scratch/

def make_model(input_shape):
    input_layer = keras.layers.Input(input_shape)

    conv1 = keras.layers.Conv1D(filters=64, kernel_size=9, padding="same")(input_layer)
    conv1 = keras.layers.BatchNormalization()(conv1)
    conv1 = keras.layers.ReLU()(conv1)

    conv2 = keras.layers.Conv1D(filters=64, kernel_size=5, padding="same")(conv1)
    conv2 = keras.layers.BatchNormalization()(conv2)
    conv2 = keras.layers.ReLU()(conv2)

    conv3 = keras.layers.Conv1D(filters=64, kernel_size=3, padding="same")(conv2)
    conv3 = keras.layers.BatchNormalization()(conv3)
    conv3 = keras.layers.ReLU()(conv3)

    gap = keras.layers.GlobalAveragePooling1D()(conv3)

    output_layer = keras.layers.Dense(2, activation="softmax")(gap)

    return keras.models.Model(inputs=input_layer, outputs=output_layer)

train = df[df['fold'] < 9][['signal', 'type']].to_numpy(copy=True)
val = df[df['fold'] >= 9][['signal', 'type']].to_numpy(copy=True)

print(train.shape)

x_train = np.stack(train[:,0]) / 250.
y_train = train[:,1].astype(int)

x_val = np.stack(val[:,0]) / 250.
y_val = val[:,1].astype(int)

x_train = x_train.reshape((x_train.shape[0], x_train.shape[1], 1))
x_val = x_val.reshape((x_val.shape[0], x_val.shape[1], 1))

model = make_model(input_shape=x_train.shape[1:])

epochs = 500
batch_size = 32

callbacks = [
    keras.callbacks.ModelCheckpoint(
        "best_model.keras", save_best_only=True, monitor="val_loss"
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss", factor=0.5, patience=20, min_lr=0.0001
    ),
    keras.callbacks.EarlyStopping(monitor="val_loss", patience=50, verbose=1),
]
model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["sparse_categorical_accuracy"],
)

history = model.fit(
    x_train,
    y_train,
    batch_size=batch_size,
    epochs=epochs,
    callbacks=callbacks,
    validation_split=0.2,
    verbose=1,
)
